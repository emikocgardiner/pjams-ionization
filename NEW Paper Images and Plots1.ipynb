# %% [markdown]
# Emiko Gardiner - VICO Summer 2021

# %%
import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)
from zeusmp_snapshot_reader import read_zeusmp_snapshot
from zeusmp_snapshot_reader import ScaleFactors

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
from matplotlib.colors import DivergingNorm
from datetime import datetime

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from IPython.display import Image as DisplayImage

# !pip install ipynb
from ipynb.fs.full.snapshotclass import *
VICO_loc = '/scratch/ecg6wm/VICO'

# %%
# INPUTS
frequencies = np.array([.01, .05, .1, .5, 1, 5.3, 23, 43, 100, 230 ]) # GHz
frequencies *= 10**9 # Hz
r_kpc = 1
heights_and_scales = np.load(VICO_loc+'/Data/heights_and_scales.npz')
scales = heights_and_scales['scales'] # AU
heights = heights_and_scales['heights'] # AU

# %% [markdown]
# # 1. Read In Flux npz Arrays

# %% [markdown]
# ### 1.1 1.4Msun 004_n

# %%
Snap004_n = snapshot(snap=4, name = 'Snap004_n', read_zeusmp = False)
Snap004_n.load_shock_variables()
Snap004_n.load_fluxes()

# %%
Snap005_n04 = snapshot(snap=5, name = 'Snap005_n04', read_zeusmp = False)
Snap005_n04.load_shock_variables()
Snap005_n04.load_fluxes()

# %%
Snap006_n04 = snapshot(snap=6, name = 'Snap006_n04', read_zeusmp = False)
Snap006_n04.load_shock_variables()
Snap006_n04.load_fluxes()

# %%
Snap007_n04 = snapshot(snap=7, name = 'Snap007_n04', read_zeusmp = False)
Snap007_n04.load_shock_variables()
Snap007_n04.load_fluxes()

# %%
Snap008_n04 = snapshot(snap=8, name = 'Snap008_n04', read_zeusmp = False)
Snap008_n04.load_shock_variables()
Snap008_n04.load_fluxes()

# %%
Snap009_n04 = snapshot(snap=9, name = 'Snap009_n04', read_zeusmp = False)
Snap009_n04.load_shock_variables()
Snap009_n04.load_fluxes()

# %%
Snap010_n04 = snapshot(snap=10, name = 'Snap010_n04', read_zeusmp = False)
Snap010_n04.load_shock_variables()
Snap010_n04.load_fluxes()

# %%
Snap011_n04 = snapshot(snap=11, name = 'Snap011_n04', read_zeusmp = False)
Snap011_n04.load_shock_variables()
Snap011_n04.load_fluxes()

# %%
Snap012_n04 = snapshot(snap=12, name = 'Snap012_n04', read_zeusmp = False)
Snap012_n04.load_shock_variables()
Snap012_n04.load_fluxes()

# %%
Snap013_n04 = snapshot(snap=13, name = 'Snap013_n04', read_zeusmp = False)
Snap013_n04.load_shock_variables()
Snap013_n04.load_fluxes()

# %%
Snap014_n04 = snapshot(snap=14, name = 'Snap014_n04', read_zeusmp = False)
Snap014_n04.load_shock_variables()
Snap014_n04.load_fluxes()

# %% [markdown]
# ### 1.2 2Msun 009_n

# %%
Snap009_n = snapshot(snap=9, name = 'Snap009_n', read_zeusmp = False)
Snap009_n.load_shock_variables()
Snap009_n.load_fluxes()

# %%
Snap010_n09 = snapshot(snap=10, name = 'Snap010_n09', read_zeusmp = False)
Snap010_n09.load_shock_variables()
Snap010_n09.load_fluxes()

# %%
Snap011_n09 = snapshot(snap=11, name = 'Snap011_n09', read_zeusmp = False)
Snap011_n09.load_shock_variables()
Snap011_n09.load_fluxes()

# %%
Snap012_n09 = snapshot(snap=12, name = 'Snap012_n09', read_zeusmp = False)
Snap012_n09.load_shock_variables()
Snap012_n09.load_fluxes()

# %%
Snap013_n09 = snapshot(snap=13, name = 'Snap013_n09', read_zeusmp = False)
Snap013_n09.load_shock_variables()
Snap013_n09.load_fluxes()

# %%
Snap014_n09 = snapshot(snap=14, name = 'Snap014_n09', read_zeusmp = False)
Snap014_n09.load_shock_variables()
Snap014_n09.load_fluxes()

# %%
Snap015_n09 = snapshot(snap=15, name = 'Snap015_n09', read_zeusmp = False)
Snap015_n09.load_shock_variables()
Snap015_n09.load_fluxes()

# %%
Snap016_n09 = snapshot(snap=16, name = 'Snap016_n09', read_zeusmp = False)
Snap016_n09.load_shock_variables()
Snap016_n09.load_fluxes()

# %%
Snap017_n09 = snapshot(snap=17, name = 'Snap017_n09', read_zeusmp = False)
Snap017_n09.load_shock_variables()
Snap017_n09.load_fluxes()

# %%
Snap018_n09 = snapshot(snap=18, name = 'Snap018_n09', read_zeusmp = False)
Snap018_n09.load_shock_variables()
Snap018_n09.load_fluxes()

# %%
Snap019_n09 = snapshot(snap=19, name = 'Snap019_n09', read_zeusmp = False)
Snap019_n09.load_shock_variables()
Snap019_n09.load_fluxes()

# %% [markdown]
# ### 1.3 4Msun 021_n

# %%
Snap021_n = snapshot(snap=21, name = 'Snap021_n', read_zeusmp = False)
Snap021_n.load_shock_variables()
Snap021_n.load_fluxes()

# %%
Snap022_n21 = snapshot(snap=22, name = 'Snap022_n21', read_zeusmp = False)
Snap022_n21.load_shock_variables()
Snap022_n21.load_fluxes()

# %%
Snap023_n21 = snapshot(snap=23, name = 'Snap023_n21', read_zeusmp = False)
Snap023_n21.load_shock_variables()
Snap023_n21.load_fluxes()

# %%
Snap024_n21 = snapshot(snap=24, name = 'Snap024_n21', read_zeusmp = False)
Snap024_n21.load_shock_variables()
Snap024_n21.load_fluxes()

# %%
Snap025_n21 = snapshot(snap=25, name = 'Snap025_n21', read_zeusmp = False)
Snap025_n21.load_shock_variables()
Snap025_n21.load_fluxes()

# %%
Snap026_n21 = snapshot(snap=26, name = 'Snap026_n21', read_zeusmp = False)
Snap026_n21.load_shock_variables()
Snap026_n21.load_fluxes()

# %%
Snap027_n21 = snapshot(snap=27, name = 'Snap027_n21', read_zeusmp = False)
Snap027_n21.load_shock_variables()
Snap027_n21.load_fluxes()

# %%
Snap028_n21 = snapshot(snap=28, name = 'Snap028_n21', read_zeusmp = False)
Snap028_n21.load_shock_variables()
Snap028_n21.load_fluxes()

# %%
Snap029_n21 = snapshot(snap=29, name = 'Snap029_n21', read_zeusmp = False)
Snap029_n21.load_shock_variables()
Snap029_n21.load_fluxes()

# %%
Snap030_n21 = snapshot(snap=30, name = 'Snap030_n21', read_zeusmp = False)
Snap030_n21.load_shock_variables()
Snap030_n21.load_fluxes()

# %%
Snap031_n21 = snapshot(snap=31, name = 'Snap031_n21', read_zeusmp = False)
Snap031_n21.load_shock_variables()
Snap031_n21.load_fluxes()

# %% [markdown]
# ### 1.4 8Msun 039_n

# %%
Snap039_n = snapshot(snap=39, name = 'Snap039_n', read_zeusmp = False)
Snap039_n.load_shock_variables()
Snap039_n.load_fluxes()

# %%
Snap040_n39 = snapshot(snap=40, name = 'Snap040_n39', read_zeusmp = False)
Snap040_n39.load_shock_variables()
Snap040_n39.load_fluxes()

# %%
Snap041_n39 = snapshot(snap=41, name = 'Snap041_n39', read_zeusmp = False)
Snap041_n39.load_shock_variables()
Snap041_n39.load_fluxes()

# %%
Snap042_n39 = snapshot(snap=42, name = 'Snap042_n39', read_zeusmp = False)
Snap042_n39.load_shock_variables()
Snap042_n39.load_fluxes()

# %%
Snap043_n39 = snapshot(snap=43, name = 'Snap043_n39', read_zeusmp = False)
Snap043_n39.load_shock_variables()
Snap043_n39.load_fluxes()

# %%
Snap044_n39 = snapshot(snap=44, name = 'Snap044_n39', read_zeusmp = False)
Snap044_n39.load_shock_variables()
Snap044_n39.load_fluxes()

# %%
Snap045_n39 = snapshot(snap=45, name = 'Snap045_n39', read_zeusmp = False)
Snap045_n39.load_shock_variables()
Snap045_n39.load_fluxes()

# %%
Snap046_n39 = snapshot(snap=46, name = 'Snap046_n39', read_zeusmp = False)
Snap046_n39.load_shock_variables()
Snap046_n39.load_fluxes()

# %%
Snap047_n39 = snapshot(snap=47, name = 'Snap047_n39', read_zeusmp = False)
Snap047_n39.load_shock_variables()
Snap047_n39.load_fluxes()

# %%
Snap048_n39 = snapshot(snap=48, name = 'Snap048_n39', read_zeusmp = False)
Snap048_n39.load_shock_variables()
Snap048_n39.load_fluxes()

# %%
Snap049_n39 = snapshot(snap=49, name = 'Snap049_n39', read_zeusmp = False)
Snap049_n39.load_shock_variables()
Snap049_n39.load_fluxes()

# %% [markdown]
# ### 1.5 12Msun 054_hb

# %%
Snap054_n = snapshot(snap=54, name = 'Snap054_n', read_zeusmp = False)
Snap054_n.load_shock_variables()
Snap054_n.load_fluxes()

# %%
Snap055_n54 = snapshot(snap=55, name = 'Snap055_n54', read_zeusmp = False)
Snap055_n54.load_shock_variables()
Snap055_n54.load_fluxes()

# %%
Snap056_n54 = snapshot(snap=56, name = 'Snap056_n54', read_zeusmp = False)
Snap056_n54.load_shock_variables()
Snap056_n54.load_fluxes()

# %%
Snap057_n54 = snapshot(snap=57, name = 'Snap057_n54', read_zeusmp = False)
Snap057_n54.load_shock_variables()
Snap057_n54.load_fluxes()

# %%
Snap058_n54 = snapshot(snap=58, name = 'Snap058_n54', read_zeusmp = False)
Snap058_n54.load_shock_variables()
Snap058_n54.load_fluxes()

# %%
Snap059_n54 = snapshot(snap=59, name = 'Snap059_n54', read_zeusmp = False)
Snap059_n54.load_shock_variables()
Snap059_n54.load_fluxes()

# %%
Snap060_n54 = snapshot(snap=60, name = 'Snap060_n54', read_zeusmp = False)
Snap060_n54.load_shock_variables()
Snap060_n54.load_fluxes()

# %%
Snap061_n54 = snapshot(snap=61, name = 'Snap061_n54', read_zeusmp = False)
Snap061_n54.load_shock_variables()
Snap061_n54.load_fluxes()

# %%
Snap062_n54 = snapshot(snap=62, name = 'Snap062_n54', read_zeusmp = False)
Snap062_n54.load_shock_variables()
Snap062_n54.load_fluxes()

# %%
Snap063_n54 = snapshot(snap=63, name = 'Snap063_n54', read_zeusmp = False)
Snap063_n54.load_shock_variables()
Snap063_n54.load_fluxes()

# %%
Snap064_n54 = snapshot(snap=64, name = 'Snap064_n54', read_zeusmp = False)
Snap064_n54.load_shock_variables()
Snap064_n54.load_fluxes()

# %% [markdown]
# ### 1.6 16Msun 068_n

# %%
Snap068_n = snapshot(snap=68, name = 'Snap068_n', read_zeusmp=False)
Snap068_n.load_shock_variables()
Snap068_n.load_fluxes()

# %%
Snap069_n68 = snapshot(snap=69, name = 'Snap069_n68', read_zeusmp = False)
Snap069_n68.load_shock_variables()
Snap069_n68.load_fluxes()

# %%
Snap070_n68 = snapshot(snap=70, name = 'Snap070_n68', read_zeusmp = False)
Snap070_n68.load_shock_variables()
Snap070_n68.load_fluxes()

# %%
Snap071_n68 = snapshot(snap=71, name = 'Snap071_n68', read_zeusmp = False)
Snap071_n68.load_shock_variables()
Snap071_n68.load_fluxes()

# %%
Snap072_n68 = snapshot(snap=72, name = 'Snap072_n68', read_zeusmp = False)
Snap072_n68.load_shock_variables()
Snap072_n68.load_fluxes()

# %%
Snap073_n68 = snapshot(snap=73, name = 'Snap073_n68', read_zeusmp = False)
Snap073_n68.load_shock_variables()
Snap073_n68.load_fluxes()

# %%
Snap074_n68 = snapshot(snap=74, name = 'Snap074_n68', read_zeusmp = False)
Snap074_n68.load_shock_variables()
Snap074_n68.load_fluxes()

# %%
Snap075_n68 = snapshot(snap=75, name = 'Snap075_n68', read_zeusmp = False)
Snap075_n68.load_shock_variables()
Snap075_n68.load_fluxes()

# %%
Snap076_n68 = snapshot(snap=76, name = 'Snap076_n68', read_zeusmp = False)
Snap076_n68.load_shock_variables()
Snap076_n68.load_fluxes()

# %%
Snap077_n68 = snapshot(snap=77, name = 'Snap077_n68', read_zeusmp = False)
Snap077_n68.load_shock_variables()
Snap077_n68.load_fluxes()

# %%
Snap078_n68 = snapshot(snap=78, name = 'Snap078_n68', read_zeusmp = False)
Snap078_n68.load_shock_variables()
Snap078_n68.load_fluxes()

# %% [markdown]
# ### 1.8 24Msun 094_n

# %%
Snap094_n = snapshot(snap=94, name = 'Snap094_n', read_zeusmp = False)
Snap094_n.load_shock_variables()
Snap094_n.load_fluxes()

# %%
Snap106_n94 = snapshot(snap=106, name = 'Snap106_n94', read_zeusmp = False)
Snap106_n94.load_shock_variables()
Snap106_n94.load_fluxes()

# %%
Snap107_n94 = snapshot(snap=107, name = 'Snap107_n94', read_zeusmp = False)
Snap107_n94.load_shock_variables()
Snap107_n94.load_fluxes()

# %%
Snap108_n94 = snapshot(snap=108, name = 'Snap108_n94', read_zeusmp = False)
Snap108_n94.load_shock_variables()
Snap108_n94.load_fluxes()

# %%
Snap109_n94 = snapshot(snap=109, name = 'Snap109_n94', read_zeusmp = False)
Snap109_n94.load_shock_variables()
Snap109_n94.load_fluxes()

# %%
Snap110_n94 = snapshot(snap=110, name = 'Snap110_n94', read_zeusmp = False)
Snap110_n94.load_shock_variables()
Snap110_n94.load_fluxes()

# %%
Snap111_n94 = snapshot(snap=111, name = 'Snap111_n94', read_zeusmp = False)
Snap111_n94.load_shock_variables()
Snap111_n94.load_fluxes()

# %%
Snap112_n94 = snapshot(snap=112, name = 'Snap112_n94', read_zeusmp = False)
Snap112_n94.load_shock_variables()
Snap112_n94.load_fluxes()

# %%
Snap113_n94 = snapshot(snap=113, name = 'Snap113_n94', read_zeusmp = False)
Snap113_n94.load_shock_variables()
Snap113_n94.load_fluxes()

# %%
Snap114_n94 = snapshot(snap=114, name = 'Snap114_n94', read_zeusmp = False)
Snap114_n94.load_shock_variables()
Snap114_n94.load_fluxes()

# %%
Snap115_n94 = snapshot(snap=115, name = 'Snap115_n94', read_zeusmp = False)
Snap115_n94.load_shock_variables()
Snap115_n94.load_fluxes()

# %%
Snap116_n94 = snapshot(snap=116, name = 'Snap116_n94', read_zeusmp = False)
Snap116_n94.load_shock_variables()
Snap116_n94.load_fluxes()

# %% [markdown]
# ## 1.9 Resolution Comparison

# %% [markdown]
# #### 1.9.2 Low Res

# %%
Snap009_nlr = snapshot(snap=9, name = 'Snap009_nlr', read_zeusmp = False)
Snap009_nlr.load_shock_variables()
Snap009_nlr.load_fluxes()

# %%
Snap021_nlr = snapshot(snap=21, name = 'Snap021_nlr', read_zeusmp = False)
Snap021_nlr.load_shock_variables()
Snap021_nlr.load_fluxes()

# %%
Snap039_nlr = snapshot(snap=39, name = 'Snap039_nlr', read_zeusmp = False)
Snap039_nlr.load_shock_variables()
Snap039_nlr.load_fluxes()

# %%
Snap054_nlr = snapshot(snap=54, name = 'Snap054_nlr', read_zeusmp = False)
Snap054_nlr.load_shock_variables()
Snap054_nlr.load_fluxes()

# %%
Snap068_nlr = snapshot(snap=68, name = 'Snap068_nlr', read_zeusmp = False)
Snap068_nlr.load_shock_variables()
Snap068_nlr.load_fluxes()

# %% [markdown]
# #### 1.9.2 Hi-Res

# %%
print('test')

# %%
Snap009_nhr = snapshot(snap=9, name = 'Snap009_nhr', read_zeusmp = False)
Snap009_nhr.load_shock_variables()
Snap009_nhr.load_fluxes()

# %%
Snap021_nhr = snapshot(snap=21, name = 'Snap021_nhr', read_zeusmp = False)
Snap021_nhr.load_shock_variables()
Snap021_nhr.load_fluxes()

# %%
Snap039_nhr = snapshot(snap=39, name = 'Snap039_nhr', read_zeusmp = False)
Snap039_nhr.load_shock_variables()
Snap039_nhr.load_fluxes()

# %% [markdown]
# # *Snapshot Arrays*

# %%
# Snapshots_sf = np.array([Snap005_hf, Snap009_sf, Snap021_sf, Snap039_sf, Snap054_hf, Snap068_n, Snap093_sf])
# Years_sf = np.array(['5,000 yrs', '9,000 yrs', '21,000 yrs', '39,000 yrs', '54,000 yrs', '68,000 yrs', '93,000 yrs'])

Snapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])

Years = np.array(['4,000 yrs', '9,000 yrs', '21,000 yrs', '39,000 yrs', '54,000 yrs', '68,000 yrs', '94,000 yrs'])
Masses = np.array([r'1.4$M_\odot$', r'2$M_\odot$', r'4$M_\odot$',
                   r'8$M_\odot$', r'12$M_\odot$', r'16$M_\odot$',
                   r'24$M_\odot$'])

# %%
# scratch
Snaps_hires = np.array([Snap009_nhr, Snap021_nhr, Snap039_nhr])
Snaps_mires = np.array([Snap009_n, Snap021_n, Snap039_n])
Years_res = np.array(['9,000 yrs', '21,000 yrs', '39,000 yrs'])
Masses_res = np.array([r'2$M_\odot$', r'4$M_\odot$',
                   r'8$M_\odot$'])

# %% [markdown]
# ### *Scale Factors*

# %%
print(Snapshots[4])

# %%
Snap=Snap004_n
def calculate_scale_factors(Snap):
    scale_factors = Snap.cooling_times/Snap.flow_times
    for ijk in np.ndindex(scale_factors.shape):
        if (scale_factors[ijk]>1):
            scale_factors[ijk]=1   
    Snap.scale_factors = scale_factors        
    return scale_factors
    
for Snap in Snapshots:
    print(Snap.name)
    calculate_scale_factors(Snap)

# %% [markdown]
# # 2. Density Slice, Velocity_z Slice, Temperature Slice, Ionization Fraction Slice, Emissivity Slices, Ionized Temperature Projections, Intensity Maps

# %%
# finding maxes for ballpark colorbar scales
Snap054_n.load_intensity_variables(5.3*10**9)
print('54000 yrs, 12Msun')
print('max intensity:',np.max(Snap054_n.InuA))
print('max temp:',np.max(Snap054_n.temperatures))
print('max j_nu:',np.max(Snap054_n.emission_coefs)*10**26)

print('max j_nu in middle slice:', 
      np.max(Snap054_n.emission_coefs[:,:,Snap054_n.mid3]))
print(np.max(Snap054_n.emission_coefs)*10**26, 
      np.unravel_index(Snap054_n.emission_coefs.argmax(), Snap054_n.emission_coefs.shape))

# %% [markdown]
# ## 2.1 Slices

# %% [markdown]
# ##### Slice Methods

# %%
# !pip install obspy
import matplotlib.colors as colors
from obspy.imaging.cm import viridis_white_r 

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

cmap = plt.get_cmap('jet')
new_jet_cmap = truncate_colormap(cmap, 0, .5)

def density_slice_pcolormesh(Snap, year, scale, vmin, vmax, cmap='cividis', 
                        saveloc=False, show=False, show_cbar= False, 
                             show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('darkkhaki')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.q['d'][:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
#     ax.plot(Snap.x2[9], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[9], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($\rho$ / [g/cm^3])'), 
                       fontsize=18,)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .3, (r'$\mathbf{\rho}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='black')#, alpha=.5)
    filename = saveloc+'/'+Snap.name+'_0_density_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename


def zvelocity_slice_pcolormesh(Snap, year, scale, vmin, vmax, cmap=viridis_white_r, 
                               saveloc=False, show=False, show_cbar= False, 
                               show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('white')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.q['v1'][:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
#     ax.plot(Snap.x2[9], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[9], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($v_z$ / [km/s])'), 
                       fontsize=18)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .3, (r'$\mathbf{v_z}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='black')#, alpha=.5)
    filename = saveloc+'/'+Snap.name+'_1_zvelocity_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename

        
        
def temp_slice_pcolormesh(Snap, year, scale, vmin, vmax, cmap='hot', 
                        saveloc=False, show=False, show_cbar= False, 
                          show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.temperatures[:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($T$ / [K])'), 
                       fontsize=18)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .3, (r'$\mathbf{T}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    filename = saveloc+'/'+Snap.name+'_2_temp_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename

        
def ionfrac_slice_pcolormesh(Snap, year, scale, vmin, vmax, cmap='viridis', 
                        saveloc=False, show=False, show_cbar= False, 
                             show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.ion_fractions[:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($\chi_\mathrm{H+}$)'), 
                      fontsize=18)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .3, (r'$\mathbf{\chi_{H+}}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    filename = saveloc+'/'+Snap.name+'_3_ionfrac_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename

        
def emis_slice_pcolormesh(Snap, year, scale, vmin, vmax, cmap='magma', nu = 5.3*10**9,
                        saveloc=False, show=False, show_cbar= False, 
                          show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.load_intensity_variables(nu)
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.emission_coefs[:,:,Snap.mid3]))+26, 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($j_{ff,\nu}$ / [mJy cm$^{-1}$)]'),
                      fontsize=18)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .3, (r'$\mathbf{j_{ff,\nu}}$'+'\n'+year), ha='left', va='top', 
                transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)

    filename = saveloc+'/'+Snap.name+'_4_emissivity_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename

# %% [markdown]
# #### Slice Images

# %%
vmin_density, vmax_density = -22.1, -14.7    # 1 Density Slice
vmin_zvelocity, vmax_zvelocity = 0, 3.5      # 2 z-Velocity Slice
vmin_temp, vmax_temp = 0, 7                  # 3 Temperature Slice
vmin_ionfrac, vmax_ionfrac = -10, 0          # 4 Ionization Fraction Slice
vmin_emis, vmax_emis = -20, 0                # 5 Emissivity Slice
vmin_iontemp, vmax_iontemp = 0, 7            # 6 Ionized Gas Temperature Projection
slicescales = np.array([4000,25000])
nu = 5.3*10**9

def slice_images(Snapshot, year_str, savefolder = VICO_loc+'/PaperImages/slice_images', 
                 show_cbar=False, xlabel=False, cbar_pad=.15):
    # density slice
    file0 = density_slice_pcolormesh(Snap=Snapshot, year=year_str, scale = scale, 
                             vmin = vmin_density, vmax=vmax_density, saveloc=savefolder, 
                             show=True, cmap='cividis', show_cbar=show_cbar, 
                             show_xlabels=xlabel, show_ylabels=True,
                             cbar_pad=cbar_pad)

    # velocity_z slice
    file1 = zvelocity_slice_pcolormesh(Snap=Snapshot, year=year_str, scale = scale, 
                               vmin = vmin_zvelocity, vmax=vmax_zvelocity, saveloc=savefolder, 
                               show=True, show_cbar=show_cbar, 
                               show_xlabels=xlabel, show_ylabels=False,
                               cbar_pad=cbar_pad)

    # temperature slice
    file2 = temp_slice_pcolormesh(Snap=Snapshot, year=year_str, scale = scale, 
                          vmin = vmin_temp, vmax=vmax_temp, saveloc=savefolder, 
                          show=True, cmap='hot', show_cbar=show_cbar, 
                          show_xlabels=xlabel, show_ylabels=False,
                          cbar_pad=cbar_pad)

    # ionization fraction slice
    file3 = ionfrac_slice_pcolormesh(Snap=Snapshot, year=year_str, scale = scale, 
                             vmin = vmin_ionfrac, vmax=vmax_ionfrac, saveloc=savefolder, 
                             show=True, cmap='viridis', show_cbar=show_cbar, 
                             show_xlabels=xlabel, show_ylabels=False,
                             cbar_pad=cbar_pad)

    # emissivity slice
    file4 = emis_slice_pcolormesh(Snap=Snapshot, year=year_str, scale = scale, 
                          vmin = vmin_emis, vmax=vmax_emis, saveloc=savefolder, 
                          show=True, cmap='magma', show_cbar=show_cbar, 
                          show_xlabels=xlabel, show_ylabels=False,
                             cbar_pad=cbar_pad)
    
    return file0, file1, file2, file3, file4

# %% [markdown]
# ##### Figure 1: Slice Plot

# %%
# 
for scale in slicescales:
    for s in range(len(Snapshots)):
        print(Years[s])
        if(s < len(Snapshots)-1):
            slice_images(Snapshots[s], Years[s], xlabel=False, 
                         show_cbar=False, cbar_pad=.15)
        else:      
            slice_images(Snapshots[s], Years[s], xlabel=True, 
                         show_cbar=False, cbar_pad=.15)

# %% [markdown]
# ##### PIL Image Methods

# %%
# for PIL    
def make_slices_allimage(imgfiles_arr, allimagename, scale):
    nrows = len(imgfiles_arr)
    ncols = len(imgfiles_arr[0]) # should be 5 for 
    side=300
    header=0
    if(scale==25000):
        leftax = 150
    else:
        leftax=134
    bottomax = 82
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side + bottomax + header))
    cropped_names = np.empty((nrows, ncols), dtype=object)

    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
#             print(width,height)
            if(c==0): # y axis
                new_width=int(side*((width-6.25)/(231-6.25-7.25)))
                left=0
                new_x=0
                right=width-6.25
            else: 
                new_width=side
                left=7.25
                new_x=c*side+(leftax)
                right=width-6.25

            if(r==nrows-1): # x axis
                new_height=int(side*(height-6.75)/(231-6.75-6.75))
                bottom=height
            else: 
                new_height=side
                bottom=height-6.75
            top=7
            new_y = r*side + header

            img = img.crop((left, top, right, bottom))
            img = img.resize((new_width,new_height))
            allimage.paste(img, ((new_x, new_y)))
    display(allimage)
    
    im0 = Image.open(VICO_loc+'/PaperImages/slice_images/cbar_0_density.png')
    im1 = Image.open(VICO_loc+'/PaperImages/slice_images/cbar_1_zvelocity.png')
    im2 = Image.open(VICO_loc+'/PaperImages/slice_images/cbar_2_temp.png')
    im3 = Image.open(VICO_loc+'/PaperImages/slice_images/cbar_3_ionfrac.png')
    im4 = Image.open(VICO_loc+'/PaperImages/slice_images/cbar_4_emissivity.png')
    cbar_ims = np.array([im0, im1, im2, im3, im4])
    cbar_height = 0
    
    for i in range(len(cbar_ims)):
        im = cbar_ims[i]
        im = im.resize((side, int(im.height * side/im.width)))
        if(im.height > cbar_height): cbar_height = im.height
        cbar_ims[i] = im
    imnew = Image.new('RGBA', (allimage.width, allimage.height+cbar_height),
                 color='white')
    imnew.paste(allimage, (0,0))
    for i in range(len(cbar_ims)):
        imnew.paste(cbar_ims[i], (leftax+side*i, allimage.height))
    
    display(imnew)
    imnew.save(allimagename)

# %% [markdown]
# ##### 2.1.1 PIL Figure: 25000 au Slices

# %%
nrows = len(Snapshots)-1
ncols = 5
scale = 25000
slicefiles_25000au = np.empty((nrows, ncols), dtype=object)
r=0
saveloc = VICO_loc+'/PaperImages/slice_images'
for s in range(1,len(Snapshots)):
    print(Years[s])
    if(s < len(Snapshots)-1):
        slice_images(Snapshots[s], Masses[s], savefolder=saveloc,
                     show_cbar=False, cbar_pad=.15, xlabel=False)
    else:      
        slice_images(Snapshots[s], Masses[s], xlabel=True,
                    show_cbar=False, cbar_pad=.3)
    slicefiles_25000au[r,0] = (saveloc+'/'+Snapshots[s].name+
                               '_0_density_'+str(scale)+'AU.png')
    slicefiles_25000au[r,1] = (saveloc+'/'+Snapshots[s].name+
                               '_1_zvelocity_'+str(scale)+'AU.png')
    slicefiles_25000au[r,2] = (saveloc+'/'+Snapshots[s].name+
                               '_2_temp_'+str(scale)+'AU.png')
    slicefiles_25000au[r,3] = (saveloc+'/'+Snapshots[s].name+
                               '_3_ionfrac_'+str(scale)+'AU.png')
    slicefiles_25000au[r,4] = (saveloc+'/'+Snapshots[s].name+
                               '_4_emissivity_'+str(scale)+'AU.png')
    r+=1

# %%
make_slices_allimage(imgfiles_arr = slicefiles_25000au, 
                    allimagename=VICO_loc+'/PaperImages/Slices_25000au.png',
                    scale = 25000)

# %% [markdown]
# ##### 2.1.2 PIL Figure: 4000au Slices

# %%
nrows = len(Snapshots)-1
ncols = 5
scale = 4000
slicefiles_4000au = np.empty((nrows, ncols), dtype=object)
r=0
saveloc = VICO_loc+'/PaperImages/slice_images'
for s in range(1,len(Snapshots)):
    print(Years[s])
    if(s < len(Snapshots)-1):
        slice_images(Snapshots[s], Masses[s], savefolder=saveloc,
                     show_cbar=False, cbar_pad=.15, xlabel=False)
    else:      
        slice_images(Snapshots[s], Masses[s], xlabel=True,
                    show_cbar=False, cbar_pad=.3)
    slicefiles_4000au[r,0] = (saveloc+'/'+Snapshots[s].name+
                               '_0_density_'+str(scale)+'AU.png')
    slicefiles_4000au[r,1] = (saveloc+'/'+Snapshots[s].name+
                               '_1_zvelocity_'+str(scale)+'AU.png')
    slicefiles_4000au[r,2] = (saveloc+'/'+Snapshots[s].name+
                               '_2_temp_'+str(scale)+'AU.png')
    slicefiles_4000au[r,3] = (saveloc+'/'+Snapshots[s].name+
                               '_3_ionfrac_'+str(scale)+'AU.png')
    slicefiles_4000au[r,4] = (saveloc+'/'+Snapshots[s].name+
                               '_4_emissivity_'+str(scale)+'AU.png')
    r+=1

# %%
make_slices_allimage(imgfiles_arr = slicefiles_4000au, 
                    allimagename=VICO_loc+'/PaperImages/Slices_4000au.png',
                    scale = 4000)

# %% [markdown]
# ###### *colorbars*

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/slice_images'
scale = 25000
density_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                         vmin=vmin_density, vmax=vmax_density, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_0_density_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = VICO_loc+'/PaperImages/slice_images/cbar_0_density.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/slice_images'
scale = 25000
zvelocity_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                         vmin=vmin_zvelocity, vmax=vmax_zvelocity, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_1_zvelocity_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = VICO_loc+'/PaperImages/slice_images/cbar_1_zvelocity.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/slice_images'
scale = 25000
temp_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                         vmin=vmin_temp, vmax=vmax_temp, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_2_temp_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = VICO_loc+'/PaperImages/slice_images/cbar_2_temp.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/slice_images'
scale = 25000
ionfrac_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                         vmin=vmin_ionfrac, vmax=vmax_ionfrac, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_3_ionfrac_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = VICO_loc+'/PaperImages/slice_images/cbar_3_ionfrac.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/slice_images'
scale = 25000
emis_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                             vmin=vmin_emis, vmax=vmax_emis, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_4_emissivity_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = VICO_loc+'/PaperImages/slice_images/cbar_4_emissivity.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %% [markdown]
# ###### *finding crop and resize parameters*
# Use the following to calculate crop and resize parameters

# %%
img = Image.open(imgfiles_arr[0,0])
print(img.size)

# %%
#using no axes
side=300
new = Image.new("RGBA", (1000,1000))

img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/slice_images/Snap054_n_1_zvelocity_25000AU.png")
print(img1.size)
width, height = img1.size
left = 7.25
top = 6.75
right = 231-6.25 # width = 231 without axes
bottom = 231-6.75 # height = 231 without axes
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((side,side))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
#using y axes
side=300
new = Image.new("RGBA", (1000,1000))

img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/ionfrac_images/Snap054_n_ionfrac_mass_v1kms_4000AU.png")
print(img1.size)
width, height = img1.size
left = 0
top = 6.75
right = 321-6.25 # width = 231 without axes
bottom = 231-6.75 # height = 231 without axes
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((int(side*((321-6.25)/(231-6.25-7.25))),side))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
#using x axes
new = Image.new("RGBA", (1000,1000))
side=300
img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/ionfrac_images/Snap094_n_ionfrac_emis_v100kms_4000AU.png")
print(img1.size)
width, height = img1.size
left = 7.25
top = 6.75
right = width-6.25
bottom = height
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((side,int(side*(289-6.75)/(231-6.75-6.75))))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
test0=plt.imread("new.png")
plt.imshow(test0)
plt.axis('off')
plt.margins(x=0, y=0)

# %%
test1=plt.imread("img1.png")
plt.imshow(test1)
plt.axis('off')
plt.margins(x=0, y=0)

# %%
test2=plt.imread("img2.png")
plt.imshow(test2)
plt.axis('on')
plt.margins(x=0, y=0)

# %% [markdown]
# ###### scratch

# %%
def ionfrac_slice_pcolormesh_temp(Snap, year, scale, vmin, vmax, cmap='viridis', 
                        saveloc=False, show=False, show_cbar= False, 
                             show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (6,6))
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_title('Shock-Ionization', fontsize=20)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.ion_fractions[:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=20)
        ax.tick_params(axis='x', labelsize=16)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=20)
        ax.tick_params(axis='y', labelsize=16)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'vertical', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($\chi_\mathrm{H+}$)'), 
                      fontsize=18)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .3, (r'$\mathbf{\chi_{H+}}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    
    fig.tight_layout()

    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_3_ionfrac_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename

ionfrac_slice_pcolormesh_temp(Snap=Snap068_n, year=r'16$M_\odot$', scale = 25000, 
                             vmin = vmin_ionfrac, vmax=vmax_ionfrac, saveloc=False, 
                             show=True, cmap='viridis', show_cbar=True, 
                             show_xlabels=True, show_ylabels=True,
                             cbar_pad=.02)

# %%
density_slice_pcolormesh(Snapshots[s], '', 
                           scale=1000, 
                        vmin=vmin_density, 
                           vmax=vmax_density,
                              saveloc=False,
                              show_xlabels = True, 
                              show_ylabels = True, 
                              show_cbar=False, cbar_pad=.15)

# %% [markdown]
# ## 2.2 Ionization Fraction Maps

# %% [markdown]
# Calculating Ionization Fraction Arrays for 2D Maps Methods

# %%
# Calculating Ionization Fraction Arrays for 2D Maps
v_mins = np.array([1,10,100])
def mass_ionfrac_array(Snap, v_mins):
    Snap.ionfrac_mass = np.zeros((len(v_mins),len(Snap.x1), len(Snap.x2)))
    for v in range(len(v_mins)):
        for i in range(len(Snap.x1)):
            for j in range(len(Snap.x2)):
                numer = 0
                denom = 0
                for k in range(len(Snap.x3)):
                    if(Snap.q['v1'][i,j,k] >= v_mins[v]):
                        numer += Snap.ion_fractions[i,j,k] * Snap.q['d'][i,j,k] * Snap.del3[k]
                        denom += Snap.q['d'][i,j,k] *  Snap.del3[k]
                if(denom>0): Snap.ionfrac_mass[v,i,j] = numer/denom
                else: Snap.ionfrac_mass[v,i,j] = 0                

def mass_ionfrac_array_const(Snap, v_mins, const=.01):
    ionfrac_mass = np.zeros((len(v_mins),len(Snap.x1), len(Snap.x2)))
    for v in range(len(v_mins)):
        for i in range(len(Snap.x1)):
            for j in range(len(Snap.x2)):
                numer = 0
                denom = 0
                for k in range(len(Snap.x3)):
                    if(Snap.q['v1'][i,j,k] >= v_mins[v]):
                        if(const): scale_factor = const
                        else: 
                            scale_factor = Snap.cooling_times[i,j,k]/Snap.flow_times[i,j,k]
                            if(scale_factor>1): scale_factor=1 # can't be more than 1
                        numer += (Snap.ion_fractions[i,j,k] * Snap.q['d'][i,j,k] 
                                  * Snap.del3[k] * scale_factor)
                        denom += Snap.q['d'][i,j,k] *  Snap.del3[k]
                if(denom>0): ionfrac_mass[v,i,j] = numer/denom
                else: ionfrac_mass[v,i,j] = 0  
    if(const): Snap.ionfrac_mass_const = ionfrac_mass
    else: Snap.ionfrac_mass_ratio = ionfrac_mass
    
# Calculating Ionization Fraction Arrays
def vol_ionfrac_array(Snap, v_mins):
    Snap.ionfrac_vol = np.zeros((len(v_mins),len(Snap.x1), len(Snap.x2)))
    for v in range(len(v_mins)):
        for i in range(len(Snap.x1)):
            for j in range(len(Snap.x2)):
                numer = 0
                denom = 0
                for k in range(len(Snap.x3)):
                    if(Snap.q['v1'][i,j,k] >= v_mins[v]):
                        numer += Snap.ion_fractions[i,j,k] * Snap.del3[k]
                        denom += Snap.del3[k]
                if(denom>0): Snap.ionfrac_vol[v,i,j] = numer/denom
                else: Snap.ionfrac_vol[v,i,j] = 0                

# Calculating Ionization Fraction Arrays
def vol_ionfrac_array_const(Snap, v_mins, const=.01):
    ionfrac_vol = np.zeros((len(v_mins),len(Snap.x1), len(Snap.x2)))
    for v in range(len(v_mins)):
        for i in range(len(Snap.x1)):
            for j in range(len(Snap.x2)):
                numer = 0
                denom = 0
                for k in range(len(Snap.x3)):
                    if(Snap.q['v1'][i,j,k] >= v_mins[v]):
                        if(const): scale_factor = const
                        else: 
                            scale_factor = Snap.cooling_times[i,j,k]/Snap.flow_times[i,j,k]
                            if(scale_factor>1): scale_factor=1 # can't be more than 1
                        numer += Snap.ion_fractions[i,j,k] * Snap.del3[k] * scale_factor
                        denom += Snap.del3[k]
                if(denom>0): ionfrac_vol[v,i,j] = numer/denom
                else: ionfrac_vol[v,i,j] = 0  
    if(const): Snap.ionfrac_vol_const = ionfrac_vol
    else: Snap.ionfrac_vol_ratio = ionfrac_vol

    
# Calculating Ionization Fraction Arrays
def emis_ionfrac_array(Snap, v_mins, f):
    Snap.load_intensity_variables(frequencies[f])
    Snap.ionfrac_emis = np.zeros((len(frequencies),len(v_mins),len(Snap.x1), len(Snap.x2)))
    for v in range(len(v_mins)):
        for i in range(len(Snap.x1)):
            for j in range(len(Snap.x2)):
                numer = 0
                denom = 0
                for k in range(len(Snap.x3)):
                    if(Snap.q['v1'][i,j,k] >= v_mins[v]):
                        numer += Snap.ion_fractions[i,j,k] * Snap.emission_coefs[i,j,k] * Snap.del3[k]
                        denom += Snap.emission_coefs[i,j,k] * Snap.del3[k]
                if(denom>0): Snap.ionfrac_emis[f,v,i,j] = numer/denom
                else: Snap.ionfrac_emis[f,v,i,j] = 0   

def emis_ionfrac_array_const(Snap, v_mins, f, const=.01):
    Snap.load_intensity_variables(frequencies[f])
    ionfrac_emis = np.zeros((len(frequencies),len(v_mins),len(Snap.x1), len(Snap.x2)))
    for v in range(len(v_mins)):
        for i in range(len(Snap.x1)):
            for j in range(len(Snap.x2)):
                numer = 0
                denom = 0
                for k in range(len(Snap.x3)):
                    if(Snap.q['v1'][i,j,k] >= v_mins[v]):
                        if(const): scale_factor = const
                        else: 
                            scale_factor = Snap.cooling_times[i,j,k]/Snap.flow_times[i,j,k]
                            if(scale_factor>1): scale_factor=1 # can't be more than 1
                        numer += Snap.ion_fractions[i,j,k] * Snap.emission_coefs[i,j,k] * Snap.del3[k] * scale_factor
                        denom += Snap.emission_coefs[i,j,k] * Snap.del3[k] 
                if(denom>0): ionfrac_emis[f,v,i,j] = numer/denom
                else: ionfrac_emis[f,v,i,j] = 0 
    if(const): Snap.ionfrac_emis_const = ionfrac_emis
    else: Snap.ionfrac_emis_ratio = ionfrac_emis

                        
                        
def save_average_ionfrac_array(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_average_ionfrac_arrays.npz'), ionfrac_mass = Snap.ionfrac_mass,
            ionfrac_vol = Snap.ionfrac_vol, ionfrac_emis = Snap.ionfrac_emis)
def load_average_ionfrac_array(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    loaded_average_ionfracs = np.load((data_path+Snap.name+'_average_ionfrac_arrays.npz'))
    Snap.ionfrac_mass = loaded_average_ionfracs['ionfrac_mass']
    Snap.ionfrac_vol =  loaded_average_ionfracs['ionfrac_vol']
    Snap.ionfrac_emis = loaded_average_ionfracs['ionfrac_emis']
    print(Snap.name + ' ionfrac arrays loaded')
    
                        
def save_average_ionfrac_array_const(Snap, const):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    if(const):
        np.savez((data_path+Snap.name+'_average_ionfrac_arrays_const'+str(const)+'.npz'), 
                 ionfrac_mass = Snap.ionfrac_mass_const,
                 ionfrac_vol = Snap.ionfrac_vol_const, 
                 ionfrac_emis = Snap.ionfrac_emis_const)
    else:
        np.savez((data_path+Snap.name+'_average_ionfrac_arrays_const'+str(const)+'.npz'), 
                 ionfrac_mass = Snap.ionfrac_mass_ratio,
                 ionfrac_vol = Snap.ionfrac_vol_ratio, 
                 ionfrac_emis = Snap.ionfrac_emis_ratio)
        
def load_average_ionfrac_array_const(Snap, const):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    loaded_average_ionfracs = np.load((data_path+Snap.name+'_average_ionfrac_arrays_const'+str(const)+'.npz'))
    if(const):
        Snap.ionfrac_mass_const = loaded_average_ionfracs['ionfrac_mass']
        Snap.ionfrac_vol_const =  loaded_average_ionfracs['ionfrac_vol']
        Snap.ionfrac_emis_const = loaded_average_ionfracs['ionfrac_emis']
        print(Snap.name + ' ionfrac_const arrays loaded')
    else:
        Snap.ionfrac_mass_ratio = loaded_average_ionfracs['ionfrac_mass']
        Snap.ionfrac_vol_ratio =  loaded_average_ionfracs['ionfrac_vol']
        Snap.ionfrac_emis_ratio = loaded_average_ionfracs['ionfrac_emis']
        print(Snap.name + ' ionfrac_ratio arrays loaded')

# %%
print(np.max(Snap054_n.ionfrac_emis - Snap054_n.ionfrac_emis_const))

# %% [markdown]
# ##### *calculate ionfrac arrays*

# %%
for s in range(len(Snapshots)):
    print(Snapshots[s].name+' running')
    mass_ionfrac_array(Snapshots[s], v_mins)
    vol_ionfrac_array(Snapshots[s], v_mins)
    emis_ionfrac_array(Snapshots[s], v_mins, f=5) #5.3GHz
    save_average_ionfrac_array(Snapshots[s])

# %%
const = .01
for s in range(len(Snapshots)):
    print(Snapshots[s].name+' running')
    mass_ionfrac_array_const(Snapshots[s], v_mins, const=const)
    vol_ionfrac_array_const(Snapshots[s], v_mins, const=const)
    emis_ionfrac_array_const(Snapshots[s], v_mins, f=5, const=const) #5.3GHz
    save_average_ionfrac_array_const(Snapshots[s], const=const)

# %%
const = False
for s in range(len(Snapshots)):
    print(Snapshots[s].name+' running')
#     mass_ionfrac_array_const(Snapshots[s], v_mins, const=const)
#     vol_ionfrac_array_const(Snapshots[s], v_mins, const=const)
    emis_ionfrac_array_const(Snapshots[s], v_mins, f=5, const=const) #5.3GHz
#     save_average_ionfrac_array_const(Snapshots[s], const=const)

# %% [markdown]
# ##### *load ionfrac arrays*

# %%
for s in range(0,len(Snapshots)):
    load_average_ionfrac_array(Snapshots[s])
    # load_average_ionfrac_array_const(Snapshots[s], const=.01)
    load_average_ionfrac_array_const(Snapshots[s], const=False)
    
# Maximum Velocities for Contours
def max_velocity_proj_array(Snap, v_min):
    Snap.maxv1 = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            Snap.maxv1[i,j] = np.max(Snap.q['v1'][i,j,:])
for s in range(len(Snapshots)): 
    for v in v_mins:
        max_velocity_proj_array(Snapshots[s], v)

# %% [markdown]
# ##### *ionization fraction map methods*

# %%
# Ionization Fraction Methods
import matplotlib.colors as colors
saveloc = VICO_loc+'/PaperImages/ionfrac_images'

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

cmap = plt.get_cmap('jet')
new_cmap = truncate_colormap(cmap, 0.1, 1)




def mass_ionfrac_pcolormesh(Snap, year, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
            
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
#     ax.plot(Snap.x2[9], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[9], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            fig.colorbar(cont, label = r'log10($\langle\chi_\mathrm{H+}\rangle$ )', 
                 orientation = 'vertical', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
        else:
            fig.colorbar(cont, label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'), 
                     orientation = 'horizontal', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
    
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, mass}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
        

        
def mass_ionfrac_const_pcolormesh(Snap, year, const, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
            
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    if(const):
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass_const[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    else: 
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass_ratio[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            fig.colorbar(cont, label = r'log10($\langle\chi_\mathrm{H+}\rangle$ )', 
                 orientation = 'vertical', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
        else:
            fig.colorbar(cont, label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'), 
                     orientation = 'horizontal', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
    
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, mass}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_const_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_ratio_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
        
        
def vol_ionfrac_pcolormesh(Snap, year, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show=False, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
#     print(v)
    v_min=v_mins[v]

    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_vol[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            fig.colorbar(cont, label = r'log10($\langle\chi_\mathrm{H+}\rangle$ )', 
                 orientation = 'vertical', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
        else:
            fig.colorbar(cont, label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'), 
                     orientation = 'horizontal', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
      
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, vol}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_vol_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename

def vol_ionfrac_const_pcolormesh(Snap, year, const, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show=False, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
#     print(v)
    v_min=v_mins[v]

    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    if(const):
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_vol_const[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    else:
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_vol_ratio[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            fig.colorbar(cont, label = r'log10($\langle\chi_\mathrm{H+}\rangle$ )', 
                 orientation = 'vertical', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
        else:
            fig.colorbar(cont, label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'), 
                     orientation = 'horizontal', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
      
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, vol}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_vol_const_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_ionfrac_vol_ratio_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
    
        
def emis_ionfrac_pcolormesh(Snap, year, scale, f, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show=False, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False, 
                           with_delta = True):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
    nu=frequencies[f]
           
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_emis[f,v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
#     ax.plot(Snap.x2[9], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[9], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')

    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            fig.colorbar(cont, label = r'log10($\langle\chi_\mathrm{H+}\rangle$ )', 
                 orientation = 'vertical', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
        else:
            fig.colorbar(cont, label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'), 
                     orientation = 'horizontal', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)   
    
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, emis}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_emis_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
        
def emis_ionfrac_const_pcolormesh(Snap, year, const, scale, f, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show=False, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False, 
                           with_delta = True):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
    nu=frequencies[f]
           
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    if(const):
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_emis_const[f,v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    else:
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_emis_ratio[f,v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            fig.colorbar(cont, label = r'log10($\langle\chi_\mathrm{H+}\rangle$ )', 
                 orientation = 'vertical', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)
        else:
            fig.colorbar(cont, label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'), 
                     orientation = 'horizontal', fraction=0.038, pad=cbar_pad, extend='min').ax.tick_params(rotation=45)   
    
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, emis}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 15, color='white', weight='bold')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_emis_const_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_ionfrac_emis_ratio_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# #### PIL Image methods

# %%
def display_image(name):
#     temp_img=plt.imread(name)
#     plt.imshow(temp_img)
#     plt.axis('off')
#     plt.margins(x=0, y=0)
    pil_img = DisplayImage(filename=name)
    display(pil_img)
    
def img_concat_h(im1, im2):
    dst = Image.new('RGBA', (im1.width + im2.width, im1.height),
                   color='white')
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, int(im2.height/2)))
    return dst

def img_concat_v(im1, im2):
    dst = Image.new('RGBA', (im1.width, im1.height + im2.height),
                   color='white')
    dst.paste(im1, (0, 0))
    dst.paste(im2, (int(im1.width/2 - im2.width/2), im1.height))
    return dst



def make_ionfracs_allimage(imgfiles_arr, allimagename, scale):
    nrows = len(imgfiles_arr)
    ncols = len(imgfiles_arr[0])
    side=300
    header=150
    if(scale==25000):
        leftax = 150
    else:
        leftax=134
    bottomax = 82
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side + bottomax + header))
    cropped_names = np.empty((nrows, ncols), dtype=object)



    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
#             print(width,height)
            if(c==0): # y axis
                new_width=int(side*((width-6.25)/(231-6.25-7.25)))
                left=0
                new_x=0
                right=width-6.25
            else: 
                new_width=side
                left=7.25
                new_x=c*side+(leftax)
                right=width-6.25

            if(r==nrows-1): # x axis
                new_height=int(side*(height-6.75)/(231-6.75-6.75))
                bottom=height
            else: 
                new_height=side
                bottom=height-6.75
            top=7
            new_y = r*side + header

            img = img.crop((left, top, right, bottom))
            img = img.resize((new_width,new_height))
            allimage.paste(img, ((new_x, new_y)))
            img.save('./IonFracCroppedImages/25000_noratio_r%d_c%d.png' % (r,c))
            cropped_names[r][c] = str('25000_noratio_r%d_c%d.png' % (r,c))
#             print(img.size)

    # add header
    I1 = ImageDraw.Draw(allimage)
    myFont = ImageFont.truetype(VICO_loc+'/Data/fonts/arial1.ttf', 65)
    smallFont = ImageFont.truetype(VICO_loc+'/Data/fonts/arial1.ttf', 55)
    I1.text((350,0), " Mass-Weighted", font=myFont, fill=(0,0,0))
    I1.text((1200,0), " Volume-Weighted", font=myFont, fill=(0,0,0))
    I1.text((2100,0), " Emission-Weighted", font=myFont, fill=(0,0,0))

    I1.text((leftax+60,header-60), "1 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+40+side,header-60), "10 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+30+2*side,header-60), "100 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+60+3*side,header-60), "1 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+40+4*side,header-60), "10 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+30+5*side,header-60), "100 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+60+6*side,header-60), "1 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+40+7*side,header-60), "10 km/s", font=smallFont, fill=(26,38,134))
    I1.text((leftax+30+8*side,header-60), "100 km/s", font=smallFont, fill=(26,38,134))

    # add section breaks
    line1 = [(leftax+3*side,0), (leftax+3*side, header)]
    line2 = [(leftax+6*side,0), (leftax+6*side, header)]
    I1.line(line1,fill=(0,0,0),width=5)
    I1.line(line2,fill=(0,0,0),width=5)

    display(allimage)

    allimage.save(allimagename)

# %% [markdown]
# #### 2.2.1 PIL Figure: 25000au no ratio

# %% [markdown]
# make and save all images for collage

# %%
nrows = len(Snapshots) - 1
ncols = 9
scale = 25000
imgfiles_arr_25000au_noratio = np.empty((nrows, ncols), dtype=object)
r=0
for s in range(1,len(Snapshots)):
    c=0
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        if(v==0): show_ylabels = True
        else: show_ylabels = False
        filename = mass_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_25000au_noratio[r,c] = filename
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        filename = vol_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, vmin=-3, vmax=0, v=v,
                              show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_25000au_noratio[r,c] = filename
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        filename = emis_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, f=5, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_25000au_noratio[r,c] = filename
        c+=1
    r+=1

# %%
make_ionfracs_allimage(imgfiles_arr=imgfiles_arr_25000au_noratio, 
                       allimagename='PaperImages/ionfrac_images/AverageIonFracMaps_25000au_noratio.png',
                      scale=25000)

# %%
im1 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/AverageIonFracMaps_25000au_noratio.png')
im2 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/cbar_horizontal.png')
im2 = im2.resize((im2.width*3, im2.height*3))
im3 = img_concat_v(im1, im2)
im3name = VICO_loc+'/PaperImages/ChiMaps_25000au_noratio_hcbar.png'
im3.save(im3name)
display(im3)

# %% [markdown]
# #### 2.2.2 PIL Figure: 4000au no ratio

# %% [markdown]
# make and save all images for collage

# %%
nrows = len(Snapshots) - 1
ncols = 9
scale = 4000
imgfiles_arr_4000au_noratio = np.empty((nrows, ncols), dtype=object)
r=0
for s in range(1,len(Snapshots)):
    c=0
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        if(v==0): show_ylabels = True
        else: show_ylabels = False
        filename = mass_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_4000au_noratio[r,c] = filename
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        filename = vol_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, vmin=-3, vmax=0, v=v,
                              show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_4000au_noratio[r,c] = filename
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        filename = emis_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, f=5, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_4000au_noratio[r,c] = filename
        c+=1
    r+=1

# %%
make_ionfracs_allimage(imgfiles_arr=imgfiles_arr_4000au_noratio, 
                       allimagename='PaperImages/ionfrac_images/AverageIonFracMaps_4000au_noratio.png',
                      scale=4000)

# %%
im1 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/AverageIonFracMaps_4000au_noratio.png')
im2 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/cbar_horizontal.png')
im2 = im2.resize((im2.width*3, im2.height*3))
im3 = img_concat_v(im1, im2)
im3name = VICO_loc+'/PaperImages/ChiMaps_4000au_noratio_hcbar.png'
im3.save(im3name)
display(im3)

# %% [markdown]
# #### 2.2.3 PIL Figure: 25000au with ratio

# %% [markdown]
# make and save all images for collage

# %%
nrows = len(Snapshots) - 1
ncols = 9
scale = 25000
const=False
imgfiles_arr_25000au_ratio = np.empty((nrows, ncols), dtype=object)
r=0
for s in range(1,len(Snapshots)):
    c=0
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        if(v==0): show_ylabels = True
        else: show_ylabels = False
        filename = mass_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_25000au_ratio[r,c] = filename
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        filename = vol_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, vmin=-3, vmax=0, v=v,
                              show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_25000au_ratio[r,c] = filename
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        filename = emis_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, f=5, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_25000au_ratio[r,c] = filename
        c+=1
    r+=1

# %%
make_ionfracs_allimage(imgfiles_arr=imgfiles_arr_25000au_ratio, 
                       allimagename='PaperImages/ionfrac_images/AverageIonFracMaps_25000au_ratio.png',
                      scale=25000)

# %%
im1 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/AverageIonFracMaps_25000au_ratio.png')
im2 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/cbar_horizontal.png')
im2 = im2.resize((im2.width*3, im2.height*3))
im3 = img_concat_v(im1, im2)
im3name = VICO_loc+'/PaperImages/ChiMaps_25000au_ratio_hcbar.png'
im3.save(im3name)
display(im3)

# %% [markdown]
# #### 2.2.4 PIL Figure: 4000au no ratio

# %% [markdown]
# make and save all images for collage

# %%
nrows = len(Snapshots) - 1
ncols = 9
scale = 4000
const=False
imgfiles_arr_4000au_ratio = np.empty((nrows, ncols), dtype=object)
r=0
for s in range(1,len(Snapshots)):
    c=0
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        if(v==0): show_ylabels = True
        else: show_ylabels = False
        mass_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_4000au_ratio[r,c] = (saveloc+'/'+Snapshots[s].name+'_ionfrac_mass_ratio_v'
                   +str(v_mins[v])+'kms_'+str(scale)+'AU.png')
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        vol_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, vmin=-3, vmax=0, v=v,
                              show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_4000au_ratio[r,c] = (saveloc+'/'+Snapshots[s].name+'_ionfrac_vol_ratio_v'
                   +str(v_mins[v])+'kms_'+str(scale)+'AU.png')
        c+=1
    for v in range(len(v_mins)):
        if(s==len(Snapshots)-1): show_xlabels = True
        else: show_xlabels = False
        show_ylabels = False
        emis_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, f=5, vmin=-3, vmax=0, v=v,
                               show_xlabels=show_xlabels, show_ylabels=show_ylabels)
        imgfiles_arr_4000au_ratio[r,c] = (saveloc+'/'+Snapshots[s].name+'_ionfrac_emis_ratio_v'
                   +str(v_mins[v])+'kms_'+str(scale)+'AU.png')
        c+=1
    r+=1

# %%
make_ionfracs_allimage(imgfiles_arr=imgfiles_arr_4000au_ratio, 
                       allimagename='PaperImages/ionfrac_images/AverageIonFracMaps_4000au_ratio.png',
                      scale=4000)

# %%
im1 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/AverageIonFracMaps_4000au_ratio.png')
im2 = Image.open(VICO_loc+'/PaperImages/ionfrac_images/cbar_horizontal.png')
im2 = im2.resize((im2.width*3, im2.height*3))
im3 = img_concat_v(im1, im2)
im3name = VICO_loc+'/PaperImages/ChiMaps_4000au_ratio_hcbar.png'
im3.save(im3name)
display(im3)

# %% [markdown]
# ###### *colorbars*

# %%
# use Snap004_n for this
s=0
v=2
saveloc = VICO_loc+'/PaperImages/ionfrac_images'
mass_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, vmin=-3, vmax=0, v=v,
                               show_xlabels=False, show_ylabels=False, 
                             show_cbar=True, vertical_cbar=True)
cbar_v_img = Image.open((saveloc+'/'+Snapshots[s].name+'_ionfrac_mass_v'
                   +str(v_mins[v])+'kms_'+str(scale)+'AU.png'))
print(cbar_v_img.size)
width, height = cbar_v_img.size
left = 220
right = width
top = 0
bottom = height
cbar_v_img = cbar_v_img.crop((left, top, right, bottom))
print(cbar_v_img.size)
cbar_v_filename = VICO_loc+'/PaperImages/ionfrac_images/cbar_vertical.png'
cbar_v_img.save(cbar_v_filename)
display_image(cbar_v_filename)

# %%
# use Snap004_n for this
s=0
v=2
saveloc = VICO_loc+'/PaperImages/ionfrac_images'

vol_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, vmin=-3, vmax=0, v=v,
                               show_xlabels=False, show_ylabels=False, 
                             show_cbar=True, vertical_cbar=False)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_ionfrac_vol_v'
                   +str(v_mins[v])+'kms_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 210
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = VICO_loc+'/PaperImages/ionfrac_images/cbar_horizontal.png'
cbar_h_img.save(cbar_h_filename)
display_image(cbar_h_filename)

# %% [markdown]
# ###### *finding crop and resize parameters*
# Use the following to calculate crop and resize parameters

# %%
img = Image.open(imgfiles_arr[0,0])
print(img.size)

# %%
#using no axes
side=300
new = Image.new("RGBA", (1000,1000))

img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/ionfrac_images/Snap054_n_ionfrac_emis_v100kms_4000AU.png")
print(img1.size)
width, height = img1.size
left = 7.25
top = 6.75
right = 231-6.25 # width = 231 without axes
bottom = 231-6.75 # height = 231 without axes
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((side,side))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
#using y axes
side=300
new = Image.new("RGBA", (1000,1000))

img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/ionfrac_images/Snap054_n_ionfrac_mass_v1kms_4000AU.png")
print(img1.size)
width, height = img1.size
left = 0
top = 6.75
right = 321-6.25 # width = 231 without axes
bottom = 231-6.75 # height = 231 without axes
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((int(side*((321-6.25)/(231-6.25-7.25))),side))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
#using x axes
new = Image.new("RGBA", (1000,1000))
side=300
img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/ionfrac_images/Snap094_n_ionfrac_emis_v100kms_4000AU.png")
print(img1.size)
width, height = img1.size
left = 7.25
top = 6.75
right = width-6.25
bottom = height
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((side,int(side*(289-6.75)/(231-6.75-6.75))))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
test0=plt.imread("new.png")
plt.imshow(test0)
plt.axis('off')
plt.margins(x=0, y=0)

# %%
test1=plt.imread("img1.png")
plt.imshow(test1)
plt.axis('off')
plt.margins(x=0, y=0)

# %%
test2=plt.imread("img2.png")
plt.imshow(test2)
plt.axis('on')
plt.margins(x=0, y=0)

# %% [markdown]
# ##### Figure 2: All ionization fraction methods, 4000AU and 25000 AU, all velocities

# %%
slicescales = np.array([4000, 25000])

vmin_ionfrac, vmax_ionfrac = -3, 0       
f=5
v_mins = np.array([1, 10, 100])

for s in range(1,len(Snapshots)):
    load_average_ionfrac_array(Snapshots[s])

for scale in slicescales: #scales
    for s in range(1,len(Snapshots)): #snapshots
        ylabels = False
        if(s==len(Snapshots)-1): xlabels = True
        else: xlabels = False
        for v in range(len(v_mins)):
            if(v==0): ylabels_mass = True
            else: ylabels_mass = False
            mass_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels_mass,
                                    show_contours = True, show_legend = False, show_cbar = False)
        for v in range(len(v_mins)):
            vol_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = False, show_cbar = False)
        for v in range(len(v_mins)):
            emis_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, f = f, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = False, show_cbar = False,
                                    with_delta=True)
#         for v in v_mins:
#             emis_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, f=f , v_min = v,
#                                     vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
#                                     show_xlabels = xlabels, show_ylabels = ylabels,
#                                     show_contours = True, show_legend = False, show_cbar = False,
#                                     with_delta=False)

    mass_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = True, show_cbar = True)

# %% [markdown]
# *For const=.01*

# %%
slicescales = np.array([4000, 25000])

vmin_ionfrac, vmax_ionfrac = -3, 0       
f=5
v_mins = np.array([1, 10, 100])
const = .01

for s in range(1,len(Snapshots)):
    load_average_ionfrac_array(Snapshots[s])

for scale in slicescales: #scales
    for s in range(1,len(Snapshots)): #snapshots
        ylabels = False
        if(s==len(Snapshots)-1): xlabels = True
        else: xlabels = False
        for v in range(len(v_mins)):
            if(v==0): ylabels_mass = True
            else: ylabels_mass = False
            mass_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels_mass,
                                    show_contours = True, show_legend = False, show_cbar = False)
        for v in range(len(v_mins)):
            vol_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = False, show_cbar = False)
        for v in range(len(v_mins)):
            emis_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, f = f, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = False, show_cbar = False,
                                    with_delta=True)
#         for v in v_mins:
#             emis_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, f=f , v_min = v,
#                                     vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
#                                     show_xlabels = xlabels, show_ylabels = ylabels,
#                                     show_contours = True, show_legend = False, show_cbar = False,
#                                     with_delta=False)

    mass_ionfrac_const_pcolormesh(Snapshots[s], Years[s], scale, const, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = True, show_cbar = True)

# %% [markdown]
# *for const=False (ratio)*

# %%
slicescales = np.array([4000, 25000])

vmin_ionfrac, vmax_ionfrac = -3, 0       
f=5
v_mins = np.array([1, 10, 100])
const = False

for s in range(1,len(Snapshots)):
    load_average_ionfrac_array(Snapshots[s])

for scale in slicescales: #scales
    for s in range(1,len(Snapshots)): #snapshots
        ylabels = False
        if(s==len(Snapshots)-1): xlabels = True
        else: xlabels = False
        for v in range(len(v_mins)):
            if(v==0): ylabels_mass = True
            else: ylabels_mass = False
            mass_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels_mass,
                                    show_contours = True, show_legend = False, show_cbar = False)
        for v in range(len(v_mins)):
            vol_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = False, show_cbar = False)
        for v in range(len(v_mins)):
            emis_ionfrac_const_pcolormesh(Snapshots[s], Years[s], const, scale, f = f, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = False, show_cbar = False,
                                    with_delta=True)
#         for v in v_mins:
#             emis_ionfrac_pcolormesh(Snapshots[s], Years[s], scale, f=f , v_min = v,
#                                     vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
#                                     show_xlabels = xlabels, show_ylabels = ylabels,
#                                     show_contours = True, show_legend = False, show_cbar = False,
#                                     with_delta=False)

    mass_ionfrac_const_pcolormesh(Snapshots[s], Years[s], scale, const, v = v,
                                    vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                    show_xlabels = xlabels, show_ylabels = ylabels,
                                    show_contours = True, show_legend = True, show_cbar = True)

# %% [markdown]
# ### 2.3.1 3d Ionfrac Methods for Table
#
# $$ n_\mathrm{H+} = N(\mathrm{H+})/V = (\sum \chi_\mathrm{H+} \rho / m_\mathrm{H} * V)/(\sum V) = N(\mathrm{H+})/V = (\sum_k \chi_\mathrm{H+} \rho / m_\mathrm{H} * \Delta y_k)/(\sum \Delta y_k) $$
#
# $$ \langle \chi_\mathrm{mass} \rangle = \frac{\sum_{i,j,k} \chi_\mathrm{H+} \Delta z \Delta x \Delta y \rho}{\sum_{i,j,k} \Delta z \Delta x \Delta y \rho} $$
#
# $$ \langle \chi_\mathrm{vol} \rangle = \frac{\sum_{i,j,k, v>v_t} \chi_\mathrm{H+} \Delta z \Delta x \Delta y}{\sum_{i,j,k, v>v_t} \Delta z \Delta x \Delta y} $$
#
# $$ \langle \chi_\mathrm{emis} \rangle = \frac{\sum_{i,j,k, v>v_t} \chi_\mathrm{H+} j_\nu \Delta y}{\sum_{i,j,k, v>v_t} j_\nu \Delta y} $$

# %%
def mass_avg_3d_ionfrac(Snap, v_cutoff, scale):
    numer = 0
    denom = 0
    for i in range(len(Snap.x1)):
        if((Snap.x1[i]) <= scale):
            for j in range(len(Snap.x2)):
                if(np.abs(Snap.x2[j] <= scale/2)):
                    for k in range(len(Snap.x3)):
                        if(Snap.q['v1'][i,j,k]>=v_cutoff):
                            numer += (Snap.ion_fractions[i,j,k] * Snap.q['d'][i,j,k] * 
                                      Snap.del1[i] * Snap.del2[j] * Snap.del3[k])
                            denom += (Snap.q['d'][i,j,k] * 
                                      Snap.del1[i] * Snap.del2[j] * Snap.del3[k])
    if(denom==0): return 0
    return numer/denom

def vol_av_cutoffg_3d_ionfrac(Snap, v, scale):
    numer = 0
    denom = 0
    for i in range(len(Snap.x1)):
        if((Snap.x1[i]) <= scale):
            for j in range(len(Snap.x2)):
                if(np.abs(Snap.x2[j] <= scale/2)):
                    for k in range(len(Snap.x3)):
                        if(Snap.q['v1'][i,j,k]>=v_cutoff):
                            numer += (Snap.ion_fractions[i,j,k]  * 
                                      Snap.del1[i] * Snap.del2[j] * Snap.del3[k])
                            denom += (Snap.del1[i] * Snap.del2[j] * Snap.del3[k])
    if(denom==0): return 0
    return numer/denom
    
def emis_avg_3d_ionfrac(Snap, nu, v_cutoff, scale):
    Snap.load_intensity_variables(nu)
    numer = 0
    denom = 0
    for i in range(len(Snap.x1)):
        if((Snap.x1[i]) <= scale):
            for j in range(len(Snap.x2)):
                if(np.abs(Snap.x2[j] <= scale/2)):
                    for k in range(len(Snap.x3)):
                        if(Snap.q['v1'][i,j,k]>=v_cutoff):
                            numer += (Snap.ion_fractions[i,j,k] * Snap.emission_coefs[i,j,k] * 
                                      Snap.del3[k])
                            denom += (Snap.emission_coefs[i,j,k] * 
                                      Snap.del3[k])
    if(denom==0): return 0
    return numer/denom

# %% [markdown]
# ##### TABLE: 3D Avg ionization fraction value of maps at 5.3 GHz

# %%
slicescales = np.array([4000, 25000])
nu = 5.3*10**9
for scale in slicescales:
    for s in range(1,len(Snapshots)):
        Snap = Snapshots[s]
        if(s==3):
            label_scale = scale
        else: label_scale = ''
        # scale & time & m1 & m10 & m100 & v1 & v10 & v100 & e1 & e10 & e100
        print('%s \t& \t%s \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t\\\\' %
             (label_scale, Years[s], 
              mass_avg_3d_ionfrac(Snap, 1, scale), mass_avg_3d_ionfrac(Snap, 10, scale), mass_avg_3d_ionfrac(Snap, 100, scale),
              vol_avg_3d_ionfrac(Snap, 1, scale), vol_avg_3d_ionfrac(Snap, 10, scale), vol_avg_3d_ionfrac(Snap, 100, scale),
              emis_avg_3d_ionfrac(Snap, nu, 1, scale), emis_avg_3d_ionfrac(Snap, nu, 10, scale), emis_avg_3d_ionfrac(Snap, nu, 100, scale)))
    print('\\hline')

# %%
# exponents instead of decimals
slicescales = np.array([4000, 25000])
nu = 5.3*10**9
for scale in slicescales:
    for s in range(1,len(Snapshots)):
        Snap = Snapshots[s]
        if(s==3):
            label_scale = scale
        else: label_scale = ''
        # scale & time & m1 & m10 & m100 & v1 & v10 & v100 & e1 & e10 & e100
        print('%s \t& \t%s \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t\\\\' %
             (label_scale, Years[s], 
              mass_avg_3d_ionfrac(Snap, 1, scale), mass_avg_3d_ionfrac(Snap, 10, scale), mass_avg_3d_ionfrac(Snap, 100, scale),
              vol_avg_3d_ionfrac(Snap, 1, scale), vol_avg_3d_ionfrac(Snap, 10, scale), vol_avg_3d_ionfrac(Snap, 100, scale),
              emis_avg_3d_ionfrac(Snap, nu, 1, scale), emis_avg_3d_ionfrac(Snap, nu, 10, scale), emis_avg_3d_ionfrac(Snap, nu, 100, scale)))
    print('\\hline')

# %% [markdown]
# ### 2.3.2 Map Avgs Methods for table

# %%
# def calculate_column_ion_densities(Snap):
#     Snap.column_ion_densities = np.zeros((len(Snap.x1), len(Snap.x2)))
#     for i in range(len(Snap.x1)):
#         for j in range(len(Snap.x2)):
#             numer = 0
#             denom = 0
#             for k in range(len(Snap.x3)):
#                 numer += (Snap.ion_fractions[i,j,k] * Snap.q['d'][i,j,k] / Constants.m_H 
#                           * Snap.del3[k]) #number density
#                 denom += Snap.del3[k]
#             if (denom == 0):
#                 Snap.column_ion_densities[i,j] = 0
#             else:
#                 Snap.column_ion_densities[i,j] = numer/denom    
                
def calculate_column_mass_densities(Snap):
    Snap.column_mass_densities = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            numer = 0
            denom = 0
            for k in range(len(Snap.x3)):
                numer += (Snap.q['d'][i,j,k] * Snap.del3[k]) #number density
                denom += Snap.del3[k]
            if (denom == 0):
                Snap.column_mass_densities[i,j] = 0
            else:
                Snap.column_mass_densities[i,j] = numer/denom   

# def mass_avg_map_ionfrac(Snap, v, scale):
#     numer = 0
#     denom = 0
#     for i in range(len(Snap.x1)):
#         if((Snap.x1[i]) <= scale):
#             for j in range(len(Snap.x2)):
#                 if(np.abs(Snap.x2[j] <= scale/2)):
#                     numer += Snap.ionfrac_mass[v,i,j] * Snap.column_ion_densities[i,j] * Snap.del1[i] * Snap.del2[j]
#                     denom += Snap.column_ion_densities[i,j] * Snap.del1[i] * Snap.del2[j]
#     return numer/denom

def mass_avg_map_ionfrac(Snap, v, scale):
    numer = 0
    denom = 0
    for i in range(len(Snap.x1)):
        if((Snap.x1[i]) <= scale):
            for j in range(len(Snap.x2)):
                if(np.abs(Snap.x2[j] <= scale/2)):
                    numer += (Snap.ionfrac_mass[v,i,j] * Snap.column_mass_densities[i,j] 
                              * Snap.del1[i] * Snap.del2[j])
                    denom += Snap.column_mass_densities[i,j] * Snap.del1[i] * Snap.del2[j]
    Snap.avg_map_ionfrac_mass = numer/denom
    return numer/denom

def vol_avg_map_ionfrac(Snap, v, scale):
    numer = 0
    denom = 0
    for i in range(len(Snap.x1)):
        if((Snap.x1[i]) <= scale):
            for j in range(len(Snap.x2)):
                if(np.abs(Snap.x2[j] <= scale/2)):
                    numer += Snap.ionfrac_vol[v,i,j] * Snap.del1[i] * Snap.del2[j]
                    denom += Snap.del1[i] * Snap.del2[j]
    Snap.avg_map_ionfrac_vol = numer/denom
    return numer/denom
    
def emis_avg_map_ionfrac(Snap, f, v, scale):
    Snap.load_intensity_variables(frequencies[f])
    numer = 0
    denom = 0
    for i in range(len(Snap.x1)):
        if((Snap.x1[i]) <= scale):
            for j in range(len(Snap.x2)):
                if(np.abs(Snap.x2[j] <= scale/2)):
                    numer += Snap.ionfrac_emis[f,v,i,j] * Snap.InuA[i,j] * Snap.del1[i] * Snap.del2[j]
                    denom += Snap.InuA[i,j] * Snap.del1[i] * Snap.del2[j]
    Snap.avg_map_ionfrac_emis = numer/denom
    return numer/denom
            
# def save_avg_map_ionfracs(Snap):
#     data_path = (VICO_loc+'/Data/'+Snap.name+'/')
#     np.savez((data_path+Snap.name+'_map_ionfracs.npz'),
#              column_mass_densities = Snap.column_mass_densities,
#              avg_map_ionfrac_mass = Snap.avg_map_ionfrac_mass,
#              avg_map_ionfrac_vol = Snap.avg_map_ionfrac_vol, 
#              avg_map_ionfrac_emis = Snap.avg_map_ionfrac_emis)

# def calculate_avg_map_ionfracs(Snap):
#     Snap.ionfrac_mass = mass_avg_map_ionfrac(Snap)
#     vol_avg_map_ionfrac(Snap)
#     emis_avg_map_ionfrac(Snap)
#     save_avg_map_ionfracs(Snap)
#     save_avg_map_ionfracs(Snap)
    
# def load_avg_map_ionfracs(Snap):
#     data_path = (VICO_loc+'/Data/'+Snap.name+'/')
#     file = np.load((data_path+Snap.name+'_map_ionfracs.npz'))
#     Snap.column_mass_densities = file['column_mass_densities']
#     Snap.avg_map_ionfrac_mass = file['avg_map_ionfrac_mass']
#     Snap.avg_map_ionfrac_vol = file['avg_map_ionfrac_vol']
#     Snap.avg_map_ionfrac_emis = file['avg_map_ionfrac_emis']

# %%
for s in range(len(Snapshots)):
    print(Snapshots[s].name)
    calculate_column_mass_densities(Snapshots[s])

# %% [markdown]
# ##### TABLE: Map Avg ionization fraction value of maps at 5.3 GHz

# %%
slicescales = np.array([4000, 25000])
f = 5
for scale in slicescales:
    for s in range(1,len(Snapshots)):
        Snap = Snapshots[s]
        if(s==3):
            label_scale = scale
        else: label_scale = ''
        # scale & time & m1 & m10 & m100 & v1 & v10 & v100 & e1 & e10 & e100
        print('%s \t& \t%s \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t& \t%.4f \t\\\\' %
             (label_scale, Years[s], 
              mass_avg_map_ionfrac(Snap, 0, scale), mass_avg_map_ionfrac(Snap, 1, scale), mass_avg_map_ionfrac(Snap, 2, scale),
              vol_avg_map_ionfrac(Snap, 0, scale), vol_avg_map_ionfrac(Snap, 1, scale), vol_avg_map_ionfrac(Snap, 2, scale),
              emis_avg_map_ionfrac(Snap, f, 0, scale), emis_avg_map_ionfrac(Snap, f, 1, scale), emis_avg_map_ionfrac(Snap, f, 2, scale)))
    print('\\hline')

# %%
# exponents instead of decimals
for s in range(1,len(Snapshots)):
    load_average_ionfrac_array(Snapshots[s])
slicescales = np.array([4000, 25000])
f = 5
for scale in slicescales:
    for s in range(1,len(Snapshots)):
        Snap = Snapshots[s]
        if(s==3):
            label_scale = scale
        else: label_scale = ''
        # scale & time & m1 & m10 & m100 & v1 & v10 & v100 & e1 & e10 & e100
        print('%s \t& \t%s \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t& \t%.2e \t\\\\' %
             (label_scale, Years[s], 
              mass_avg_map_ionfrac(Snap, 0, scale), mass_avg_map_ionfrac(Snap, 1, scale), mass_avg_map_ionfrac(Snap, 2, scale),
              vol_avg_map_ionfrac(Snap, 0, scale), vol_avg_map_ionfrac(Snap, 1, scale), vol_avg_map_ionfrac(Snap, 2, scale),
              emis_avg_map_ionfrac(Snap, f, 0, scale), emis_avg_map_ionfrac(Snap, f, 1, scale), emis_avg_map_ionfrac(Snap, f, 2, scale)))
    print('\\hline')

# %% [markdown]
# ## 2.4 Ionization Fraction vs Height Profiles

# %%
def mass_ionfrac_average(Snap, year, xmin, xmax, zmin, zmax, v_min, ymin=0, ymax=False, to_print=False):
    if(not ymax): ymax = len(Snap.x3)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax], Snap.x2[xmin], Snap.x2[xmax], Snap.x3[ymin], Snap.x3[ymax-1]))
    numer = 0
    denom = 0
    for i in range(zmin, zmax):
        for j in range(xmin, xmax):
            for k in range(len(Snap.x3)):
                if(Snap.q['v1'][i,j,k] >= v_min):
                    numer += Snap.ion_fractions[i,j,k] * Snap.q['d'][i,j,k] * Snap.del3[k]
                    denom += Snap.q['d'][i,j,k] * Snap.del3[k]
    if(denom==0): return 0
    return(numer/denom)
def vol_ionfrac_average(Snap, year, xmin, xmax, zmin, zmax, v_min, ymin=0, ymax=False, to_print=False):
    if(not ymax): ymax = len(Snap.x3)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax], Snap.x2[xmin], Snap.x2[xmax], Snap.x3[ymin], Snap.x3[ymax-1]))
    numer = 0
    denom = 0
    for i in range(zmin, zmax):
        for j in range(xmin, xmax):
            for k in range(len(Snap.x3)):
                if(Snap.q['v1'][i,j,k] >= v_min):
                    numer += Snap.ion_fractions[i,j,k] * Snap.del3[k]
                    denom += Snap.del3[k]
    if(denom==0): return 0
    return(numer/denom)

def emis_ionfrac_average(Snap, year, nu, xmin, xmax, zmin, zmax, v_min, ymin=0, ymax=False, to_print=False):
    Snap.load_intensity_variables(nu)
    if(not ymax): ymax = len(Snap.x3)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax], Snap.x2[xmin], Snap.x2[xmax], Snap.x3[ymin], Snap.x3[ymax-1]))
    numer = 0
    denom = 0
    for i in range(zmin, zmax):
        for j in range(xmin, xmax):
            for k in range(len(Snap.x3)):
                if(Snap.q['v1'][i,j,k] >= v_min):
                    numer += Snap.ion_fractions[i,j,k] * Snap.emission_coefs[i,j,k] * Snap.del3[k] #with delta
                    denom += Snap.emission_coefs[i,j,k] * Snap.del3[k]
    if(denom==0): return 0
    return(numer/denom)

        
z_segments = np.array([0, 43, 66, 81, 92, 100, 108, 114, 119, 124, 
                       128, 132, 135, 139, 142, 145, 147, 150, 152, 154, 
                       156, 159, 160, 162, 164, 166, 167])
z_values = np.zeros(len(z_segments))
for i in range(len(z_segments)):
    z_values[i] = Snap009_n.x1[z_segments[i]]
# print('z segment boundaries:', z_values)
xsquare = np.array([111, 169])
xsquarevals = np.zeros(2)
for j in range(2):
    xsquarevals[j] = Snap009_n.x2[xsquare[j]]
xslice = np.array([0, len(Snap009_n.x2)])

ionfrac_heights = np.zeros(len(z_segments)-1)
for i in range(len(ionfrac_heights)):
    ionfrac_heights[i] = np.average([z_values[i], z_values[i+1]])
# print('heights:', ionfrac_heights)
    
    
    
v_mins = np.array([1, 10, 100])

# %%
def make_mass_ionfrac_arrays(Snap, Year):
    Snap.mass_ionfrac_xsquare = np.zeros((len(v_mins), len(ionfrac_heights)))
    Snap.mass_ionfrac_xslice = np.zeros((len(v_mins), len(ionfrac_heights)))
    for i in range(25):
        for v in range(len(v_mins)):
            Snap.mass_ionfrac_xsquare[v,i] = mass_ionfrac_average(Snap, Year, xsquare[0], xsquare[1], z_segments[i], z_segments[i+1], v_min=v_mins[v])
            Snap.mass_ionfrac_xslice[v,i] = mass_ionfrac_average(Snap, Year, xslice[0], xslice[1], z_segments[i], z_segments[i+1], v_min=v_mins[v])
    print('%s mass ionfrac arrays made' % (Year))
def make_vol_ionfrac_arrays(Snap, Year):
    Snap.vol_ionfrac_xsquare = np.zeros((len(v_mins), len(ionfrac_heights)))
    Snap.vol_ionfrac_xslice = np.zeros((len(v_mins), len(ionfrac_heights)))
    for i in range(25):
        for v in range(len(v_mins)):
            Snap.vol_ionfrac_xsquare[v,i] = vol_ionfrac_average(Snap, Year, xsquare[0], xsquare[1], z_segments[i], z_segments[i+1], v_min=v_mins[v])
            Snap.vol_ionfrac_xslice[v,i] = vol_ionfrac_average(Snap, Year, xslice[0], xslice[1], z_segments[i], z_segments[i+1], v_min=v_mins[v])
    print('%s vol ionfrac arrays made' % (Year))
def make_emis_ionfrac_arrays(Snap, Year, nu):
    Snap.emis_ionfrac_xsquare = np.zeros((len(v_mins), len(ionfrac_heights)))
    Snap.emis_ionfrac_xslice = np.zeros((len(v_mins), len(ionfrac_heights)))
    for i in range(25):
        for v in range(len(v_mins)):
            Snap.emis_ionfrac_xsquare[v,i] = emis_ionfrac_average(Snap, Year, nu, xsquare[0], xsquare[1], z_segments[i], z_segments[i+1], v_min=v_mins[v])
            Snap.emis_ionfrac_xslice[v,i] = emis_ionfrac_average(Snap, Year, nu, xslice[0], xslice[1], z_segments[i], z_segments[i+1], v_min=v_mins[v])
    print('%s emis ionfrac arrays made (nu=%s)' % (Year, str(nu/10**9)))
    
             
def save_ionfrac_profile(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_ionfrac_profile.npz'), 
             mass_ionfrac_xsquare = Snap.mass_ionfrac_xsquare, mass_ionfrac_xslice = Snap.mass_ionfrac_xslice,
             vol_ionfrac_xsquare = Snap.vol_ionfrac_xsquare, vol_ionfrac_xslice = Snap.vol_ionfrac_xslice, 
             emis_ionfrac_xsquare = Snap.emis_ionfrac_xsquare, emis_ionfrac_xslice = Snap.emis_ionfrac_xslice)
def load_ionfrac_profile(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    loaded_ionfrac_profile= np.load((data_path+Snap.name+'_ionfrac_profile.npz'))
    Snap.mass_ionfrac_xsquare = loaded_ionfrac_profile['mass_ionfrac_xsquare']
    Snap.mass_ionfrac_xslice =  loaded_ionfrac_profile['mass_ionfrac_xslice']
    Snap.vol_ionfrac_xsquare = loaded_ionfrac_profile['vol_ionfrac_xsquare']
    Snap.vol_ionfrac_xslice = loaded_ionfrac_profile['vol_ionfrac_xslice']
    Snap.emis_ionfrac_xsquare =  loaded_ionfrac_profile['emis_ionfrac_xsquare']
    Snap.emis_ionfrac_xslice = loaded_ionfrac_profile['emis_ionfrac_xslice']
    print(Snap, 'ionfrac_profile loaded')
    
def area_avg_of_map(var_arr, del1_arr, del2_arr):
    numer = 0
    denom = 0
    if(len(var_arr[:,0] != len(del1_arr) or len(var_arr[0,:] != len(del2_arr)))):
        print('array sizes', var_arr.shape, 'does not match', del1_arr.shape, 'and', del2_arr.shape)
    for i in range(len(del1_arr)):
        for j in range(len(del2_arr)):
            numer += var_arr[i,j] * del1_arr[i] * del2_arr[j]
            denom += del1_arr[i] * del2_arr[j]

# %%
for s in range(len(Snapshots)):   
    make_mass_ionfrac_arrays(Snapshots[s], Years[s])
    make_vol_ionfrac_arrays(Snapshots[s], Years[s])
    make_emis_ionfrac_arrays(Snapshots[s], Years[s], 5.3*10**9)
    save_ionfrac_profile(Snapshots[s])

# %%
def make_xslice_plot(Snap, Mass):
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()

    ax.set_xlabel('z (au)')
    ax.set_ylabel(r'$\langle\chi_\mathrm{H+}\rangle$')
    ax.set_title(Mass + ' Ionization Fraction vs. Height')
    ax.set_yscale('log')
    ax.set_ylim(10**-4, 10**0)

    
    ax.plot(ionfrac_heights[:-1], Snap.mass_ionfrac_xslice[2,:-1], label='mass, 100km/s', 
            linestyle='solid', linewidth=3.5, color='blueviolet')
    ax.plot(ionfrac_heights[:-1], Snap.mass_ionfrac_xslice[1,:-1], label='mass, 10km/s', 
            linestyle='solid', linewidth=2.5, color='m')
    ax.plot(ionfrac_heights[:-1], Snap.mass_ionfrac_xslice[0,:-1], label='mass, 1km/s', 
            linestyle='solid', linewidth = 1.5, color='fuchsia')
    ax.plot(ionfrac_heights[:-1], Snap.vol_ionfrac_xslice[2,:-1], label='vol, 100km/s', 
            linestyle='dashed', linewidth=3.5, c='darkgreen')
    ax.plot(ionfrac_heights[:-1], Snap.vol_ionfrac_xslice[1,:-1], label='vol, 10km/s', 
            linestyle='dashed', linewidth=2.5, c='mediumseagreen')
    ax.plot(ionfrac_heights[:-1], Snap.vol_ionfrac_xslice[0,:-1], label='vol, 1km/s', 
            linestyle='dashed', linewidth=1.5, c='chartreuse')
    ax.plot(ionfrac_heights[:-1], Snap.emis_ionfrac_xslice[2,:-1], label='emis, 100km/s', 
            linestyle='dashdot', linewidth = 3.5, c='darkblue')
    ax.plot(ionfrac_heights[:-1], Snap.emis_ionfrac_xslice[1,:-1], label='emis, 10km/s', 
            linestyle='dashdot', linewidth = 2.5, c='blue')
    ax.plot(ionfrac_heights[:-1], Snap.emis_ionfrac_xslice[0,:-1], label='emis, 1km/s', 
            linestyle='dashdot', linewidth = 1.5, c='cornflowerblue')
    
    ruben_heights = np.array([3000, 5000, 9000, 18000])
    ruben_fracs = np.array([.12, .17, .07, .05])
    uplims = np.array([0,1,0,0], dtype=bool)
    yerr = np.array([.06, .06, .01, .01])
    ax.errorbar(ruben_heights, ruben_fracs, yerr=yerr, uplims=uplims, label='G35.2-0.74N',
                marker = 'o', markersize=5, color='black', linestyle='none', capsize=5)
    ax.legend(loc='lower right',bbox_to_anchor=(1.0,0))
#     fig.savefig(VICO_loc+'/ChiProfiles/ChiProfile_noratio_'+Snap.name+'.png')
    fig.savefig('/home/ecg6wm/ChiProfile_noratio_'+Snap.name+'.png')

MassLabels = np.array([r'1.5M$_\odot$', r'2M$_\odot$', r'4M$_\odot$', r'8M$_\odot$', r'12M$_\odot$', r'16M$_\odot$', r'24M$_\odot$'])   
for s in range(len(Snapshots)):
    load_ionfrac_profile(Snapshots[s])
    make_xslice_plot(Snapshots[s], MassLabels[s])
    print(np.log10(np.min(Snapshots[s].mass_ionfrac_xslice[:,:-1])))

# %% [markdown]
# ##### with ratio scaling

# %%
def mass_ionfrac_average_ratio(Snap, year, xmin, xmax, zmin, zmax, v_min, ymin=0, ymax=False, to_print=False):
    if(not ymax): ymax = len(Snap.x3)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax], Snap.x2[xmin], Snap.x2[xmax], Snap.x3[ymin], Snap.x3[ymax-1]))
    numer = 0
    denom = 0
    for i in range(zmin, zmax):
        for j in range(xmin, xmax):
            for k in range(len(Snap.x3)):
                if(Snap.q['v1'][i,j,k] >= v_min):
                    scale_factor = (Snap.cooling_times[i,j,k]
                                    /Snap.flow_times[i,j,k])
                    if(scale_factor>1): scale_factor=1 
                        # can't be more than 1  
                    numer += (Snap.ion_fractions[i,j,k] * 
                              Snap.q['d'][i,j,k] 
                              * Snap.del3[k] 
                              * scale_factor)
                    denom += Snap.q['d'][i,j,k] * Snap.del3[k]
    if(denom==0): return 0
    return(numer/denom)
def vol_ionfrac_average_ratio(Snap, year, xmin, xmax, zmin, zmax, v_min, ymin=0, ymax=False, to_print=False):
    if(not ymax): ymax = len(Snap.x3)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax], Snap.x2[xmin], Snap.x2[xmax], Snap.x3[ymin], Snap.x3[ymax-1]))
    numer = 0
    denom = 0
    for i in range(zmin, zmax):
        for j in range(xmin, xmax):
            for k in range(len(Snap.x3)):
                scale_factor = (Snap.cooling_times[i,j,k]
                                    /Snap.flow_times[i,j,k])
                if(scale_factor>1): scale_factor=1 
                    # can't be more than 1
                if(Snap.q['v1'][i,j,k] >= v_min):
                    numer += (Snap.ion_fractions[i,j,k] 
                              * Snap.del3[k] 
                              * scale_factor)
                    denom += Snap.del3[k]
    if(denom==0): return 0
    return(numer/denom)

def emis_ionfrac_average_ratio(Snap, year, nu, xmin, xmax, zmin, zmax, v_min, ymin=0, ymax=False, to_print=False):
    Snap.load_intensity_variables(nu)
    if(not ymax): ymax = len(Snap.x3)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax], Snap.x2[xmin], Snap.x2[xmax], Snap.x3[ymin], Snap.x3[ymax-1]))
    numer = 0
    denom = 0
    for i in range(zmin, zmax):
        for j in range(xmin, xmax):
            for k in range(len(Snap.x3)):
                if(Snap.q['v1'][i,j,k] >= v_min):
                    numer += Snap.ion_fractions[i,j,k] * Snap.emission_coefs[i,j,k] * Snap.del3[k] #with delta
                    denom += Snap.emission_coefs[i,j,k] * Snap.del3[k]
    if(denom==0): return 0
    return(numer/denom)

        
z_segments = np.array([0, 43, 66, 81, 92, 100, 108, 114, 119, 124, 
                       128, 132, 135, 139, 142, 145, 147, 150, 152, 154, 
                       156, 159, 160, 162, 164, 166, 167])
z_values = np.zeros(len(z_segments))
for i in range(len(z_segments)):
    z_values[i] = Snap009_n.x1[z_segments[i]]
# print('z segment boundaries:', z_values)
xsquare = np.array([111, 169])
xsquarevals = np.zeros(2)
for j in range(2):
    xsquarevals[j] = Snap009_n.x2[xsquare[j]]
xslice = np.array([0, len(Snap009_n.x2)])

ionfrac_heights = np.zeros(len(z_segments)-1)
for i in range(len(ionfrac_heights)):
    ionfrac_heights[i] = np.average([z_values[i], z_values[i+1]])
# print('heights:', ionfrac_heights)
    
    
    
v_mins = np.array([1, 10, 100])

# %%
def make_mass_ionfrac_ratio_arrays(Snap, Year):
    Snap.mass_ionfrac_xsquare = np.zeros((len(v_mins), 
                                   len(ionfrac_heights)))
    Snap.mass_ionfrac_xslice = np.zeros((len(v_mins), 
                                   len(ionfrac_heights)))
    for i in range(25):
        for v in range(len(v_mins)):
            Snap.mass_ionfrac_xsquare[v,i] = \
            mass_ionfrac_average_ratio(Snap, Year, 
                                xsquare[0], xsquare[1], 
                        z_segments[i], z_segments[i+1], 
                                       v_min=v_mins[v])
            Snap.mass_ionfrac_xslice[v,i] = \
            mass_ionfrac_average_ratio(Snap, Year, 
                                xslice[0], xslice[1], 
                        z_segments[i], z_segments[i+1], 
                                       v_min=v_mins[v])
    print('%s mass ionfrac ratio arrays made' % (Year))
def make_vol_ionfrac_ratio_arrays(Snap, Year):
    Snap.vol_ionfrac_xsquare = np.zeros((len(v_mins), 
                                len(ionfrac_heights)))
    Snap.vol_ionfrac_xslice = np.zeros((len(v_mins), 
                                len(ionfrac_heights)))
    for i in range(25):
        for v in range(len(v_mins)):
            Snap.vol_ionfrac_xsquare[v,i] = \
            vol_ionfrac_average_ratio(Snap, Year, 
                                xsquare[0], xsquare[1], 
                        z_segments[i], z_segments[i+1], 
                                      v_min=v_mins[v])
            Snap.vol_ionfrac_xslice[v,i] = \
            vol_ionfrac_average_ratio(Snap, Year, 
                                xslice[0], xslice[1], 
                        z_segments[i], z_segments[i+1], 
                                      v_min=v_mins[v])
    print('%s vol ionfrac ratio arrays made' % (Year))
def make_emis_ionfrac_ratio_arrays(Snap, Year, nu):
    Snap.emis_ionfrac_xsquare = np.zeros((len(v_mins), 
                                len(ionfrac_heights)))
    Snap.emis_ionfrac_xslice = np.zeros((len(v_mins), 
                                len(ionfrac_heights)))
    for i in range(25):
        for v in range(len(v_mins)):
            Snap.emis_ionfrac_xsquare[v,i] = \
            emis_ionfrac_average_ratio(Snap, Year, nu, 
                                xsquare[0], xsquare[1], 
                        z_segments[i], z_segments[i+1], 
                                       v_min=v_mins[v])
            Snap.emis_ionfrac_xslice[v,i] = \
            emis_ionfrac_average_ratio(Snap, Year, nu, 
                                xslice[0], xslice[1], 
                        z_segments[i], z_segments[i+1], 
                                       v_min=v_mins[v])
    print('%s emis ionfrac ratio arrays made (nu=%s)' % (Year, str(nu/10**9)))
    
             
def save_ionfrac_ratio_profile(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name
              +'_ionfrac_ratio_profile.npz'), 
             mass_ionfrac_xsquare = \
             Snap.mass_ionfrac_xsquare, 
             mass_ionfrac_xslice = \
             Snap.mass_ionfrac_xslice,
             vol_ionfrac_xsquare = \
             Snap.vol_ionfrac_xsquare, 
             vol_ionfrac_xslice = \
             Snap.vol_ionfrac_xslice, 
             emis_ionfrac_xsquare = \
             Snap.emis_ionfrac_xsquare, 
             emis_ionfrac_xslice = \
             Snap.emis_ionfrac_xslice)
def load_ionfrac_ratio_profile(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    loaded_ionfrac_profile= np.load((data_path+Snap.name
                        +'_ionfrac_ratio_profile.npz'))
    Snap.mass_ionfrac_xsquare = \
    loaded_ionfrac_profile['mass_ionfrac_xsquare']
    Snap.mass_ionfrac_xslice =  \
    loaded_ionfrac_profile['mass_ionfrac_xslice']
    Snap.vol_ionfrac_xsquare = \
    loaded_ionfrac_profile['vol_ionfrac_xsquare']
    Snap.vol_ionfrac_xslice = \
    loaded_ionfrac_profile['vol_ionfrac_xslice']
    Snap.emis_ionfrac_xsquare =  \
    loaded_ionfrac_profile['emis_ionfrac_xsquare']
    Snap.emis_ionfrac_xslice = \
    loaded_ionfrac_profile['emis_ionfrac_xslice']
    print(Snap, 'ionfrac_profile loaded')

# %%
for s in range(len(Snapshots)):   
    make_mass_ionfrac_ratio_arrays(Snapshots[s], Years[s])
    make_vol_ionfrac_ratio_arrays(Snapshots[s], Years[s])
    make_emis_ionfrac_ratio_arrays(Snapshots[s], Years[s], 5.3*10**9)
    save_ionfrac_ratio_profile(Snapshots[s])VICO_loc

# %%
def make_xslice_plot(Snap, Mass):
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()

    ax.set_xlabel('z (au)')
    ax.set_ylabel(r'$\langle\chi_\mathrm{H+}\rangle$')
    ax.set_title(Mass + ' Ionization Fraction vs. Height')
    ax.set_yscale('log')
    ax.set_ylim(10**-4, 10**0)

    
    ax.plot(ionfrac_heights[:-1], Snap.mass_ionfrac_xslice[2,:-1], label='mass, 100km/s', 
            linestyle='solid', linewidth=3.5, color='blueviolet')
    ax.plot(ionfrac_heights[:-1], Snap.mass_ionfrac_xslice[1,:-1], label='mass, 10km/s', 
            linestyle='solid', linewidth=2.5, color='m')
    ax.plot(ionfrac_heights[:-1], Snap.mass_ionfrac_xslice[0,:-1], label='mass, 1km/s', 
            linestyle='solid', linewidth = 1.5, color='fuchsia')
    ax.plot(ionfrac_heights[:-1], Snap.vol_ionfrac_xslice[2,:-1], label='vol, 100km/s', 
            linestyle='dashed', linewidth=3.5, c='darkgreen')
    ax.plot(ionfrac_heights[:-1], Snap.vol_ionfrac_xslice[1,:-1], label='vol, 10km/s', 
            linestyle='dashed', linewidth=2.5, c='mediumseagreen')
    ax.plot(ionfrac_heights[:-1], Snap.vol_ionfrac_xslice[0,:-1], label='vol, 1km/s', 
            linestyle='dashed', linewidth=1.5, c='chartreuse')
    ax.plot(ionfrac_heights[:-1], Snap.emis_ionfrac_xslice[2,:-1], label='emis, 100km/s', 
            linestyle='dashdot', linewidth = 3.5, c='darkblue')
    ax.plot(ionfrac_heights[:-1], Snap.emis_ionfrac_xslice[1,:-1], label='emis, 10km/s', 
            linestyle='dashdot', linewidth = 2.5, c='blue')
    ax.plot(ionfrac_heights[:-1], Snap.emis_ionfrac_xslice[0,:-1], label='emis, 1km/s', 
            linestyle='dashdot', linewidth = 1.5, c='cornflowerblue')
    
    ruben_heights = np.array([3000, 5000, 9000, 18000])
    ruben_fracs = np.array([.12, .17, .07, .05])
    uplims = np.array([0,1,0,0], dtype=bool)
    yerr = np.array([.06, .06, .01, .01])
    ax.errorbar(ruben_heights, ruben_fracs, yerr=yerr, uplims=uplims, label='G35.2-0.74N',
                marker = 'o', markersize=5, color='black', linestyle='none', capsize=5)
    ax.legend(loc='lower right',bbox_to_anchor=(1.0,0))
#     fig.savefig(VICO_loc+'/ChiProfiles/ChiProfile_ratio_'+Snap.name+'.png')
    fig.savefig(VICO_loc+'/ChiProfiles/ChiProfile_ratio_'+Snap.name+'.png')

MassLabels = np.array([r'1.5M$_\odot$', r'2M$_\odot$', r'4M$_\odot$', r'8M$_\odot$', r'12M$_\odot$', r'16M$_\odot$', r'24M$_\odot$'])   
for s in range(len(Snapshots)):
    load_ionfrac_ratio_profile(Snapshots[s])
    make_xslice_plot(Snapshots[s], MassLabels[s])
    print(np.log10(np.min(Snapshots[s].mass_ionfrac_xslice[:,:-1])))

# %% [markdown]
# ## 2.5 Intensity Mapping

# %% [markdown]
# ##### *Intensity Map Methods*

# %%
def intensity_pcolormesh(Snap, year, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 14)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=14)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    ax.text(.02, .29, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_'+str(scale)+'AU.png' 
        fig.savefig(filename, bbox_inches='tight')
        return(filename)
        
def intensity_const_pcolormesh(Snap, year, const, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.load_intensity_variables_const(nu=nu, const=const)
    
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA_const[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 14)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=14)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    ax.text(.02, .29, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_const_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_ratio_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# Figure 3: All frequencies 12Msun example no ratio
# #### PIL Image Methods

# %%
def make_Inu12msun_allimage(imgfiles_arr, allimagename, scale, ratio=False):
    nrows = len(imgfiles_arr) # should be 2
    ncols = len(imgfiles_arr[0]) # should be 5 for 
    side=300
    header=0
    if(scale==25000):
        leftax = 150
    else:
        leftax=134
    bottomax = 82
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side + bottomax + header))

    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
#             print(width,height)
            if(c==0): # y axis
                new_width=int(side*((width-6.25)/(231-6.25-7.25)))
                left=0
                new_x=0
                right=width-6.25
            else: 
                new_width=side
                left=7.25
                new_x=c*side+(leftax)
                right=width-6.25

            if(r==nrows-1): # x axis
                new_height=int(side*(height-6.75)/(231-6.75-6.75))
                bottom=height
            else: 
                new_height=side
                bottom=height-6.75
            top=7
            new_y = r*side + header

            img = img.crop((left, top, right, bottom))
            img = img.resize((new_width,new_height))
            allimage.paste(img, ((new_x, new_y)))
    display(allimage)
    if(ratio):
        imcbar = Image.open(VICO_loc+'/PaperImages/intensities_12msun/cbar_vertical_ratio.png')
    else:
        imcbar = Image.open(VICO_loc+'/PaperImages/intensities_12msun/cbar_vertical_noratio.png')
    imcbar = imcbar.resize((2*imcbar.width, 2*imcbar.height))
    imnew = Image.new('RGBA', (allimage.width+imcbar.width, allimage.height),
                 color='white')
    imnew.paste(allimage, (0,0))
    imnew.paste(imcbar, (allimage.width, int(allimage.height/2 - imcbar.height/2)))
    
    display(imnew)
    imnew.save(allimagename)

# %% [markdown]
# #### 2.5.1 PIL Image: 25000au no ratio

# %%
s=4
vmin_intensity_noratio, vmax_intensity_noratio = -4, 3 
saveloc = VICO_loc+'/PaperImages/intensities_12msun'

nrows = 2
ncols = 5
scale = 25000
Inu12msun_files_25000au = np.empty((nrows, ncols), dtype=object)

r = -1
c = 0
for f in range(len(frequencies)):
    if(f==0 or f==5):
        show_ylabels=True
        r += 1
        c = 0
    else: show_ylabels=False 
    if(f<5): 
        show_xlabels=False
    else: show_xlabels=True
    filename = intensity_pcolormesh(Snapshots[s], Masses[s], scale, 
                              f, vmin_intensity_noratio, 
                              vmax_intensity_noratio,
                              saveloc=saveloc,
                              show_xlabels = show_xlabels, 
                              show_ylabels = show_ylabels, 
                              show_cbar=False)
    Inu12msun_files_25000au[r,c] = filename
    print(r,c)
    c+=1

# %%
make_Inu12msun_allimage(imgfiles_arr=Inu12msun_files_25000au, 
                        allimagename=VICO_loc+'/PaperImages/Inu12msun_25000au.png',
                        scale = 25000)

# %% [markdown]
# #### 2.5.2 PIL Figure: 4000au no ratio

# %%
s=4
saveloc = VICO_loc+'/PaperImages/intensities_12msun'

nrows = 2
ncols = 5
scale = 4000
Inu12msun_files_4000au = np.empty((nrows, ncols), dtype=object)

r = -1
c = 0
for f in range(len(frequencies)):
    if(f==0 or f==5):
        show_ylabels=True
        r += 1
        c = 0
    else: show_ylabels=False 
    if(f<5):        
        show_xlabels=False
    else: show_xlabels=True
    filename = intensity_pcolormesh(Snapshots[s], Masses[s], scale, 
                              f, vmin_intensity_noratio, vmax_intensity_noratio,
                              saveloc=saveloc,
                              show_xlabels = show_xlabels, 
                              show_ylabels = show_ylabels, 
                              show_cbar=False)
    Inu12msun_files_4000au[r,c] = filename
    print(r,c)
    c+=1

# %%
make_Inu12msun_allimage(imgfiles_arr=Inu12msun_files_4000au, 
                        allimagename=VICO_loc+'/PaperImages/Inu12msun_4000au.png',
                        scale = 4000)

# %% [markdown]
# #### 2.5.3 PIL Figure: 25000 au ratio

# %%
s=4
vmin_intensity_ratio, vmax_intensity_ratio = -4, -1 
saveloc = VICO_loc+'/PaperImages/intensities_12msun'

nrows = 2
ncols = 5
scale = 25000
Inu12msun_files_25000au_ratio = np.empty((nrows, ncols), dtype=object)

r = -1
c = 0
for f in range(len(frequencies)):
    if(f==0 or f==5):
        show_ylabels=True
        r += 1
        c = 0
    else: show_ylabels=False 
    if(f<5): 
        show_xlabels=False
    else: show_xlabels=True
    filename = intensity_const_pcolormesh(Snapshots[s], Masses[s], False,
                                               scale, f,
                              vmin_intensity_ratio, vmax_intensity_ratio,
                              saveloc=saveloc,
                              show_xlabels = show_xlabels, 
                              show_ylabels = show_ylabels, 
                              show_cbar=False)
    Inu12msun_files_25000au_ratio[r,c] = filename
    print(r,c)
    c+=1

# %%
make_Inu12msun_allimage(imgfiles_arr=Inu12msun_files_25000au_ratio, 
                        allimagename=VICO_loc+'/PaperImages/Inu12msun_25000au_ratio.png',
                        scale = 25000, ratio=True)

# %% [markdown]
# #### 2.5.4 PIL Figure: 4000au ratio

# %%
s=4
saveloc = VICO_loc+'/PaperImages/intensities_12msun'

nrows = 2
ncols = 5
scale = 4000
Inu12msun_files_4000au_ratio = np.empty((nrows, ncols), dtype=object)

r = -1
c = 0
for f in range(len(frequencies)):
    if(f==0 or f==5):
        show_ylabels=True
        r += 1
        c = 0
    else: show_ylabels=False 
    if(f<5): 
        show_xlabels=False
    else: show_xlabels=True
    filename = intensity_const_pcolormesh(Snapshots[s], Masses[s], False,
                                               scale, f,
                              vmin_intensity_ratio, vmax_intensity_ratio,
                              saveloc=saveloc,
                              show_xlabels = show_xlabels, 
                              show_ylabels = show_ylabels, 
                              show_cbar=False)
    Inu12msun_files_4000au_ratio[r,c] = filename
    print(r,c)
    c+=1

# %%
make_Inu12msun_allimage(imgfiles_arr=Inu12msun_files_4000au_ratio, 
                        allimagename=VICO_loc+'/PaperImages/Inu12msun_4000au_ratio.png',
                        scale = 4000, ratio=True)

# %% [markdown]
# ###### *colorbar*

# %%
# use Snap004_n for this
s=0
f=5
saveloc = VICO_loc+'/PaperImages/intensities_12msun'
filename = intensity_pcolormesh(Snapshots[s], Years[s], scale, f=f,
                          vmin=vmin_intensity_noratio, vmax=vmax_intensity_noratio,
                          show_xlabels=False, show_ylabels=False, 
                          show_cbar=True, vertical_cbar=True,
                                    saveloc=saveloc)
cbar_v_img = Image.open(filename)
print(cbar_v_img.size)
width, height = cbar_v_img.size
left = 220
right = width
top = 0
bottom = height
cbar_v_img = cbar_v_img.crop((left, top, right, bottom))
print(cbar_v_img.size)
cbar_v_filename = saveloc+'/cbar_vertical_noratio.png'
cbar_v_img.save(cbar_v_filename)
display_image(cbar_v_filename)
print(cbar_v_filename)

# %%
# use Snap004_n for this
s=0
f=5
saveloc = VICO_loc+'/PaperImages/intensities_12msun'
filename = intensity_const_pcolormesh(Snapshots[s], Years[s], False, scale, f=f,
                          vmin=vmin_intensity_ratio, vmax=vmax_intensity_ratio,
                          show_xlabels=False, show_ylabels=False, 
                          show_cbar=True, vertical_cbar=True,
                                    saveloc=saveloc)
cbar_v_img = Image.open(filename)
print(cbar_v_img.size)
width, height = cbar_v_img.size
left = 220
right = width
top = 0
bottom = height
cbar_v_img = cbar_v_img.crop((left, top, right, bottom))
print(cbar_v_img.size)
cbar_v_filename = saveloc+'/cbar_vertical_ratio.png'
cbar_v_img.save(cbar_v_filename)
display_image(cbar_v_filename)
print(cbar_v_filename)

# %% [markdown]
# ###### scratch

# %%
def intensity_pcolormesh(Snap, year, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 14)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=14)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    ax.text(.02, .29, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_'+str(scale)+'AU.png' 
        fig.savefig(filename, bbox_inches='tight')
        return(filename)
        
def intensity_const_pcolormesh_temp(Snap, year, const, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.load_intensity_variables_const(nu=nu, const=const)
    
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (6,6))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1, Snap.X1_2, np.log10((Snap.InuA_const[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=20)
        ax.tick_params(axis='x', labelsize=16)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=20)
        ax.tick_params(axis='y', labelsize=16)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 14)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=14)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    ax.text(.02, .29, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_const_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_ratio_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    

for s in range(len(Snapshots)-2, len(Snapshots)):
    for scale in (4000, 25000):
        intensity_const_pcolormesh_temp(Snapshots[s], Masses[s], False,
                           scale=scale, f=5,
                        vmin=-5, 
                           vmax=0,
                              saveloc=False,
                              show_xlabels = True, 
                              show_ylabels = True, 
                              show_cbar=True, cbar_pad=.15)

# %% [markdown]
# ## 2.6 Projection Maps

# %% [markdown]
# ##### *Ionfrac Proj Map Methods*

# %%
def mass_ionfrac_proj_pcolormesh(Snap, year, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
            
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=13)
            
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, mass}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    ax.text(.02, .3, (r'$\mathbf{\langle\chi_{H+}\rangle}$'+'\n'+year),
            ha='left', va='top', transform=ax.transAxes, 
            fontsize = 28, weight='bold', color='white')
    
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
    
def mass_ionfrac_proj_const_pcolormesh(Snap, year, const, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
            
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    if(const):
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass_const[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    else: 
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass_ratio[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=13)
            
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, mass}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    ax.text(.02, .3, (r'$\mathbf{\langle\chi_{H+}\rangle}$'+'\n'+year),
            ha='left', va='top', transform=ax.transAxes, 
            fontsize = 28, weight='bold', color='white')
    
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_const_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_ratio_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# ##### *Intensity Proj Map Methods*

# %%
freq_strings=np.array(['.01', '.05', '0.1', '0.5', '1.0', 
                       '5.3', '23', '43', '100', '230']) 

def intensity_proj_pcolormesh(Snap, year, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 12)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=12)
    ax.text(.02, .29, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_'+str(scale)+'AU.png' 
        fig.savefig(filename, bbox_inches='tight')
        return(filename)
        
def intensity_proj_const_pcolormesh(Snap, year, const, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.load_intensity_variables_const(nu=nu, const=const)
    
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA_const[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 12)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=12)
    ax.text(.02, .29, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_const_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_ratio_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# ##### *Iontemp Proj Map Methods*

# %%
def iontemp_proj_pcolormesh(Snap, year, scale, vmin, vmax, 
                            cmap='hot', nu = 5.3*10**9,
                            saveloc=False, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, vertical_cbar=False):
    TprojA = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            TprojA[i,j] = (np.sum(Snap.temperatures[i,j,:] * Snap.ion_fractions[i,j,:] * Snap.q['d'][i,j,:] * Snap.del3) 
                           / np.sum(Snap.ion_fractions[i,j,:] * Snap.q['d'][i,j,:] * Snap.del3))
    # Make temperature projection log plots for snapshot    
    
    
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(TprojA)), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($\langle T_\mathrm{H+}\rangle$ / [K])'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($\langle T_\mathrm{H+}\rangle$ / [K])'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    
    ax.text(.02, .3, (r'$\mathbf{\langle T_{H+}\rangle}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_iontemp_'+str(scale)+'AU.png' 
        fig.savefig(filename, bbox_inches='tight')
        return(filename)

def iontemp_proj_ratio_pcolormesh(Snap, year, scale, vmin, vmax, 
                            cmap='hot', nu = 5.3*10**9,
                            saveloc=False, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, vertical_cbar=False):
    TprojA = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            TprojA[i,j] = (np.sum(Snap.temperatures[i,j,:] * Snap.ion_fractions[i,j,:] 
                                  * Snap.q['d'][i,j,:] * Snap.del3 
                                  * Snap.scale_factors[i,j,:]) 
                           / np.sum(Snap.ion_fractions[i,j,:] 
                                    * Snap.q['d'][i,j,:] * Snap.del3
                                    * Snap.scale_factors[i,j,:]))
    # Make temperature projection log plots for snapshot    
    
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(TprojA)), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($\langle T_\mathrm{H+}\rangle$ / [K])'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($\langle T_\mathrm{H+}\rangle$ / [K])'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    
    ax.text(.02, .3, (r'$\mathbf{\langle T_{H+}\rangle}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_iontemp_const_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_iontemp_ratio_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %%
       
# Not needed, just for trouble shotting    
def surfacedensity_pcolormesh(Snap, year, scale, vmin, vmax, cmap='cividis', 
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    avgA = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            avgA[i,j] = np.sum(Snap.q['d'][i,j,:] * Snap.del3) 
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('navy')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(avgA)), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        fig.colorbar(cont, label = 'log($\sigma$ / [g/cm^2])', 
                 orientation = 'horizontal', fraction=0.038, pad=cbar_pad).ax.tick_params(rotation=45)
    ax.text(.02, .2, (r'$\mathbf{\sigma}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 15, weight='bold', color='white')
#     if (saveloc != False): fig.savefig(saveloc+'/'+Snap.name+'_6_iontempproj_'+str(scale)+'AU.png')
    if(show): fig.show()
        
def avgzvelocity_pcolormesh(Snap, year, scale, vmin, vmax, cmap='PuBuGn', v_min=100,
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    avgA = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            numer = 0
            denom = 0
            for k in range(len(Snap.x3)):
                if(Snap.q['v1'][i,j,k] >= v_min):
                    numer += Snap.q['v1'][i,j,k] * Snap.q['d'][i,j,k] * Snap.del3[k]
                    denom += np.sum(Snap.q['d'][i,j,k] * Snap.del3[k]) 
            if(denom>0):
                avgA[i,j] = numer/denom
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('white')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(avgA)), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        fig.colorbar(cont, label = r'log($\langle v_z \rangle$ / [km/s])', 
                 orientation = 'horizontal', fraction=0.038, pad=cbar_pad).ax.tick_params(rotation=45)
    ax.text(.02, .2, (r'$\langle v_z \rangle$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 15, weight='bold', color='black')
#     if (saveloc != False): fig.savefig(saveloc+'/'+Snap.name+'_6_iontempproj_'+str(scale)+'AU.png')
    if(show): fig.show()

# %% [markdown]
# ###### Figure 4: Ionization Fraction, Temp Proj, 5.3GHz, 230 GHz

# %%
slicescales = np.array([4000, 25000])
vmin_ionfrac, vmax_ionfrac = -3, 0       
v = len(v_mins)-1
vmin_iontemp, vmax_iontemp = 0, 7       
vmin_intensity_noratio, vmax_intensity_noratio = -3, 2.8   
vmin_intensity_ratio, vmax_intensity_ratio = -4, 0    

def proj_images(Snap, year, scale, saveloc = False, 
                 show_cbar=False, xlabels=False, cbar_pad=.15):
    # Ionization Fraction
    file0 = mass_ionfrac_proj_pcolormesh(Snap, year, scale, v = v,
                            vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                            show_xlabels = xlabels, show_ylabels = True,
                            show_contours = False, show_legend = False, 
                            show_cbar = False, saveloc=saveloc)
    # Temperature Projection
    file1 = iontemp_proj_pcolormesh(Snap, year, scale,  
                            vmin_iontemp, vmax_iontemp,
                            show_xlabels = xlabels, show_ylabels = False, 
                            show_cbar=False, saveloc=saveloc)
    
    # 5.3 GHz Intensity
    file2 = intensity_proj_pcolormesh(Snap, year, scale, 5, 
                              vmin_intensity_noratio, vmax_intensity_noratio, 
                             show_xlabels = xlabels, show_ylabels = False, 
                              show_cbar=False, saveloc=saveloc)
    # 230 GHz
    file3 = intensity_proj_pcolormesh(Snap, year, scale, 9,
                              vmin_intensity_noratio, vmax_intensity_noratio, 
                             show_xlabels = xlabels, show_ylabels = False, 
                              show_cbar=False, saveloc=saveloc)
    return (file0, file1, file2, file3)

def proj_const_images(Snap, year, const, scale, saveloc = False, 
                 show_cbar=False, xlabels=False, cbar_pad=.15):
    # Ionization Fraction
    file0 = mass_ionfrac_proj_const_pcolormesh(Snap, year, const, scale, v = v,
                            vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                            show_xlabels = xlabels, show_ylabels = True,
                            show_contours = False, show_legend = False, 
                            show_cbar = False, saveloc=saveloc)
    # Temperature Projection
    file1 = iontemp_proj_ratio_pcolormesh(Snap, year, scale,  
                            vmin_iontemp, vmax_iontemp,
                            show_xlabels = xlabels, show_ylabels = False, 
                            show_cbar=False, saveloc=saveloc)

    
    # 5.3 GHz Intensity
    file2 = intensity_proj_const_pcolormesh(Snap, year, const, scale, 5, 
                              vmin_intensity_ratio, vmax_intensity_ratio, 
                             show_xlabels = xlabels, show_ylabels = False, 
                              show_cbar=False, saveloc=saveloc)
    # 230 GHz
    file3 = intensity_proj_const_pcolormesh(Snap, year, const, scale, 9,
                              vmin_intensity_ratio, vmax_intensity_ratio, 
                             show_xlabels = xlabels, show_ylabels = False, 
                              show_cbar=False, saveloc=saveloc)
    return (file0, file1, file2, file3)

# %% [markdown]
# ##### PIL Image Methods

# %%
# for PIL    
def make_proj_allimage(imgfiles_arr, allimagename, scale, ratio):
    nrows = len(imgfiles_arr)
    ncols = len(imgfiles_arr[0]) # should be 5 for 
    side=300
    header=0
    if(scale==25000):
        leftax = 150
    else:
        leftax=134
    bottomax = 82
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side + bottomax + header))
    cropped_names = np.empty((nrows, ncols), dtype=object)

    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
#             print(width,height)
            if(c==0): # y axis
                new_width=int(side*((width-6.25)/(231-6.25-7.25)))
                left=0
                new_x=0
                right=width-6.25
            else: 
                new_width=side
                left=7.25
                new_x=c*side+(leftax)
                right=width-6.25

            if(r==nrows-1): # x axis
                new_height=int(side*(height-6.75)/(231-6.75-6.75))
                bottom=height
            else: 
                new_height=side
                bottom=height-6.75
            top=7
            new_y = r*side + header

            img = img.crop((left, top, right, bottom))
            img = img.resize((new_width,new_height))
            allimage.paste(img, ((new_x, new_y)))
    display(allimage)
    
    if(ratio):
        im0 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_ionfrac.png')
        im1 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_iontemp.png')
        im2 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_intensity_ratio.png')
        im3 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_intensity_ratio.png')
    else:
        im0 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_ionfrac.png')
        im1 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_iontemp.png')
        im2 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_intensity_noratio.png')
        im3 = Image.open(VICO_loc+'/PaperImages/proj_images/cbar_intensity_noratio.png')
    
    cbar_ims = np.array([im0, im1, im2, im3])
    cbar_height = 0
    
    for i in range(len(cbar_ims)):
        im = cbar_ims[i]
        im = im.resize((side, int(im.height * side/im.width)))
        if(im.height > cbar_height): cbar_height = im.height
        cbar_ims[i] = im
    imnew = Image.new('RGBA', (allimage.width, allimage.height+cbar_height),
                 color='white')
    imnew.paste(allimage, (0,0))
    for i in range(len(cbar_ims)):
        imnew.paste(cbar_ims[i], (leftax+side*i, allimage.height))
    
    display(imnew)
    imnew.save(allimagename)

# %% [markdown]
# #### 2.6.1 PIL Figure: 25000au no ratio

# %%
nrows = len(Snapshots)-1
ncols = 4
scale = 25000
projfiles_25000au_noratio = np.empty((nrows, ncols), dtype=object)
saveloc = VICO_loc+'/PaperImages/proj_images'


vmin_ionfrac, vmax_ionfrac = -3, 0       
v = len(v_mins)-1
vmin_iontemp, vmax_iontemp = 0, 7       
vmin_intensity, vmax_intensity = -3, 2.8 

r=0
for s in range(1,len(Snapshots)):
    print(Years[s])
    if(s < len(Snapshots)-1):
        file0, file1, file2, file3 = \
        proj_images(Snapshots[s], Masses[s], scale,
                    saveloc=saveloc, xlabels=False)
    else:      
        file0, file1, file2, file3 = \
        proj_images(Snapshots[s], Masses[s], scale,
                    saveloc=saveloc, xlabels=True)
    projfiles_25000au_noratio[r,0] = file0
    projfiles_25000au_noratio[r,1] = file1
    projfiles_25000au_noratio[r,2] = file2
    projfiles_25000au_noratio[r,3] = file3
    r+=1

# %%
make_proj_allimage(imgfiles_arr=projfiles_25000au_noratio, 
                   allimagename=VICO_loc+'/PaperImages/Projs_25000au_noratio.png', 
                   scale=25000, ratio=False)

# %% [markdown]
# #### 2.6.2 PIL Figure: 4000au no ratio

# %%
nrows = len(Snapshots)-1
ncols = 4
scale = 4000
projfiles_4000au_noratio = np.empty((nrows, ncols), dtype=object)
saveloc = VICO_loc+'/PaperImages/proj_images'


vmin_ionfrac, vmax_ionfrac = -3, 0       
v = len(v_mins)-1
vmin_iontemp, vmax_iontemp = 0, 7       
vmin_intensity, vmax_intensity = -3, 2.8 

r=0
for s in range(1,len(Snapshots)):
    print(Years[s])
    if(s < len(Snapshots)-1):
        file0, file1, file2, file3 = \
        proj_images(Snapshots[s], Masses[s], scale,
                    saveloc=saveloc, xlabels=False)
    else:      
        file0, file1, file2, file3 = \
        proj_images(Snapshots[s], Masses[s], scale,
                    saveloc=saveloc, xlabels=True)
    projfiles_4000au_noratio[r,0] = file0
    projfiles_4000au_noratio[r,1] = file1
    projfiles_4000au_noratio[r,2] = file2
    projfiles_4000au_noratio[r,3] = file3
    r+=1

# %%
make_proj_allimage(imgfiles_arr=projfiles_4000au_noratio, 
                   allimagename=VICO_loc+'/PaperImages/Projs_4000au_noratio.png', 
                   scale=4000, ratio=False)

# %% [markdown]
# #### 2.6.3 PIL Figure: 25000au ratio

# %%
nrows = len(Snapshots)-1
ncols = 4
scale = 25000
projfiles_25000au_ratio = np.empty((nrows, ncols), dtype=object)
saveloc = VICO_loc+'/PaperImages/proj_images'


vmin_ionfrac, vmax_ionfrac = -3, 0       
v = len(v_mins)-1
vmin_iontemp, vmax_iontemp = 0, 7       
vmin_intensity, vmax_intensity = -3, 2.8 

r=0
for s in range(1,len(Snapshots)):
    print(Years[s])
    if(s < len(Snapshots)-1):
        file0, file1, file2, file3 = \
        proj_const_images(Snapshots[s], Masses[s], False, 
                          scale,
                    saveloc=saveloc, xlabels=False)
    else:      
        file0, file1, file2, file3 = \
        proj_const_images(Snapshots[s], Masses[s], False,
                          scale,
                    saveloc=saveloc, xlabels=True)
    projfiles_25000au_ratio[r,0] = file0
    projfiles_25000au_ratio[r,1] = file1
    projfiles_25000au_ratio[r,2] = file2
    projfiles_25000au_ratio[r,3] = file3
    r+=1

# %%
make_proj_allimage(imgfiles_arr=projfiles_25000au_ratio, 
                   allimagename=VICO_loc+'/PaperImages/Projs_25000au_ratio.png', 
                   scale=25000, ratio=True)

# %% [markdown]
# #### 2.6.4 PIL Figure: 4000au ratio

# %%
nrows = len(Snapshots)-1
ncols = 4
scale = 4000
projfiles_4000au_ratio = np.empty((nrows, ncols), dtype=object)
saveloc = VICO_loc+'/PaperImages/proj_images'


vmin_ionfrac, vmax_ionfrac = -3, 0       
v = len(v_mins)-1
vmin_iontemp, vmax_iontemp = 0, 7       
vmin_intensity, vmax_intensity = -3, 2.8 

r=0
for s in range(1,len(Snapshots)):
    print(Years[s])
    if(s < len(Snapshots)-1):
        file0, file1, file2, file3 = \
        proj_const_images(Snapshots[s], Masses[s], False, 
                          scale,
                    saveloc=saveloc, xlabels=False)
    else:      
        file0, file1, file2, file3 = \
        proj_const_images(Snapshots[s], Masses[s], False,
                          scale,
                    saveloc=saveloc, xlabels=True)
    projfiles_4000au_ratio[r,0] = file0
    projfiles_4000au_ratio[r,1] = file1
    projfiles_4000au_ratio[r,2] = file2
    projfiles_4000au_ratio[r,3] = file3
    r+=1

# %%
make_proj_allimage(imgfiles_arr=projfiles_4000au_ratio, 
                   allimagename=VICO_loc+'/PaperImages/Projs_4000au_ratio.png', 
                   scale=4000, ratio=True)

# %% [markdown]
# ##### *colorbars*

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/proj_images'
scale = 25000
filename = mass_ionfrac_proj_pcolormesh(Snapshots[s], Years[s], scale, v = v,
                        vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                        show_xlabels = False, show_ylabels = False,
                        show_contours = False, show_legend = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_ionfrac.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/proj_images'
scale = 25000
filename = iontemp_proj_pcolormesh(Snapshots[s], Years[s], scale, 
                        vmin=vmin_iontemp, vmax = vmax_iontemp, 
                        show_xlabels = False, show_ylabels = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_iontemp.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/proj_images'
scale = 25000
filename = intensity_proj_pcolormesh(Snapshots[s], Years[s], scale, 5,
                                     vmin=vmin_intensity_noratio, 
                                     vmax = vmax_intensity_noratio, 
                        show_xlabels = False, show_ylabels = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_intensity_noratio.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
f=5
saveloc = VICO_loc+'/PaperImages/proj_images'
scale = 25000
filename = intensity_proj_const_pcolormesh(Snapshots[s], Years[s], False, 
                                     scale, f,
                                     vmin=vmin_intensity_ratio, 
                                     vmax = vmax_intensity_ratio, 
                        show_xlabels = False, show_ylabels = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_intensity_ratio.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %% [markdown]
# # 2.7 Gifs

# %% [markdown]
# ##### 9000 years

# %%
ZoomSnapshots009 = np.array([Snap009_n, Snap010_n09, Snap011_n09, Snap012_n09, 
                          Snap013_n09, Snap014_n09, Snap015_n09, Snap016_n09, 
                          Snap017_n09, Snap018_n09, Snap019_n09])
ZoomYears009 = np.array(['9,000 yrs', '9,010 yrs', '9,020 yrs', '9,030 yrs', 
                     '9,040 yrs', '9,050 yrs', '9,060 yrs', '9,070 yrs', 
                     '9,080 yrs', '9,090 yrs', '9,100 yrs'])
ZoomScales = np.array([4000,25000])
nu_intensity=5.3*10**9
# for scale in ZoomScales:
# vmin_intensity, vmax_intensity = -4.5,-1
#     saveloc=VICO_loc+'/Gifs/009_'+str(scale)+'au_ratio'
#     for s in range(len(ZoomSnapshots009)):
#         show_ylabels=True
#         show_xlabels=True
#         intensity_const_proj_pcolormesh(ZoomSnapshots009[s], ZoomYears009[s], 
#                                         scale, vmin_intensity, 
#                                         vmax_intensity, const=False, nu = nu_intensity,
#                                         show_xlabels = show_xlabels, 
#                                         show_ylabels = show_ylabels, 
#                                         show_cbar=True, vertical_cbar=True, 
#                                         show_freq=True, cbar_pad=.02, 
#                                         saveloc=saveloc)
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -3,2.7
    saveloc=VICO_loc+'/Gifs/009_'+str(scale)+'au'
    for s in range(len(ZoomSnapshots009)):
        show_ylabels=True
        show_xlabels=True
        intensity_proj_pcolormesh(ZoomSnapshots009[s], ZoomYears009[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02, 
                                        saveloc=saveloc)

# %% [markdown]
# ##### 21000 yrs

# %%
ZoomSnapshots021 = np.array([Snap021_n, Snap022_n21, Snap023_n21, Snap024_n21, 
                             Snap025_n21, Snap026_n21, Snap027_n21, Snap028_n21, 
                             Snap029_n21, Snap030_n21, Snap031_n21])
ZoomYears021 = np.array(['21,000 yrs', '21,010 yrs', '21,020 yrs', '21,030 yrs', 
                        '21,040 yrs', '21,050 yrs', '21,060 yrs', '21,070 yrs', 
                        '21,080 yrs', '21,090 yrs', '21,100 yrs'])
ZoomScales = np.array([4000, 25000])
nu_intensity=5.3*10**9
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -5,-1
    saveloc=VICO_loc+'/Gifs/021_'+str(scale)+'au_ratio'
    for s in range(len(ZoomSnapshots021)):
        show_ylabels=True
        show_xlabels=True
        intensity_const_proj_pcolormesh(ZoomSnapshots021[s], ZoomYears021[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, const=False, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                       saveloc=saveloc)
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -3,2.7
    saveloc=VICO_loc+'/Gifs/021_'+str(scale)+'au'
    for s in range(len(ZoomSnapshots021)):
        show_ylabels=True
        show_xlabels=True
        intensity_proj_pcolormesh(ZoomSnapshots021[s], ZoomYears021[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                       saveloc=saveloc)

# %% [markdown]
# ##### 39000 yrs

# %%
ZoomSnapshots039 = np.array([Snap039_n, Snap040_n39, Snap041_n39, Snap042_n39, 
                             Snap043_n39, Snap044_n39, Snap045_n39, Snap046_n39, 
                             Snap047_n39, Snap048_n39, Snap049_n39])
ZoomYears039 = np.array(['39,000 yrs', '39,010 yrs', '39,020 yrs', '39,030 yrs', 
                        '39,040 yrs', '39,050 yrs', '39,060 yrs', '39,070 yrs', 
                        '39,080 yrs', '39,090 yrs', '39,100 yrs'])
ZoomScales = np.array([4000, 25000])
nu_intensity=5.3*10**9
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -5,-1
    saveloc=VICO_loc+'/Gifs/039_'+str(scale)+'au_ratio'
    for s in range(len(ZoomSnapshots039)):
        show_ylabels=True
        show_xlabels=True
        intensity_const_proj_pcolormesh(ZoomSnapshots039[s], ZoomYears039[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, const=False, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                        saveloc=saveloc)
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -3,2.7
    saveloc=VICO_loc+'/Gifs/039_'+str(scale)+'au'
    for s in range(len(ZoomSnapshots039)):
        show_ylabels=True
        show_xlabels=True
        intensity_proj_pcolormesh(ZoomSnapshots039[s], ZoomYears039[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                        saveloc=saveloc)

# %% [markdown]
# ##### 54000 yrs

# %%
ZoomSnapshots054 = np.array([Snap054_n, Snap055_n54, Snap056_n54, Snap057_n54, 
                             Snap058_n54, Snap059_n54, Snap060_n54, Snap061_n54, 
                             Snap062_n54, Snap063_n54, Snap064_n54])
ZoomYears054 = np.array(['54,000 yrs', '54,010 yrs', '54,020 yrs', '54,030 yrs', 
                        '54,040 yrs', '54,050 yrs', '54,060 yrs', '54,070 yrs', 
                        '54,080 yrs', '54,090 yrs', '54,100 yrs'])
ZoomScales = np.array([4000, 25000])
nu_intensity=5.3*10**9
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -5,-1
    saveloc=VICO_loc+'/Gifs/054_'+str(scale)+'au_ratio'
    for s in range(len(ZoomSnapshots054)):
        show_ylabels=True
        show_xlabels=True
        intensity_const_proj_pcolormesh(ZoomSnapshots054[s], ZoomYears054[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, const=False, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                       saveloc=saveloc)
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -3,2.7
    saveloc=VICO_loc+'/Gifs/054_'+str(scale)+'au'
    for s in range(len(ZoomSnapshots054)):
        show_ylabels=True
        show_xlabels=True
        intensity_proj_pcolormesh(ZoomSnapshots054[s], ZoomYears054[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                       saveloc=saveloc)

# %% [markdown]
# ##### 68000 yrs

# %%
ZoomSnapshots068 = np.array([Snap068_n, Snap069_n68, Snap070_n68, Snap071_n68, 
                             Snap072_n68, Snap073_n68, Snap074_n68, Snap075_n68, 
                             Snap076_n68, Snap077_n68, Snap078_n68])
ZoomYears068 = np.array(['68,000 yrs', '68,010 yrs', '68,020 yrs', '68,030 yrs', 
                        '68,040 yrs', '68,050 yrs', '68,060 yrs', '68,070 yrs', 
                        '68,080 yrs', '68,090 yrs', '68,100 yrs'])
ZoomScales = np.array([4000, 25000])
nu_intensity=5.3*10**9
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -5,-1
    saveloc=VICO_loc+'/Gifs/068_'+str(scale)+'au_ratio'
    for s in range(len(ZoomSnapshots068)):
        show_ylabels=True
        show_xlabels=True
        intensity_const_proj_pcolormesh(ZoomSnapshots068[s], ZoomYears068[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, const=False, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                       saveloc=saveloc)
        
for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -3,2.7
    saveloc=VICO_loc+'/Gifs/068_'+str(scale)+'au'
    for s in range(len(ZoomSnapshots068)):
        show_ylabels=True
        show_xlabels=True
        intensity_proj_pcolormesh(ZoomSnapshots068[s], ZoomYears068[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                       saveloc=saveloc)

# %% [markdown]
# ##### 94000 yrs

# %%
ZoomSnapshots094 = np.array([Snap106_n94, Snap107_n94, Snap108_n94, 
                             Snap109_n94, Snap110_n94, Snap111_n94, Snap112_n94, 
                             Snap113_n94, Snap114_n94, Snap115_n94, Snap116_n94])
ZoomYears094 = np.array(['94,006 yrs', '94,016 yrs', '94,026 yrs', '94,036 yrs', 
                        '94,046 yrs', '94,056 yrs', '94,066 yrs', '94,076 yrs', 
                        '94,086 yrs', '94,096 yrs', '94,106 yrs'])
ZoomScales = np.array([4000, 25000])
vmin_intensity, vmax_intensity = -5,-1
nu_intensity=5.3*10**9
for scale in ZoomScales:
    saveloc=VICO_loc+'/Gifs/094_'+str(scale)+'au_ratio'
    for s in range(len(ZoomSnapshots094)):
        show_ylabels=True
        show_xlabels=True
        intensity_const_proj_pcolormesh(ZoomSnapshots094[s], ZoomYears094[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, const=False, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                        saveloc=saveloc)

for scale in ZoomScales:
    vmin_intensity, vmax_intensity = -3,2.7
    saveloc=VICO_loc+'/Gifs/094_'+str(scale)+'au'
    for s in range(len(ZoomSnapshots094)):
        show_ylabels=True
        show_xlabels=True
        intensity_proj_pcolormesh(ZoomSnapshots094[s], ZoomYears094[s], 
                                        scale, vmin_intensity, 
                                        vmax_intensity, nu = nu_intensity,
                                        show_xlabels = show_xlabels, 
                                        show_ylabels = show_ylabels, 
                                        show_cbar=True, vertical_cbar=True, 
                                        show_freq=True, cbar_pad=.02,
                                        saveloc=saveloc)

# %% [markdown]
# ## 2.8 Zoom Intensity

# %%
def zoom_intensity_pcolormesh(Snap, year, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    ax.vlines(x=(-250,250), ymin=0, ymax=500, colors='white')
    ax.hlines(y=(0,500), xmin=-250, xmax=250, colors='white')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.tick_params(axis='x', labelsize=20)
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 14)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=14)
            cbar.ax.tick_params(rotation=45, labelsize=13)
    ax.text(.02, 1, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 25, color='white', weight='bold')
    ax.text(.02, 1, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_'+str(scale)+'AU.png' 
        fig.savefig(filename, bbox_inches='tight')
        return(filename)

# %% [markdown]
# #### PIL Image Methods

# %%
# for PIL    
def make_zoom_allimage(imgfiles_arr, allimagename):
    nrows = len(imgfiles_arr)
    ncols = len(imgfiles_arr[0]) # should be 5 for 
    side=300
    header=0
    leftax = 135
    bottomax = int((26+58)*side/231)
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side + bottomax + header))
    cropped_names = np.empty((nrows, ncols), dtype=object)

    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
            if(c==0): # y axis
                left=0
                right=width-6.25
                if(r==0): # 500au scale
                    new_x = 435-419
                else: # 4000au scale
                    new_x = 0
            else: # no y axis
                left=7.25
                new_x=c*side+(leftax)
                right=width-6.25

            if(r==nrows-1): # x axis
                bottom=height
            else: 
                bottom=height
            top=7
            new_y = r*side + header

            img = img.crop((left, top, right, bottom))
            img = img.resize((img.width*300/231), (img.height*300/231)))
            allimage.paste(img, ((new_x, new_y)))
    display(allimage)
    
    imcbar = Image.open(VICO_loc+'/PaperImages/zoom_images/cbar_vertical.png')
    
    imnew = Image.new('RGBA', (allimage.width+imcbar.width, allimage.height),
                 color='white')
    imnew.paste(allimage, (0,0))
    imnew.paste(imcbar, (allimage.width, int(allimage.height/2 - imcbar.height/2)))
    
    display(imnew)
    imnew.save(allimagename)

# %% [markdown]
# ##### Figure: 12Msun Zoomed in Intensity 54,050-54,090 yrs#

# %%
# ZoomSnapshots = np.array([Snap059_hf, Snap060_hf, Snap061_hf, Snap062_hf, Snap063_hf])
# ZoomYears = np.array(['54,050 yrs', '54,060 yrs', '54,070 yrs', '54,080 yrs', '54,090 yrs'])
ZoomSnapshots = np.array([Snap059_n54, Snap060_n54, Snap061_n54, 
                          Snap062_n54, Snap063_n54])
ZoomYears = np.array(['54,050 yrs', '54,060 yrs', '54,070 yrs', 
                      '54,080 yrs', '54,090 yrs'])
zoomslicescales = np.array([500,4000])


nrows = 2
ncols = 5
scale = slicescales[0]
zoomfiles = np.empty((nrows, ncols), dtype=object)
saveloc = VICO_loc+'/PaperImages/zoom_images'
vmin_zoom, vmax_zoom = -2,5
f=9

r=0
for scale in zoomslicescales:
    c=0
    for s in range(len(ZoomSnapshots)):
        print(ZoomYears[s])
        if(r==0): xlabels = False
        else: xlabels = True
        if(c==0): ylabels = True
        else: ylabels = False
        filename = zoom_intensity_pcolormesh(ZoomSnapshots[s],
                            ZoomYears[s], scale, f=9,
                            vmin = vmin_zoom, vmax = vmax_zoom,
                            show_xlabels=xlabels, show_ylabels=ylabels,
                                        saveloc=saveloc)
        zoomfiles[r,c] = filename
        img = Image.open(filename)
        print(img.size)
        c+=1
    r+=1

# %%
make_zoom_allimage(imgfiles_arr=zoomfiles, 
                  allimagename=VICO_loc+'/PaperImages/12MsunZoom.png')

# %% [markdown]
# ###### *colorbar*

# %%
# use Snap004_n for this
s=0
f=9
saveloc = VICO_loc+'/PaperImages/zoom_images'
filename = zoom_intensity_pcolormesh(Snapshots[s], Years[s], scale, f=f,
                          vmin=vmin_zoom, vmax=vmax_zoom,
                          show_xlabels=False, show_ylabels=False, 
                          show_cbar=True, vertical_cbar=True,
                                    saveloc=saveloc)
cbar_v_img = Image.open(filename)
print(cbar_v_img.size)
width, height = cbar_v_img.size
left = 220
right = width
top = 0
bottom = height
cbar_v_img = cbar_v_img.crop((left, top, right, bottom))
print(cbar_v_img.size)
cbar_v_filename = saveloc+'/cbar_vertical.png'
cbar_v_img.save(cbar_v_filename)
display_image(cbar_v_filename)
print(cbar_v_filename)

# %%
intensity_proj_pcolormesh(Snap061_hf, '54,070 yrs', 250,  vmin_intensity, vmax_intensity, nu = nu_intensity,
                                 show_xlabels = True, show_ylabels = False, show_cbar=False, vertical_cbar=False, show_freq=True)
surfacedensity_pcolormesh(Snap061_hf, '54,070 yrs', 250,  vmin_density, vmax_density, 
                                 show_xlabels = show_xlabels, show_ylabels = True, show_cbar=False)

# %%
avgzvelocity_pcolormesh(Snap061_hf, '54,070 yrs', 250,  vmin, vmax, 
                                 show_xlabels = True, show_ylabels = False, show_cbar=False)

# %% [markdown]
# ###### Figure: 12Msun Zoomed in Density 54,050-54,090 yrs

# %%
ZoomSnapshots = np.array([Snap054_hf, Snap055_hf, Snap056_hf, Snap057_hf, Snap058_hf, Snap059_hf, Snap060_hf, Snap061_hf, Snap062_hf, Snap063_hf])
ZoomYears = np.array(['54,000 yrs', '54,010 yrs', '54,020 yrs', '54,030 yrs', '54,040 yrs', '54,050 yrs', '54,060 yrs', '54,070 yrs', '54,080 yrs', '54,090 yrs'])
slicescales = np.array([500,2000,4000])
vmin_density, vmax_density = 0, 1
nu_intensity=230*10**9
for scale in slicescales:
    for s in range(len(ZoomSnapshots)):
        if(s==0): show_ylabels=True
        else: show_ylabels=False
        if(scale == slicescales[-1]): show_xlabels=True
        else:show_xlabels=False
        surfacedensity_pcolormesh(ZoomSnapshots[s], ZoomYears[s], scale,  vmin_density, vmax_density, 
                                 show_xlabels = show_xlabels, show_ylabels = show_ylabels, show_cbar=False)
surfacedensity_pcolormesh(ZoomSnapshots[s], ZoomYears[s], scale,  vmin_density, vmax_density, 
                                 show_xlabels = show_xlabels, show_ylabels = show_ylabels, show_cbar=True)

# %% [markdown]
# ###### Figure: 12Msun Zoomed in Velocity 54,050-54,090 yrs

# %%
ZoomSnapshots = np.array([Snap054_hf, Snap055_hf, Snap056_hf, Snap057_hf, Snap058_hf, Snap059_hf, Snap060_hf, Snap061_hf, Snap062_hf, Snap063_hf])
ZoomYears = np.array(['54,000 yrs', '54,010 yrs', '54,020 yrs', '54,030 yrs', '54,040 yrs', '54,050 yrs', '54,060 yrs', '54,070 yrs', '54,080 yrs', '54,090 yrs'])
slicescales = np.array([500,2000,4000])
vmin, vmax = 2, 3.4
nu_intensity=230*10**9
for scale in slicescales[0:2]:
    for s in range(len(ZoomSnapshots)):
        if(s==0): show_ylabels=True
        else: show_ylabels=False
        if(scale == slicescales[-1]): show_xlabels=True
        else:show_xlabels=False
        avgzvelocity_pcolormesh(ZoomSnapshots[s], ZoomYears[s], scale,  vmin, vmax, 
                                 show_xlabels = show_xlabels, show_ylabels = show_ylabels, show_cbar=False)
avgzvelocity_pcolormesh(ZoomSnapshots[s], ZoomYears[s], scale,  vmin, vmax, 
                                 show_xlabels = show_xlabels, show_ylabels = show_ylabels, show_cbar=True)

# %%
print(np.log10(np.max(Snap059_hf.q['v1'])))

# %%
# Snap059_hf.load_intensity_variables(230*10**9)
# Snap061_hf.load_intensity_variables(230*10**9)
# Snap063_hf.load_intensity_variables(230*10**9)

print('x=%.2fAU, z=%.2fAU' % (Snap061_hf.x2[141], Snap061_hf.x1[3]))
print(Snap061_hf.InuA[3,141])
print()

#note indices are printed for arrays of the limited range
print('z range = [%.2f, %.2f]' % (Snap059_hf.x1[43],Snap059_hf.x1[66]))
print('x range = [%.2f, %.2f]' % (Snap059_hf.x2[155], Snap059_hf.x2[185]))
print('54,050 yrs Max intensity = %.2f mJy/as at [i,j] = %s, [z,x] = %.2f,%.2f AU'
     % (np.max(Snap059_hf.InuA[43:66,155:185]), 
        str(np.unravel_index(Snap059_hf.InuA[43:66,155:185].argmax(), Snap059_hf.InuA[43:66,155:185].shape)),  
        Snap059_hf.x1[43:66][1],Snap059_hf.x2[155:185][24]))
print('54,090 yrs Max intensity = %.2f mJy/as at [i,j] = %s, [z,x] = %.2f,%.2f AU'
     % (np.max(Snap063_hf.InuA[43:66,155:185]), 
        str(np.unravel_index(Snap063_hf.InuA[43:66,155:185].argmax(), Snap063_hf.InuA[43:66,155:185].shape)),  
        Snap063_hf.x1[43:66][8],Snap063_hf.x2[155:185][29]))
print()
print()
#note indices are printed for arrays of the limited range
print('z range = [%.2f, %.2f]' % (Snap059_hf.x1[0],Snap059_hf.x1[66]))
print('x range = [%.2f, %.2f]' % (Snap059_hf.x2[0], Snap059_hf.x2[185]))
print('54,050 yrs Max intensity = %.2f mJy/as at [i,j] = %s, [z,x] = %.2f,%.2f AU'
     % (np.max(Snap059_hf.InuA[:66,:185]), 
        str(np.unravel_index(Snap059_hf.InuA[:66,:185].argmax(), Snap059_hf.InuA[:66,:185].shape)),  
        Snap059_hf.x1[:66][59],Snap059_hf.x2[:185][115]))
# print('54,090 yrs Max intensity = %.2f mJy/as at [i,j] = %s, [z,x] = %.2f,%.2f AU'
#      % (np.max(Snap063_hf.InuA[:66,:185]), 
#         str(np.unravel_index(Snap063_hf.InuA[:66,:185].argmax(), Snap063_hf.InuA[:66,:185].shape)),  
#         Snap063_hf.x1[:66][8],Snap063_hf.x2[:185][29]))

# %% [markdown]
# ## Check Dispersion Calculations

# %%
f = 9
s = 1
print('scale: %dAU, frequency: %.1fGHz' % (scales[s], frequencies[f]/10**9))
print('12Msun 54,000-54,100 yrs Flux in mJy', '\n', 
      Snap054_hf.ScaleFluxes[0,f,s], '\n', Snap055_hf.ScaleFluxes[0,f,s], '\n', Snap056_hf.ScaleFluxes[0,f,s], '\n',
      Snap057_hf.ScaleFluxes[0,f,s], '\n', Snap058_hf.ScaleFluxes[0,f,s], '\n', Snap059_hf.ScaleFluxes[0,f,s], '\n',
      Snap060_hf.ScaleFluxes[0,f,s], '\n', Snap061_hf.ScaleFluxes[0,f,s], '\n', Snap062_hf.ScaleFluxes[0,f,s], '\n',
      Snap063_hf.ScaleFluxes[0,f,s], '\n', Snap064_hf.ScaleFluxes[0,f,s])

# %%
## Ionization Fraction Average

# %%
# emission-weighted avg ionization fraction map
Snapshot.emis_weighted_ionfrac_plotA(year = year_str, scale= slice, levels = levels_eionfrac, saveloc=savefolder, 
                              show=True, cmap = 'winter', show_cbar=show_cbar)

# %% [markdown]
#  ## 2.7 Flux vs. Height

# %%
Snap = Snap004_n
Snap054_n.load_intensity_variables_const(5.3*10**9, False)

# %%
Snap054_n.InuA_ra

# %%
def flux_height_average(Snap, year, nu, zmin, zmax, to_print=False):
    Snap.load_intensity_variables(nu)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax]))
    height_FnuA=0
    for i in range(zmin, zmax):
        for j in range(len(Snap.x2)):
            height_FnuA += Snap.InuA[i,j] * Snap.del1[i] * Snap.del2[j] / Snap.r_cm**2 * 206264.5**2 # mJy
    return(height_FnuA)

def flux_height_average_ratio(Snap, year, nu, zmin, zmax, to_print=False):
    Snap.load_intensity_variables_const(nu, False)
    if(to_print): print('(%.1f <= z < %.1f), (%.1f <= x < %.1f), (%.1f <= y <= %.1f)' % 
                         (Snap.x1[zmin], Snap.x1[zmax]))
    height_FnuA_ratio=0
    for i in range(zmin, zmax):
        for j in range(len(Snap.x2)):
            height_FnuA_ratio += (Snap.InuA_const[i,j] 
                                  * Snap.del1[i] 
                                  * Snap.del2[j] 
                                  / Snap.r_cm**2 
                                  * 206264.5**2 ) # mJy
    return(height_FnuA_ratio) 
    
z_segments = np.array([0, 43, 66, 81, 92, 100, 108, 114, 119, 124, 
                       128, 132, 135, 139, 142, 145, 147, 150, 152, 154, 
                       156, 159, 160, 162, 164, 166, 167])
z_values = np.zeros(len(z_segments))
for i in range(len(z_segments)):
    z_values[i] = Snap009_n.x1[z_segments[i]]
# print('z segment boundaries:', z_values)


flux_heights = np.zeros(len(z_segments)-1)
for i in range(len(flux_heights)):
    flux_heights[i] = np.average([z_values[i], z_values[i+1]])
# print('heights:', ionfrac_heights)

# %%
def make_flux_profiles(Snap, Year):
    Snap.avg_flux_vs_height = np.zeros((len(frequencies), len(flux_heights)))
    for f in [5,9]:
        for i in range(25):
            Snap.avg_flux_vs_height[f,i] = flux_height_average(Snap, Year, frequencies[f], z_segments[i], z_segments[i+1])
        print('%s avg flux vs height arrays made (nu=%s)' % (Year, str(frequencies[f]/10**9)))
    
def make_flux_profiles_ratio(Snap, Year):
    Snap.avg_flux_vs_height_ratio = np.zeros((len(frequencies), len(flux_heights)))
    for f in [5,9]:
        for i in range(25):
            Snap.avg_flux_vs_height_ratio[f,i] = \
            flux_height_average_ratio(Snap, Year, frequencies[f], z_segments[i], z_segments[i+1])
        print('%s avg flux vs height ratio arrays made (nu=%s)' % (Year, str(frequencies[f]/10**9)))
    
              
def save_flux_profiles(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_flux_profile.npz'), 
             avg_flux_vs_height = Snap.avg_flux_vs_height)
def load_flux_profiles(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    file= np.load((data_path+Snap.name+'_flux_profile.npz'))
    Snap.avg_flux_vs_height = file['avg_flux_vs_height']
    print(Snap, 'flux_profile loaded')
    

def save_flux_profiles_ratio(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_flux_profile_ratio.npz'), 
             avg_flux_vs_height_ratio = Snap.avg_flux_vs_height_ratio)
def load_flux_profiles_ratio(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    file= np.load((data_path+Snap.name+'_flux_profile_ratio.npz'))
    Snap.avg_flux_vs_height_ratio = file['avg_flux_vs_height_ratio']
    print(Snap, 'flux_profile_ratio loaded')

# %%
# for s in range(len(Snapshots)):
#     print(Snapshots[s].name)
#     make_flux_profiles_ratio(Snapshots[s], Years[s])
#     save_flux_profiles_ratio(Snapshots[s])

# %%
# for s in range(len(Snapshots)):
#     print(Snapshots[s].name)
#     make_flux_profiles(Snapshots[s], Years[s])
#     save_flux_profiles(Snapshots[s])

# %%
for s in range(1,len(Snapshots)):
    load_flux_profiles(Snapshots[s])

# %%
# Add snapshot to flux vs. scale plot
def add_snap_to_flux_height_plot(snapshot, year_str, c):

    ax.plot(flux_heights[:-1], 
            np.log10(snapshot.avg_flux_vs_height[f,:-1]), 
            label = year_str, marker = 'x', 
            color=colors(c/num))    
    ax.legend(loc = 'lower right', )

        #axA.legend(bbox_to_anchor=(1.00,1.02))
    return (c + 1)

# Add snapshot to flux vs. scale plot
def add_snap_to_flux_height_ratio_plot(snapshot, year_str, c):

    ax.plot(flux_heights[:-1], 
            np.log10(snapshot.avg_flux_vs_height_ratio[f,:-1]), 
            label = year_str, marker = 'x', 
            color=colors(c/num))    
    ax.legend(loc = 'lower right', )

        #axA.legend(bbox_to_anchor=(1.00,1.02))
    return (c + 1)

# %% [markdown]
# ##### Figure: Flux vs. Height

# %%
# Plot all fluxes vs height for no ratio
# Plot Flux at Frequency of index f

for f in [5,9]:
    fig = plt.figure(figsize = (6,4))
    ax = plt.subplot()
    fig.tight_layout()
    ymin = -5
    ymax = 2

#     axA.set_title('Flux vs. Height at '+str(frequencies[f]/10**9)+'GHz', 
#                  fontsize=15)
    ax.set_xlabel('z (au)', fontsize=15)
    if(f==5):
        ax.set_ylabel(\
        r'log($S_{5.3\mathrm{GHz}}}$ / [mJy])',
                      fontsize=15)
    elif(f==9):
        ax.set_ylabel(\
        r'log($S_{230\mathrm{GHz}}}$ / [mJy])',
                      fontsize=15)
    #axA.set_aspect(3500)
    ax.set_ylim(ymin,ymax)


    colors = cm.get_cmap('rainbow_r')
    num=5
    c=0
    for s in range(1, len(Snapshots)):
        load_flux_profiles(Snapshots[s])
        c = add_snap_to_flux_height_plot(\
                            Snapshots[s], Masses[s], c)

    fig.savefig(VICO_loc+'/PaperPlots/FluxVsHeight_'+str(frequencies[f]/10**9)
                +'GHz_noratio.png', dpi=200, bbox_inches='tight')
#     fig.savefig('/home/ecg6wm/FluxVsHeight_'+str(frequencies[f]/10**9)
#                 +'GHz_noratio.png', dpi=200, bbox_inches='tight')

# %%
# Plot all fluxes vs height for ratio-scaled (cooling)
# Plot Flux at Frequency of index f

for f in [5,9]:
    fig = plt.figure(figsize = (6,4))
    ax = plt.subplot()
    fig.tight_layout()
    ymin = -7
    ymax = -1

#     axA.set_title('Flux vs. Height at '+str(frequencies[f]/10**9)+'GHz', 
#                  fontsize=15)
    ax.set_xlabel('z (au)', fontsize=15)
    if(f==5):
        ax.set_ylabel(\
        r'log($S_{5.3\mathrm{GHz}}}$ / [mJy])',
                      fontsize=15)
    elif(f==9):
        ax.set_ylabel(\
        r'log($S_{230\mathrm{GHz}}}$ / [mJy])',
                      fontsize=15)
    #axA.set_aspect(3500)
    ax.set_ylim(ymin,ymax)


    colors = cm.get_cmap('rainbow_r')
    num=5
    c=0
    for s in range(1, len(Snapshots)):
        load_flux_profiles_ratio(Snapshots[s])
        c = add_snap_to_flux_height_ratio_plot(\
                            Snapshots[s], Masses[s], c)

    fig.savefig(VICO_loc+'/PaperPlots/FluxVsHeight_'+str(frequencies[f]/10**9)
                +'GHz_ratio.png', dpi=200, bbox_inches='tight')
#     fig.savefig('PaperPlots/FluxVsHeight_'+str(frequencies[f]/10**9)
#                 +'GHz_ratio.png', dpi=200, bbox_inches='tight')

# %% [markdown]
# # 3. Flux over Time

# %%
def add_freq_to_hf_flux_time_plotA(starttime, snaps_arr, inc=10, doprint=False, linestyle='solid', nu_str=''):
    num_snaps = len(snaps_arr)
    snap_times = np.zeros(num_snaps)
    flux_over_time = np.zeros(num_snaps)
    flux_over_time_const = np.zeros(num_snaps)
    flux_over_time_ratio = np.zeros(num_snaps)
    difs = np.zeros(num_snaps-1)
    difs_const = np.zeros(num_snaps-1)
    difs_ratio = np.zeros(num_snaps-1)
    
    for n in range(num_snaps):
        snap_times[n] = starttime+(n*inc)
        flux_over_time[n] = snaps_arr[n].ScaleFluxes[0,f,s]
        flux_over_time_const[n] = snaps_arr[n].ScaleFluxes_const[f,s]
        flux_over_time_ratio[n] = snaps_arr[n].ScaleFluxes_ratio[f,s]
        if (n<num_snaps-1): 
            difs[n] = (np.abs(snaps_arr[n].ScaleFluxes[0,f,s]
                              - snaps_arr[n+1].ScaleFluxes[0,f,s])
                       /snaps_arr[n].ScaleFluxes[0,f,s])
            difs_const[n] = (np.abs(snaps_arr[n].ScaleFluxes_const[f,s]
                              - snaps_arr[n+1].ScaleFluxes_const[f,s])
                       /snaps_arr[n].ScaleFluxes_const[f,s])
            difs_ratio[n] = (np.abs(snaps_arr[n].ScaleFluxes_ratio[f,s]
                              - snaps_arr[n+1].ScaleFluxes_ratio[f,s])
                       /snaps_arr[n].ScaleFluxes_ratio[f,s])
            
    if(doprint): 
        print(snap_times)
        print(flux_over_time)
   
    axA.plot(snap_times, np.log10(flux_over_time), marker = 'o', 
             label = nu_str+str(scales[s])+' AU', color = colors((s-1)/num), 
             linestyle='dashed')
    
    axA.plot(snap_times, np.log10(flux_over_time_const), marker = 'x', 
             label = nu_str+str(scales[s])+' AU const .01', color = colors((s-1)/num), 
             linestyle='solid')
    
    axA.plot(snap_times, np.log10(flux_over_time_ratio), marker = '*', 
             label = nu_str+str(scales[s])+r' AU $t_\mathrm{cool}/t_\mathrm{flow}$', color = colors((s-1)/num), 
             linestyle='dotted')
    
    avg_log = np.average(np.log10(flux_over_time))
    avg_log_const = np.average(np.log10(flux_over_time_const))
    avg_log_ratio = np.average(np.log10(flux_over_time_ratio))
                             
    stdev_log = np.std(np.log10(flux_over_time))
    stdev_log_const = np.std(np.log10(flux_over_time_const))
    stdev_log_ratio = np.std(np.log10(flux_over_time_ratio))
                             
    difsavg = np.sum(difs)/len(difs)
    difsavg_const = np.sum(difs_const)/len(difs_const)
    difsavg_ratio = np.sum(difs_ratio)/len(difs_ratio)
    
    
    return (avg_log, avg_log_const, avg_log_ratio,
            stdev_log, stdev_log_const, stdev_log_ratio,
            difsavg, difsavg_const, difsavg_ratio)

# %% [markdown]
# #### 3.1 1.4Msun

# %%
print('frequencies', frequencies, '\nScales:', scales)

# %%
snaps_arr = np.array([Snap004_n, Snap005_n04, Snap006_n04, Snap007_n04, Snap008_n04, Snap009_n04, 
                          Snap010_n04, Snap011_n04, Snap012_n04, Snap013_n04, Snap014_n04])                   
year=4000

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'1.4M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/004_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/004_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)


for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'1.4M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %%
print(difsavg[5,1])

# %%
print(difsavg[f,s])

# %% [markdown]
# #### 3.2 2Msun

# %%
year = 9000
snaps_arr = np.array([Snap009_n, Snap010_n09, Snap011_n09, Snap012_n09, Snap013_n09, Snap014_n09, 
                          Snap015_n09, Snap016_n09, Snap017_n09, Snap018_n09, Snap019_n09])                   

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'2M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/009_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/009_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)


#just plot
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'2M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %% [markdown]
# #### 3.3 4Msun

# %%
snaps_arr = np.array([Snap021_n, Snap022_n21, Snap023_n21, Snap024_n21, Snap025_n21, Snap026_n21, 
                          Snap027_n21, Snap028_n21, Snap029_n21, Snap030_n21, Snap031_n21])                   
year = 21000

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'4M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/021_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/021_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)

# just plot
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'4M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %% [markdown]
# #### 3.4 8Msun

# %%
snaps_arr = np.array([Snap039_n, Snap040_n39, Snap041_n39, Snap042_n39, Snap043_n39, Snap044_n39, 
                          Snap045_n39, Snap046_n39, Snap047_n39, Snap048_n39, Snap049_n39])                   
year=39000

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'8M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/039_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/039_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)

# just plot
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'8M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %% [markdown]
# #### 3.5 12Msun

# %%
snaps_arr = np.array([Snap054_n, Snap055_n54, Snap056_n54, Snap057_n54, Snap058_n54, Snap059_n54, 
                          Snap060_n54, Snap061_n54, Snap062_n54, Snap063_n54, Snap064_n54])                   
year=54000

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'12M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/054_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/054_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)

# just plot
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'12M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %% [markdown]
# ##### Figure: plot of 12Msun 230 GHz flux over time

# %%
averages = np.zeros((len(frequencies), len(scales)))
stdevs = np.zeros((len(frequencies), len(scales)))
percents = np.zeros((len(frequencies), len(scales)))
logpercents = np.zeros((len(frequencies), len(scales)))
difsavg = np.zeros((len(frequencies), len(scales)))
for f in [5,9]:
    snaps_arr = np.array([Snap054_n, Snap055_n54, Snap056_n54, Snap057_n54, Snap058_n54, Snap059_n54, 
                          Snap060_n54, Snap061_n54, Snap062_n54, Snap063_n54, Snap064_n54]) 
    if(f==9): 
        linestyle= 'dotted'
        nu_str='230 GHz, '
    else: 
        linestyle = 'solid'
        fig, axA = plt.subplots(figsize = (8,6))
        nu_str='5.3 GHz, '

    fig.tight_layout()
    axA.set_title(r'12M$_{\odot}$ Flux Over Time', fontsize=16)
    ymin = .5
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
    axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2

    text_str = 'Flux Log Averages in mJy\n'
    percent_str = 'Percent Variability\n'
    for s in range(1,len(scales)):
        add_freq_to_hf_flux_time_plotA(54000, snaps_arr, linestyle=linestyle, nu_str=nu_str)
    axA.legend(bbox_to_anchor=(1.0,1.0))
#     fig.text(.93,.38,text_str, fontsize=12)
#     fig.text(.93,.125, percent_str, fontsize=12)
#     print(text_str+'\n')
    fig.savefig(VICO_loc+'/PaperPlots/054_hf_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# %%
snaps_arr = np.array([Snap054_n, Snap055_n54, Snap056_n54, Snap057_n54, Snap058_n54, Snap059_n54, 
                          Snap060_n54, Snap061_n54, Snap062_n54, Snap063_n54, Snap064_n54]) 
starttime=54000
# nu_str='230GHz'
   
num_snaps = len(snaps_arr)
snap_times = np.zeros(num_snaps)
inc=10

    

    

    

                 
for f in [5,9]:
    fig = plt.figure(figsize=(5,4))
    axA = fig.add_subplot()
    if(f==9): 
        nu_str='230 GHz, '
    else:
        nu_str='5.3 GHz, '

    axA.set_title(r'12M$_{\odot}$ Flux Over Time', fontsize=16)
    ymin = -2
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
    axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2

#     text_str = 'Flux Log Averages in mJy\n'
#     percent_str = 'Percent Variability\n'
    for s in range(1,len(scales)):
        flux_over_time = np.zeros(num_snaps)
        flux_over_time_ratio = np.zeros(num_snaps)
        for n in range(num_snaps):
            snap_times[n] = starttime+(n*inc)
            flux_over_time[n] = snaps_arr[n].ScaleFluxes[0,f,s]
            flux_over_time_ratio[n] = snaps_arr[n].ScaleFluxes_ratio[f,s]
        axA.plot(snap_times, np.log10(flux_over_time), marker = 'o', 
             label = nu_str+str(scales[s])+' AU', color = colors((s-1)/num), 
             linestyle='solid')
        axA.plot(snap_times, np.log10(flux_over_time_ratio), marker = '*', 
                 label = nu_str+str(scales[s])+r' AU $t_\mathrm{cool}/t_\mathrm{flow}$', color = colors((s-1)/num), 
                 linestyle='dotted')
    fig.tight_layout()
    axA.legend(bbox_to_anchor=(1.0,1.0))
#     fig.text(.93,.38,text_str, fontsize=12)
#     fig.text(.93,.125, percent_str, fontsize=12)
#     print(text_str+'\n')
    
    fig.savefig(VICO_loc+'/PaperPlots/12Msun_FluxVsTime_'+nu_str+'.png', 
                bbox_inches='tight')

# %%
snaps_arr = np.array([Snap054_n, Snap055_n54, Snap056_n54, Snap057_n54, Snap058_n54, Snap059_n54, 
                          Snap060_n54, Snap061_n54, Snap062_n54, Snap063_n54, Snap064_n54]) 
starttime=54000
# nu_str='230GHz'
   
num_snaps = len(snaps_arr)
snap_times = np.zeros(num_snaps)
inc=10

    

    

    

for x in [0,1]:                 
    fig = plt.figure(figsize=(5,4))
    axA = fig.add_subplot()
    for f in [5,9]:
        if(f==9): 
            nu_str='230 GHz, '
            linestyle='dashed'
        else:
            nu_str='5.3 GHz, '
            linestyle='solid'

        axA.set_title(r'12M$_{\odot}$ Flux Over Time', fontsize=16)
        axA.set_xlabel('Years', fontsize = 13)
        axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize = 13)
        #     axA.set_aspect(30)
        axA.set_ylim(ymin,ymax)
        colors = cm.get_cmap('rainbow')
        num=len(scales)-2

        #     text_str = 'Flux Log Averages in mJy\n'
        #     percent_str = 'Percent Variability\n'
        for s in range(1,len(scales)):
            flux_over_time = np.zeros(num_snaps)
            flux_over_time_ratio = np.zeros(num_snaps)
            for n in range(num_snaps):
                snap_times[n] = starttime+(n*inc)
                flux_over_time[n] = snaps_arr[n].ScaleFluxes[0,f,s]
                flux_over_time_ratio[n] = snaps_arr[n].ScaleFluxes_ratio[f,s]
            if(x==0):
                ymin = .5
                ymax = 2.5
                axA.plot(snap_times, np.log10(flux_over_time), marker = 'o', 
                     label = nu_str+str(scales[s])+' AU', color = colors((s-1)/num), 
                     linestyle=linestyle)
                file_str = 'noratio'
            else:
                ymin = -1.4
                ymax = -.3
                axA.plot(snap_times, np.log10(flux_over_time_ratio), marker = '*', 
                         label = nu_str+str(scales[s])+
                         r' AU $t_\mathrm{cool}/t_\mathrm{flow}$', 
                         color = colors((s-1)/num), 
                         linestyle=linestyle)
                file_str = 'ratio'
    fig.tight_layout()
    axA.legend(bbox_to_anchor=(1.0,1.0))
    #     fig.text(.93,.38,text_str, fontsize=12)
    #     fig.text(.93,.125, percent_str, fontsize=12)
    #     print(text_str+'\n')

    fig.savefig(VICO_loc+'/PaperPlots/12Msun_FluxVsTime_'+file_str+'.png', 
                bbox_inches='tight')

# %% [markdown]
# #### 3.6 16Msun

# %%
snaps_arr = np.array([Snap068_n, Snap069_n68, Snap070_n68, Snap071_n68, Snap072_n68, Snap073_n68, 
                          Snap074_n68, Snap075_n68, Snap076_n68, Snap077_n68, Snap078_n68])                   
year=68000

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'16M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/068_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/068_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)


#just plot
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'16M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %% [markdown]
# #### 3.7 24Msun

# %%
snaps_arr = np.array([Snap106_n94, Snap107_n94, Snap108_n94, Snap109_n94, Snap109_n94, Snap109_n94, 
                          Snap110_n94, Snap111_n94, Snap112_n94, Snap113_n94, Snap114_n94, Snap115_n94, Snap116_n94])                   
year = '94006'
year=4000

# same for each below
averages = np.zeros((len(frequencies), len(scales)))
averages_const = np.zeros((len(frequencies), len(scales)))
averages_ratio = np.zeros((len(frequencies), len(scales)))

stdevs = np.zeros((len(frequencies), len(scales)))
stdevs_const = np.zeros((len(frequencies), len(scales)))
stdevs_ratio = np.zeros((len(frequencies), len(scales)))

difsavg = np.zeros((len(frequencies), len(scales)))
difsavg_const = np.zeros((len(frequencies), len(scales)))
difsavg_ratio = np.zeros((len(frequencies), len(scales)))
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'24M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(0, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)
    
    
#     fig.savefig(VICO_loc+'/RadioEmissions/FluxTimePlots/094_n_Fnu_vs_time_'+str(frequencies[f]/10**9)+'GHz.png')

# change savez filename
np.savez(VICO_loc+'/Data/VariabilityArrays/094_n_variabilities.npz', 
         averages = averages, averages_const = averages_const, 
         averages_ratio = averages_ratio,
         stdevs = stdevs, stdevs_const = stdevs_const, 
         stdevs_ratio = stdevs_ratio, 
         difsavg = difsavg, difsavg_const = difsavg_const,
         difsavg_ratio = difsavg_ratio)


# just plot
for f in range(len(frequencies)):
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title(r'24M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux', fontsize=16)
    ymin = -1
    ymax = 2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'log($F_\nu$ / [mJy])', fontsize = 13)
#     axA.set_aspect(30)
#     axA.set_ylim(ymin,ymax)
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2   

    text_str = 'Flux Log Averages in mJy\n'
    text_str_const = 'Const Log Averages in mJy\n'
    text_str_ratio = 'Ratio Log Averages in mJy\n'
    for s in range(1, len(scales)):
        averages[f,s], averages_const[f,s], averages_ratio[f,s], \
           stdevs[f,s], stdevs_const[f,s], stdevs_ratio[f,s], \
           difsavg[f,s], difsavg_const[f,s], difsavg_ratio[f,s] \
           = add_freq_to_hf_flux_time_plotA(year, snaps_arr)
        text_str = text_str + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages[f,s], 10**stdevs[f,s]))+'\n'
        text_str_const = text_str_const + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_const[f,s], 10**stdevs_const[f,s]))+'\n'
        text_str_ratio = text_str_ratio + (u'%sAU: %.3f \u00B1 %.3f mJy' % (scales[s], 10**averages_ratio[f,s], 10**stdevs_ratio[f,s]))+'\n'
    axA.legend(bbox_to_anchor=(-.15, 1))
    axA.text(1.25,.5,text_str+'\n\n'+text_str_const+'\n\n'+text_str_ratio, 
             fontsize=12, horizontalalignment='left', verticalalignment='center', 
             transform=axA.transAxes)

# %% [markdown]
# # 4. Variability Over Time

# %%
Snap004_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/004_n_variabilities.npz', allow_pickle=True)
Snap009_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/009_n_variabilities.npz', allow_pickle=True)
Snap021_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/021_n_variabilities.npz', allow_pickle=True)
Snap039_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/039_n_variabilities.npz', allow_pickle=True)
Snap054_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/054_n_variabilities.npz', allow_pickle=True)
Snap068_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/068_n_variabilities.npz', allow_pickle=True)
Snap094_n.Variabilities = np.load(VICO_loc+'/Data/VariabilityArrays/094_n_variabilities.npz', allow_pickle=True)

# %%
print(Snap039_n.Variabilities['difsavg'])

# %% [markdown]
# #### 4.1 Average 10-year Change $\langle\Delta S_\nu / S_\nu\rangle$

# %%
# VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
# VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

# print('')
# for f in range(len(frequencies)):
#     AvgPercentDifs = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
#     for snap in range(len(VarSnapshots)):
#         AvgPercentDifs[snap] = VarSnapshots[snap].Variabilities['difsavg'] * 100

#     fig, axA = plt.subplots(figsize = (7,6))
#     fig.tight_layout()
#     axA.set_title('Average 10-Year Percent Variation in '+str(frequencies[f]/10**9)+' GHz Flux', fontsize=16)
#     ymin = .3
#     ymax = 110
#     axA.set_xlabel('Years', fontsize = 13)
#     axA.set_ylabel(r'$\langle\Delta S_\nu / S_\nu\rangle$ (%)', fontsize = 13)
# #     axA.set_aspect(2000)
#     axA.set_ylim(ymin,ymax)
#     axA.set_yscale('log')
#     colors = cm.get_cmap('rainbow')
#     num=len(scales)-2  
  
#     for s in range(1,len(scales)):
#         axA.plot(VarYears, AvgPercentDifs[:,f,s], marker = 'x', 
#              label = str(scales[s])+'AU', color = colors((s-1)/num))
#     axA.legend(bbox_to_anchor=(1,.30))
# #     axA.set_yscale('log')

# %%
# VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
# VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

# print('')
# for f in range(len(frequencies)):
#     AvgPercentDifs_const = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
#     for snap in range(len(VarSnapshots)):
#         AvgPercentDifs_const[snap] = VarSnapshots[snap].Variabilities['difsavg_const'] * 100

#     fig, axA = plt.subplots(figsize = (7,6))
#     fig.tight_layout()
#     axA.set_title('Average 10-Year Percent Variation in '+str(frequencies[f]/10**9)+' GHz Const .01 Flux', fontsize=16)
#     ymin = .3
#     ymax = 110
#     axA.set_xlabel('Years', fontsize = 13)
#     axA.set_ylabel(r'$\langle\Delta S_\nu / S_\nu\rangle$ (%)', fontsize = 13)
# #     axA.set_aspect(2000)
#     axA.set_ylim(ymin,ymax)
#     axA.set_yscale('log')
#     colors = cm.get_cmap('rainbow')
#     num=len(scales)-2  
  
#     for s in range(1,len(scales)):
#         axA.plot(VarYears, AvgPercentDifs_const[:,f,s], marker = 'x', 
#              label = str(scales[s])+'AU', color = colors((s-1)/num))
#     axA.legend(bbox_to_anchor=(1,.30))
# #     axA.set_yscale('log')

# %%
# VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
# VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

# print('')
# for f in range(len(frequencies)):
#     AvgPercentDifs_ratio = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
#     for snap in range(len(VarSnapshots)):
#         AvgPercentDifs_ratio[snap] = VarSnapshots[snap].Variabilities['difsavg_ratio'] * 100

#     fig, axA = plt.subplots(figsize = (7,6))
#     fig.tight_layout()
#     axA.set_title(r'Average 10-Year Percent Variation in '+str(frequencies[f]/10**9)+' GHz Flux $t_\mathrm{cool}/t_\mathrm{flow}$', fontsize=16)
#     ymin = .3
#     ymax = 110
#     axA.set_xlabel('Years', fontsize = 13)
#     axA.set_ylabel(r'$\langle\Delta S_\nu / S_\nu\rangle$ (%)', fontsize = 13)
# #     axA.set_aspect(2000)
#     axA.set_ylim(ymin,ymax)
#     axA.set_yscale('log')
#     colors = cm.get_cmap('rainbow')
#     num=len(scales)-2  
  
#     for s in range(1,len(scales)):
#         axA.plot(VarYears, AvgPercentDifs_ratio[:,f,s], marker = 'x', 
#              label = str(scales[s])+'AU', color = colors((s-1)/num))
#     axA.legend(bbox_to_anchor=(1,.30))
# #     axA.set_yscale('log')

# %%
# All in one

VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

print('')
for f in range(len(frequencies)):
    AvgPercentDifs = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs[snap] = VarSnapshots[snap].Variabilities['difsavg'] * 100

#     AvgPercentDifs_const = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
#     for snap in range(len(VarSnapshots)):
#         AvgPercentDifs_const[snap] = VarSnapshots[snap].Variabilities['difsavg_const'] * 100

    AvgPercentDifs_ratio = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs_ratio[snap] = VarSnapshots[snap].Variabilities['difsavg_ratio'] * 100

    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title('Average 10-Year Percent Variation in '+str(frequencies[f]/10**9)+' GHz Flux', fontsize=16)
    ymin = .3
    ymax = 110
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'$\langle\Delta S_\nu / S_\nu\rangle$ (%)', fontsize = 13)
#     axA.set_aspect(2000)
#     axA.set_ylim(ymin,ymax)
    axA.set_yscale('log')
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2  
  
    for s in range(1,len(scales)):
        axA.plot(VarYears, AvgPercentDifs[:,f,s], marker = 'o', 
             label = str(scales[s])+'AU', 
                 color = colors((s-1)/num), linestyle='solid')
#         axA.plot(VarYears, AvgPercentDifs_const[:,f,s], marker = 'x', 
#              label = str(scales[s])+'AU const .01',
#                  color = colors((s-1)/num), linestyle='solid')
        axA.plot(VarYears, AvgPercentDifs_ratio[:,f,s], marker = '*', 
             label = str(scales[s])+r'AU $t_\mathrm{cool}/t_\mathrm{flow}$', 
                 color = colors((s-1)/num), linestyle='dotted')
    # De Pree et al
    x = np.linspace(0,100000,100) # 100 linearly spaced numbers
    y = np.array(np.full(100, (40)))
    axA.plot(x, y, label = 'W49A/G2', color='black', linestyle='dashed')
    
    axA.legend(bbox_to_anchor=(1,1), loc='upper left')
#     axA.set_yscale('log')

# %% [markdown]
# 43GHz with De Pree et al

# %%
VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

for f in range(7,8):
    AvgPercentDifs = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs[snap] = VarSnapshots[snap].Variabilities['difsavg'] * 100
    AvgPercentDifs_ratio = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs_ratio[snap] = VarSnapshots[snap].Variabilities['difsavg_ratio'] * 100

    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    axA.set_title('Average 10-Year Percent Variation in '+str(frequencies[f]/10**9)+' GHz Flux', fontsize=16)
    ymin = .3
    ymax = 50
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'$\langle\Delta S_\nu / S_\nu\rangle$ (%)', fontsize = 13)
#     axA.set_aspect(2000)
    axA.set_ylim(ymin,ymax)
    axA.set_yscale('log')
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2  
  
    for s in range(1,len(scales)):
        axA.plot(VarYears, AvgPercentDifs[:,f,s], marker = 'x', 
             label = str(scales[s])+'AU', color = colors((s-1)/num))
        
    # De Pree et al
    x = np.linspace(0,100000,100) # 100 linearly spaced numbers
    y = np.array(np.full(100, (40)))
    axA.plot(x, y, label = 'W49A/G2', color='black', linestyle='dashed')
    axA.legend(bbox_to_anchor=(1,.01), loc='lower right')
#     axA.set_yscale('log')

# %% [markdown]
# 5.3GHz With all comparison points

# %%
VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

for f in range(5,6):
    AvgPercentDifs = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs[snap] = VarSnapshots[snap].Variabilities['difsavg'] * 100
    AvgPercentDifs_ratio = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs_ratio[snap] = VarSnapshots[snap].Variabilities['difsavg_ratio'] * 100

    fig, axA = plt.subplots(figsize = (6,4.5))
    fig.tight_layout()
#     axA.set_title('Average 10-Year Percent Difference in '+str(frequencies[f]/10**9)+' GHz Flux', fontsize=16)
    ymin = 10**-1.5
    
    
    
    ymax = 50
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'$\langle\Delta S_\mathrm{5.3\ GHz} / S_\mathrm{5.3\ GHz}\rangle$ (%)', fontsize = 14)
#     axA.set_aspect(2000)
    axA.set_ylim(ymin,ymax)
    axA.set_yscale('log')
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2  
  
    for s in range(1,len(scales)):
        axA.plot(VarYears, AvgPercentDifs[:,f,s], marker = 'o', 
             label = str(scales[s])+'AU', color = colors((s-1)/num))
        axA.plot(VarYears, AvgPercentDifs_ratio[:,f,s], marker = '*', 
             label = str(scales[s])+r'AU $t_\mathrm{cool}/t_\mathrm{flow}$', 
                 color = colors((s-1)/num), linestyle='dotted')
        
    # De Pree et al
    depree_lines = np.array([6.862745098, 5.04587156, 21.05263158,
                             2.53164557, 5.303030303, 38.53211009,
                             2.564102564, 8.045977011, 4.87804878])
    depree_sources = np.array(['B', 'C', 'C1', 
                               'D', 'F', 'G2', 
                               'G3', 'G4', 'G5'])
    depree_xtext = np.array([5000,5000,0,
                            0,0,0,
                            0,0,10000])
    for a in range(len(depree_lines)):
        axA.axhline(y=depree_lines[a], 
                color='dimgray', linestyle='dashed', linewidth=1)
        axA.text(depree_xtext[a],depree_lines[a]*.92, depree_sources[a], fontsize = '14')
    
    axA.plot(-1, 1000, label = 'W49A Sources \n(8.3GHz)', color='dimgray', 
             linestyle='dashed', linewidth=1)
    axA.legend(bbox_to_anchor=(1,1), loc='upper left')
    
    fig.savefig('PaperPlots/VariabilityOverTime_5.3GHz.png', dpi=300, bbox_inches='tight')
#     axA.set_yscale('log')

# %%
VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

for f in range(9,10):
    AvgPercentDifs = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs[snap] = VarSnapshots[snap].Variabilities['difsavg'] * 100
    AvgPercentDifs_ratio = np.zeros((len(VarSnapshots), len(frequencies), len(scales)))
    for snap in range(len(VarSnapshots)):
        AvgPercentDifs_ratio[snap] = VarSnapshots[snap].Variabilities['difsavg_ratio'] * 100

    fig, axA = plt.subplots(figsize = (6,4.5))
    fig.tight_layout()
#     axA.set_title('Average 10-Year Percent Difference in '+str(frequencies[f]/10**9)+' GHz Flux', fontsize=16)
    ymin = 10**-1.6
    
    
    
    ymax = 10**2.5
    axA.set_xlabel('Years', fontsize = 13)
    axA.set_ylabel(r'$\langle\Delta S_\mathrm{230\ GHz} / S_\mathrm{230\ GHz} \rangle$ (%)', fontsize = 14)
#     axA.set_aspect(2000)
    axA.set_ylim(ymin,ymax)
    axA.set_yscale('log')
    colors = cm.get_cmap('rainbow')
    num=len(scales)-2  
  
    for s in range(1,len(scales)):
        axA.plot(VarYears, AvgPercentDifs[:,f,s], marker = 'o', 
             label = str(scales[s])+'AU', color = colors((s-1)/num))
        axA.plot(VarYears, AvgPercentDifs_ratio[:,f,s], marker = '*', 
             label = str(scales[s])+r'AU $t_\mathrm{cool}/t_\mathrm{flow}$', 
                 color = colors((s-1)/num), linestyle='dotted')
        
#     # De Pree et al
#     depree_lines = np.array([6.862745098, 5.04587156, 21.05263158,
#                              2.53164557, 5.303030303, 38.53211009,
#                              2.564102564, 8.045977011, 4.87804878])
#     depree_sources = np.array(['B', 'C', 'C1', 
#                                'D', 'F', 'G2', 
#                                'G3', 'G4', 'G5'])
#     depree_xtext = np.array([5000,5000,0,
#                             0,0,0,
#                             0,0,10000])
#     for a in range(len(depree_lines)):
#         axA.axhline(y=depree_lines[a], 
#                 color='dimgray', linestyle='dashed', linewidth=1)
#         axA.text(depree_xtext[a],depree_lines[a]*.92, depree_sources[a], fontsize = '15')
    
#     axA.plot(-1, 1000, label = 'W49A Sources \n(8.3GHz)', color='dimgray', 
#              linestyle='dashed', linewidth=1)
    axA.legend(bbox_to_anchor=(1,1), loc='upper left')
#     axA.set_yscale('log')
fig.savefig('PaperPlots/VariabilityOverTime_230GHz.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### 4.2 Anglada Flux and Dispersion

# %%
VarSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, 
                         Snap039_n, Snap054_n, Snap068_n, Snap094_n])
VarYears = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  
Masses = np.array([1.4, 2, 4, 8, 12, 16, 24])

L004 = ((611.0070) + (1316.53))*1.4/(1+2)
print(L004)
Luminosities = np.array([L004,1317.5300,1317.5300,12499.000,44323.600,65461.500,84459.800])

# %%
# NEW, Flux bug corrected
# filled 
f = 5
nu = frequencies[f] # 5.3GHz


print(frequencies[f]/10**9, scales[6])
print('LogFlux and stdev(logflux)')
print('Mass \t&\t Years \t&\t Lst (Lsun) \t&\t 500AU \t\t\t&\t 1000AU \t\t\t&\t \
2000AU \t\t\t&\t 4000AU \t\t\t&\t 8000AU \t\t\t&\t 16000AU \t\t\t&\t 32000AU')
for s in range(len(VarSnapshots)):
    VarSnapshots[s].load_intensity_variables(nu)
    print(u'%.1f \t&\t%d \t&\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f  \
    \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t\\\\' 
          % (Masses[s], VarYears[s], Luminosities[s], 
                                     VarSnapshots[s].Variabilities['averages'][f,0], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,0], 
                                     VarSnapshots[s].Variabilities['averages'][f,1], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,1], 
                                     VarSnapshots[s].Variabilities['averages'][f,2], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,2], 
                                     VarSnapshots[s].Variabilities['averages'][f,3], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,3], 
                                     VarSnapshots[s].Variabilities['averages'][f,4], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,4], 
                                     VarSnapshots[s].Variabilities['averages'][f,5], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,5], 
                                     VarSnapshots[s].Variabilities['averages'][f,6],
                                     VarSnapshots[s].Variabilities['stdevs'][f,6]))
    
    
# const
print('\n\n')
print('LogFlux and stdev(logflux) using Const.01')
print('Mass \t&\t Years \t&\t Lst (Lsun) \t&\t 500AU \t\t\t&\t 1000AU \t\t\t&\t \
2000AU \t\t\t&\t 4000AU \t\t\t&\t 8000AU \t\t\t&\t 16000AU \t\t\t&\t 32000AU')
for s in range(len(VarSnapshots)):
    VarSnapshots[s].load_intensity_variables(nu)
    print(u'%.1f \t&\t%d \t&\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f  \
    \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t\\\\' % (Masses[s], VarYears[s], Luminosities[s], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,0], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,0], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,1], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,1], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,2], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,2], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,3], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,3], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,4], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,4], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,5], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,5], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,6],
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,6]))
    


# ratio
print('\n\n')
print('LogFlux and stdev(logflux) using t_cool/t_flow')
print('Mass \t&\t Years \t&\t Lst (Lsun) \t&\t 500AU \t\t\t&\t 1000AU \t\t\t&\t \
2000AU \t\t\t&\t 4000AU \t\t\t&\t 8000AU \t\t\t&\t 16000AU \t\t\t&\t 32000AU')
for s in range(len(VarSnapshots)):
    VarSnapshots[s].load_intensity_variables(nu)
    print(u'%.1f \t&\t%d \t&\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f  \
    \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t\\\\' % (Masses[s], VarYears[s], Luminosities[s], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,0], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,0], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,1], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,1], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,2], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,2], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,3], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,3], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,4], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,4], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,5], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,5], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,6],
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,6]))

# %%
# new, fluxbug fixed
f = 9
nu = frequencies[f] # 230GHz

#filled
print(frequencies[f]/10**9, scales[6])
print('LogFlux and stdev(logflux)')
print('Mass \t&\t Years \t&\t Lst (Lsun) \t&\t 500AU \t\t\t&\t 1000AU \t\t\t&\t \
2000AU \t\t\t&\t 4000AU \t\t\t&\t 8000AU \t\t\t&\t 16000AU \t\t\t&\t 32000AU')
for s in range(len(VarSnapshots)):
    VarSnapshots[s].load_intensity_variables(nu)
    print(u'%.1f \t&\t%d \t&\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f  \
    \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t\\\\' 
          % (Masses[s], VarYears[s], Luminosities[s], 
                                     VarSnapshots[s].Variabilities['averages'][f,0], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,0], 
                                     VarSnapshots[s].Variabilities['averages'][f,1], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,1], 
                                     VarSnapshots[s].Variabilities['averages'][f,2], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,2], 
                                     VarSnapshots[s].Variabilities['averages'][f,3], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,3], 
                                     VarSnapshots[s].Variabilities['averages'][f,4], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,4], 
                                     VarSnapshots[s].Variabilities['averages'][f,5], 
                                     VarSnapshots[s].Variabilities['stdevs'][f,5], 
                                     VarSnapshots[s].Variabilities['averages'][f,6],
                                     VarSnapshots[s].Variabilities['stdevs'][f,6]))
    
    
# const
print('\n\n')
print('LogFlux and stdev(logflux) using Const.01')
print('Mass \t&\t Years \t&\t Lst (Lsun) \t&\t 500AU \t\t\t&\t 1000AU \t\t\t&\t \
2000AU \t\t\t&\t 4000AU \t\t\t&\t 8000AU \t\t\t&\t 16000AU \t\t\t&\t 32000AU')
for s in range(len(VarSnapshots)):
    VarSnapshots[s].load_intensity_variables(nu)
    print(u'%.1f \t&\t%d \t&\t%f \t&\t%e \t$\pm$\t%e \t&\t%f \t$\pm$\t%f \t&\t%f  \
    \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \\\\' % (Masses[s], VarYears[s], Luminosities[s], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,0], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,0], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,1], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,1], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,2], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,2], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,3], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,3], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,4], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,4], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,5], 
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,5], 
                                     VarSnapshots[s].Variabilities['averages_const'][f,6],
                                     VarSnapshots[s].Variabilities['stdevs_const'][f,6]))
    


# ratio
print('\n\n')
print('LogFlux and stdev(logflux) using t_cool/t_flow')
print('Mass \t&\t Years \t&\t Lst (Lsun) \t&\t 500AU \t\t\t&\t 1000AU \t\t\t&\t \
2000AU \t\t\t&\t 4000AU \t\t\t&\t 8000AU \t\t\t&\t 16000AU \t\t\t&\t 32000AU')
for s in range(len(VarSnapshots)):
    VarSnapshots[s].load_intensity_variables(nu)
    print(u'%.1f \t&\t%d \t&\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f  \
    \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t&\t%f \t$\pm$\t%f \t\\\\' 
          % (Masses[s], VarYears[s], Luminosities[s], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,0], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,0], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,1], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,1], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,2], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,2], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,3], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,3], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,4], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,4], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,5], 
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,5], 
                                     VarSnapshots[s].Variabilities['averages_ratio'][f,6],
                                     VarSnapshots[s].Variabilities['stdevs_ratio'][f,6]))

# %%
print(Snap004_n.Variabilities.files)

# %% [markdown]
# #### 4.3 Average Flux vs Time

# %%
# Separate PlotsNEW fluxbug corrected
FluxSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
snap_times = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000]) 

def add_scale_to_avg_flux_time_plot(f,s,linestyle='solid', nu_str=''):
    flux_over_time = np.zeros(len(FluxSnapshots))    
    disp_over_time = np.zeros(len(FluxSnapshots))
    for snap in range(len(FluxSnapshots)):
        flux_over_time[snap] = 10**(FluxSnapshots[snap].Variabilities['averages'][f,s])
        disp_over_time[snap] = 10**(FluxSnapshots[snap].Variabilities['stdevs'][f,s])
    
    axA.errorbar(snap_times, np.log10(flux_over_time), yerr=np.log10(disp_over_time), marker = 'x', 
             label = nu_str+str(scales[s])+' AU', color = colors((s-1)/num), linestyle=linestyle, capsize=10)



# axA.set_aspect(30)
colors = cm.get_cmap('rainbow')
num=len(scales)-2  
for f in [5,9]:
    fig, axA = plt.subplots(figsize = (7,6))
    fig.tight_layout()
    # axA.set_title('12M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux Variability ', fontsize=16)
    ymin = -1.5
    ymax = 3.5
    axA.set_ylim(ymin,ymax)
    axA.set_xlabel('Years', fontsize = 13)
    if(f==5):   
        linestyle = 'solid'  
        axA.set_ylabel(r'log($S_{5.3GHz}$ / [mJy])', fontsize = 13)
    if(f==9): 
        linestyle= 'solid'  
        axA.set_ylabel(r'log($S_{230GHz}$ / [mJy])', fontsize = 13)
    for s in range(1,len(scales)):
        add_scale_to_avg_flux_time_plot(f,s, linestyle=linestyle)
    axA.legend(loc='lower right',bbox_to_anchor=(.9,0))

# %%
# On One Plots, NEW fluxbug corrected
FluxSnapshots = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n, Snap068_n, Snap094_n])
snap_times = np.array([4000, 9000, 21000, 39000, 54000, 68000, 94000])  

def add_to_flux_plot(f,s,linestyle='solid', nu_str=''):  
    flux_over_time = np.zeros(len(FluxSnapshots))    
    disp_over_time = np.zeros(len(FluxSnapshots))
    for snap in range(len(FluxSnapshots)-1):
        flux_over_time[snap] = 10**(FluxSnapshots[snap].Variabilities['averages'][f,s])
        disp_over_time[snap] = 10**(FluxSnapshots[snap].Variabilities['stdevs'][f,s])
    
    axA.errorbar(snap_times, np.log10(flux_over_time), yerr=np.log10(disp_over_time), marker = 'x', 
             label = nu_str+str(scales[s])+' AU', color = colors((s-1)/num), linestyle=linestyle, capsize=10)

def add_to_flux_plot_ratio(f,s,linestyle='solid', nu_str=''):  
    flux_over_time_ratio = np.zeros(len(FluxSnapshots))    
    disp_over_time_ratio = np.zeros(len(FluxSnapshots))
    for snap in range(len(FluxSnapshots)-1):
        flux_over_time_ratio[snap] = 10**(FluxSnapshots[snap].Variabilities['averages_ratio'][f,s])
        disp_over_time_ratio[snap] = 10**(FluxSnapshots[snap].Variabilities['stdevs_ratio'][f,s])
    
    axA.errorbar(snap_times, np.log10(flux_over_time_ratio), yerr=np.log10(disp_over_time_ratio), marker = 'x', 
             label = nu_str+str(scales[s])+' AU', color = colors((s-1)/num), linestyle=linestyle, capsize=10)

# %%
# Flux over time (noratio, both frequencies)
colors = cm.get_cmap('rainbow')
num=len(scales)-2  

fig, axA = plt.subplots(figsize = (7,6))
fig.tight_layout()
# axA.set_title('12M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux Variability ', fontsize=16)
ymin = -.5
ymax = 3.1
axA.set_ylim(ymin,ymax)
axA.set_xlabel('Years', fontsize = 13)
axA.set_ylabel(r'log($S_{\nu}$ / [mJy])', fontsize = 13)
for f in [5,9]:
    if(f==5):   
        
        linestyle = 'solid'  
        nu_str=' 5.3 GHz'
    if(f==9): 
        linestyle= 'dashed'  
        nu_str = ' 230 GHz'
    for s in range(1,len(scales)):
        add_to_flux_plot(f,s, nu_str=nu_str, linestyle=linestyle)
    axA.legend(bbox_to_anchor=(1.0,1.0))
    
fig.savefig(VICO_loc+'/PaperPlots/FluxVsTime_noratio.png', dpi=200, bbox_inches='tight')

# %%
# Flux over time (noratio, both frequencies)
colors = cm.get_cmap('rainbow')
num=len(scales)-2  

fig, axA = plt.subplots(figsize = (7,6))
fig.tight_layout()
# axA.set_title('12M$_{\odot}$ '+str(frequencies[f]/10**9)+'GHz Flux Variability ', fontsize=16)
ymin = -2.3
ymax = -.2
axA.set_ylim(ymin,ymax)
axA.set_xlabel('Years', fontsize = 13)
axA.set_ylabel(r'log($S_{\nu}$ / [mJy])', fontsize = 13)
for f in [5,9]:
    if(f==5):   
        
        linestyle = 'solid'  
        nu_str=' 5.3 GHz'
    if(f==9): 
        linestyle= 'dashed'  
        nu_str = ' 230 GHz'
    for s in range(1,len(scales)):
        add_to_flux_plot_ratio(f,s, nu_str=nu_str, linestyle=linestyle)
    axA.legend(bbox_to_anchor=(1.0,1.0))
    
fig.savefig(VICO_loc+'/PaperPlots/FluxVsTime_ratio.png', dpi=200, bbox_inches='tight')

# %% [markdown]
# # 5. Spectra (flux vs. nu)

# %%
# Add snapshot to plot of scaleflux vs freq_pres, at a given scale
freq_pres= frequencies[:]
print(freq_pres)
def add_snap_to_flux_nu_plot_pres(snapshot, label, c, show_slopes=False, m='x'):
    axA.plot(np.log10(freq_pres/10**9), np.log10(snapshot.ScaleFluxes[0,:,s]), 
             marker = m, label = label, color = colors(c/num))
    m1A,b1A = np.polyfit(np.log10(freq_pres[:2]/10**9), np.log10(snapshot.ScaleFluxes[0,:,s][:2]), 1)
    m2A,b2A = np.polyfit(np.log10(freq_pres[-2:]/10**9), np.log10(snapshot.ScaleFluxes[0,:,s][-2:]), 1)
    if(show_slopes): axA.plot(np.log10(freq_pres[:2]/10**9), m1A*np.log10(freq_pres[:2]/10**9)+b1A, '--', 
             label = ('.05-.1 GHz slope = %.4f'  % m1A), color = colors(c/num))
    if(show_slopes): axA.plot(np.log10(freq_pres[-2:]/10**9), m2A*np.log10(freq_pres[-2:]/10**9)+b2A, '--', 
             label = ('100-230 GHz slope = %.4f'  % m2A), color = colors(c/num))
    axA.legend(loc = 'upper left')
    if(c==0): print('Snapshot & %sGHz s & %sGHz s' %(str(freq_pres[:2]/10**9), str(freq_pres[-2:]/10**9)))
    if(show_slopes): print('%s & %.4f & %.4f \\\ '  % (label, m1A, m2A))
    return (c+1)

# %% [markdown]
# ##### Figure: Spectral Evolution

# %%
# NEW (fluxbug corrected)
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 1000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5

# c = add_snap_to_flux_nu_plot_pres(Snap005_hf, '5,000 yrs', c, False, m='o')
c = add_snap_to_flux_nu_plot_pres(Snap009_n, '9,000 yrs', c, False, m='v')
c = add_snap_to_flux_nu_plot_pres(Snap021_n, '21,000 yrs', c, False, m='s')
c = add_snap_to_flux_nu_plot_pres(Snap039_n, '39,000 yrs', c, False, m='x')
c = add_snap_to_flux_nu_plot_pres(Snap054_n, '54,000 yrs', c, False, m='*')
c = add_snap_to_flux_nu_plot_pres(Snap068_n, '68,000 yrs', c, False, m='d')
c = add_snap_to_flux_nu_plot_pres(Snap094_n, '94,000 yrs', c, False, m='P')
axA.legend(loc = 'upper left')

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_n_Fnu_vs_nu_1000AU.png')

# %%
# NEW, fluxbug corrected
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5

# c = add_snap_to_flux_nu_plot_pres(Snap004_n, '4,000 yrs', c, False, m='o')
c = add_snap_to_flux_nu_plot_pres(Snap009_n, '9,000 yrs', c, False, m='v')
c = add_snap_to_flux_nu_plot_pres(Snap021_n, '21,000 yrs', c, False, m='s')
c = add_snap_to_flux_nu_plot_pres(Snap039_n, '39,000 yrs', c, False, m='x')
c = add_snap_to_flux_nu_plot_pres(Snap054_n, '54,000 yrs', c, False, m='*')
c = add_snap_to_flux_nu_plot_pres(Snap068_n, '68,000 yrs', c, False, m='d')
c = add_snap_to_flux_nu_plot_pres(Snap094_n, '94,000 yrs', c, False, m='P')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ### 5.1 Spectral Indices for All

# %%
# Add snapshot to plot of scaleflux vs freq_pres, at a given scale
freq_pres= frequencies[:]
# print(freq_pres)
def all_spectral_indices(snapshot, label, print_header=False):
    axA.plot(np.log10(freq_pres/10**9), np.log10(snapshot.ScaleFluxes[0,:,s]), label = label)
    if(print_header): print('scale:', scales[s])
    header = ('[yrs] ')
    text = (label+' \t & \t')
    for f in range(len(freq_pres)-1):
        header += ('\t & \t%s-%sGHz' % (str(freq_pres[f]/10**9), str(freq_pres[f+1]/10**9)))
        m = (np.log10(snapshot.ScaleFluxes[0,f+1,s]) - np.log10(snapshot.ScaleFluxes[0,f,s]))/((np.log10(frequencies[f+1]) - np.log10(frequencies[f])))
        text += ('%.4f' % m)
        if(f<len(frequencies-2)):
            text += ' \t & \t'
    if(print_header): print(header)
    print(text)
for s in np.array([1,len(scales)-1]):
    for snap in range(len(Snapshots)):
        if(snap==0): print_header = True
        else: print_header = False
        all_spectral_indices(Snapshots[snap], Years[snap], print_header)

# %%
# with cooling ones

# Add snapshot to plot of scaleflux vs freq_pres, at a given scale
freq_pres= frequencies[:]
# print(freq_pres)
def all_spectral_indices(snapshot, label, print_header=False, 
                         ratio = False, plot=False):
    if ratio:
        fluxes_pres = snapshot.ScaleFluxes_ratio
    else:
        fluxes_pres = snapshot.ScaleFluxes[0,:,:]
    if(plot):
        axA.plot(np.log10(freq_pres/10**9), 
                 np.log10(snapshot.fluxes_pres[:,s]), 
                 label = label)
    if(print_header): print('scale:', scales[s])
    header = ('\t&\t[yrs] ')
    text = (label+' \t & \t')
    for f in range(len(freq_pres)-1):
        header += ('\t & \t%s-%sGHz' 
                   % (str(freq_pres[f]/10**9), 
                      str(freq_pres[f+1]/10**9)))
        m = ((np.log10(fluxes_pres[f+1,s]) 
              - np.log10(fluxes_pres[f,s]))
             /((np.log10(freq_pres[f+1]) 
                - np.log10(freq_pres[f]))))
        text += ('%.4f' % m)
        if(f<len(freq_pres-2)):
            text += ' \t & \t'
    text += '\\\\'
    if(print_header): print(header)
    print(text)
    
for s in np.array([1,len(scales)-1]):
    for snap in range(len(Snapshots)):
        if(snap==0): print_header = True
        else: print_header = False
        if(Snapshots[snap].name == Snap039_n.name): label = 'scale \t& \t'
        else: label = '\t & \t'
        all_spectral_indices(Snapshots[snap], label+Years[snap], 
                             print_header, ratio=False)
        
print('\n\nWith Cooling')
for s in np.array([1,len(scales)-1]):
    for snap in range(len(Snapshots)):
        if(snap==0): print_header = True
        else: print_header = False
        if(Snapshots[snap].name == Snap039_n.name): label = 'scale \t& \t'
        else: label = '\t & \t'
        all_spectral_indices(Snapshots[snap], label+Years[snap], 
                             print_header, ratio=True)

# %% [markdown]
# ###### 5.1 1.5Msun Spectra

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 1000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectra Evolution for 1.5M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap005_hf, r'5,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap006_hf, r'5,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap007_hf, r'5,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap008_hf, r'5,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap009_hf, r'5,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap010_hf, r'5,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap011_hf, r'5,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap012_hf, r'5,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap013_hf, r'5,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap014_hf, r'5,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap015_hf, r'5,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/05_hf_Fnu_vs_nu_1000AU.png')

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectra Evolution for 1.5M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap005_hf, r'5,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap006_hf, r'5,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap007_hf, r'5,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap008_hf, r'5,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap009_hf, r'5,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap010_hf, r'5,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap011_hf, r'5,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap012_hf, r'5,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap013_hf, r'5,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap014_hf, r'5,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap015_hf, r'5,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/05_hf_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ###### 5.2 2Msun Spectra

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 1000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectra Evolution for 2M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap009_sf, r'9,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap010_2hf, r'9,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap011_2hf, r'9,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap012_2hf, r'9,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap013_2hf, r'9,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap014_2hf, r'9,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap015_2hf, r'9,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap016_2hf, r'9,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap017_2hf, r'9,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap018_2hf, r'9,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap019_2hf, r'9,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/09_hf_Fnu_vs_nu_1000AU.png')

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectra Evolution for 2M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap009_sf, r'9,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap010_2hf, r'9,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap011_2hf, r'9,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap012_2hf, r'9,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap013_2hf, r'9,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap014_2hf, r'9,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap015_2hf, r'9,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap016_2hf, r'9,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap017_2hf, r'9,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap018_2hf, r'9,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap019_2hf, r'9,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/09_hf_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ###### 5.3 4Msun Spectra

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 1000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectra Evolution for 4M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap021_sf, r'21,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap022_hf, r'21,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap022_hf, r'21,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap023_hf, r'21,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap024_hf, r'21,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap025_hf, r'21,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap026_hf, r'21,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap027_hf, r'21,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap028_hf, r'21,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap029_hf, r'21,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap030_hf, r'21,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap031_hf, r'21,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/21_hf_Fnu_vs_nu_1000AU.png')

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectra Evolution for 4M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap021_sf, r'21,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap022_hf, r'21,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap023_hf, r'21,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap024_hf, r'21,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap025_hf, r'21,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap026_hf, r'21,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap027_hf, r'21,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap028_hf, r'21,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap029_hf, r'21,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap030_hf, r'21,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap031_hf, r'21,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/21_hf_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ###### 5.4 8Msun Spectra

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 1000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectra Evolution for 8M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap039_n, r'39,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap040_hf, r'39,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap041_hf, r'39,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap042_hf, r'39,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap043_hf, r'39,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap044_hf, r'39,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap045_hf, r'39,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap046_hf, r'39,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap047_hf, r'39,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap048_hf, r'39,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap049_hf, r'39,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/39_hf_Fnu_vs_nu_1000AU.png')

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectra Evolution for 8M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap039_n, r'39,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap040_hf, r'39,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap041_hf, r'39,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap042_hf, r'39,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap043_hf, r'39,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap044_hf, r'39,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap045_hf, r'39,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap046_hf, r'39,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap047_hf, r'39,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap048_hf, r'39,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap049_hf, r'39,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/39_hf_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ###### 5.5 12Msun Spectra

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 1000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectra Evolution for 12M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap054_hf, r'54,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap055_hf, r'54,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap056_hf, r'54,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap057_hf, r'54,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap058_hf, r'54,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap059_hf, r'54,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap060_hf, r'54,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap061_hf, r'54,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap062_hf, r'54,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap063_hf, r'54,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap064_hf, r'54,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/54_hf_Fnu_vs_nu_1000AU.png')

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectra Evolution for 12M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap054_hf, r'54,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap055_hf, r'54,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap056_hf, r'54,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap057_hf, r'54,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap058_hf, r'54,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap059_hf, r'54,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap060_hf, r'54,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap061_hf, r'54,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap062_hf, r'54,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap063_hf, r'54,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap064_hf, r'54,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/54_hf_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ###### 5.6 16Msun Spectra

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Inner 1000AU Spectra Evolution for 16M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap068_n, r'68,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap069_hf, r'68,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap070_hf, r'68,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap071_hf, r'68,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap072_hf, r'68,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap073_hf, r'68,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap074_hf, r'68,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap075_hf, r'68,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap076_hf, r'68,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap077_hf, r'68,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap078_hf, r'68,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/68_n_Fnu_vs_nu_1000AU.png')

# %%
# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s
s = np.where(scales == 32000)[0][0]
fig = plt.figure(figsize = (8,5))
axA = plt.subplot(1,1,1)
fig.tight_layout()
axA.set_title('Entire Snapshot Spectra Evolution for 16M$_\odot$', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
ymin = -4.2
ymax = 3


#axA.set_title('y-direction')
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($F_\nu$ / [mJy])')
#axA.set_aspect(1)
#axA.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=10

c = add_snap_to_flux_nu_plot_pres(Snap068_n, r'68,000 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap069_hf, r'68,010 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap070_hf, r'68,020 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap071_hf, r'68,030 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap072_hf, r'68,040 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap073_hf, r'68,050 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap074_hf, r'68,060 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap075_hf, r'68,070 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap076_hf, r'68,080 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap077_hf, r'68,090 yrs', c, False)
c = add_snap_to_flux_nu_plot_pres(Snap078_hf, r'68,100 yrs', c, False)

axA.legend(loc = 'upper left')

fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/68_n_Fnu_vs_nu_32000AU.png')

# %% [markdown]
# ### 5.7 Resolution Comparison

# %% [markdown]
# # 6. Cooling vs. Flow Time

# %% [markdown]
# from Draine's: $$ \tau_\mathrm{cooling} = \Big(\frac{3}{2} nkT V\Big) \Bigg/ \Bigg\{1.422\times 10^{-25} \Big[ 1 + \frac{0.44}{1 + 0.058[\ln(T/10^{5.4}Z_i^2 \mathrm{K})]^2}\Big] T_4^{1/2}Z_i^2n_in_e \frac{\mathrm{erg\ cm^3}}{\mathrm{s}} \times V \Bigg\} $$

# %% [markdown]
# Simplified:
# $$ \tau_\mathrm{cooling} = (3k_BT)\big/\Bigg[ 2 \times 1.442 \times 10^{-25} \Bigg\{ 1 + \frac{.44}{1 + 0.058\Big[\ln (\frac{T}{10^{5.4}})\Big]^2} \Bigg\} \chi_\mathrm{H_+}^2 n_\mathrm{H} \Bigg] \mathrm{[s]}$$
#
# With $k_B = 1.38064852 \times 10^{-16} \frac{\mathrm{erg}}{\mathrm{K}}$, $[T] = \mathrm{K}$, $[n_\mathrm{H}] = \mathrm{cm}^{-3}$

# %% [markdown]
# #### 6.1 *Cooling Time Functions*

# %%
def cooling_time(T, n_H, chi):
    if(T>10**5):
        C = 1.1*10**-22 # erg cm^3 s^-1
        numer = 3 * Constants.k_B * T**1.7
        denom = 2 * C * chi * n_H * 10**4.2
    else:
        D = 3.98*10**-30
        numer = (3/2) * Constants.k_B * T**-0.6
        denom = D * chi * n_H 
    if(denom == 0): 
        return np.inf
    return numer/denom

def cell_cooling_time(Snap, i, j, k):
    T = Snap.temperatures[i,j,k]
    n_H = Snap.q['d'][i,j,k] / Constants.m_H
    chi = Snap.ion_fractions[i,j,k]
    return(cooling_time(T, n_H, chi))

def calculate_cooling_times_slice(Snap):
    Snap.cooling_times_slice = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            k = Snap.mid3
            Snap.cooling_times_slice[i,j] = cell_cooling_time(Snap,i,j,k)
    print('cooling_times_slice[][] complete, units: s')
    
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_cooling_times_slice.npz'), 
             cooling_times_slice = Snap.cooling_times_slice)
    print('cooling_times_slice[][] saved, units: s')
    
def calculate_cooling_times(Snap):
    Snap.cooling_times = np.zeros((len(Snap.x1), len(Snap.x2), len(Snap.x3)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            for k in range(len(Snap.x3)):
                Snap.cooling_times[i,j,k] = cell_cooling_time(Snap,i,j,k)
    print('cooling_times[][][] complete, units: s')
    
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_cooling_times.npz'), 
             cooling_times = Snap.cooling_times)
    print('cooling_times[][][] saved, units: s')
    
def load_cooling_times_slice(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    cooling_times_file = np.load(data_path+Snap.name+'_cooling_times_slice.npz')
    Snap.cooling_times_slice = cooling_times_file['cooling_times_slice']
    
def load_cooling_times(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    cooling_times_file = np.load(data_path+Snap.name+'_cooling_times.npz')
    Snap.cooling_times = cooling_times_file['cooling_times']

# %% [markdown]
# 6.1.1 One cell tests

# %%
for i in range(len(Snap039_n.x1)):
    j=70
    k=Snap039_n.mid3
    T=Snap039_n.temperatures[i,j,k]
    if(T>1000):
        print(i,j,k, 'T=\t', Snap039_n.temperatures[i,j,k])
temp_slice_pcolormesh(Snap039_n, year='39,000 yrs', scale = 4000, vmin = 0, vmax=7, saveloc=False, 
                                     show=True, cmap='hot', show_cbar=False, show_xlabels=False, show_ylabels=False)

# %%
TestSnap = Snap039_n
i = 160
j = 70
k = 139
print('location: z = %d au, x = %d au, y = %d au' % (TestSnap.x1[i], TestSnap.x2[j], TestSnap.x3[k]))
print('T = %d K, n_H = %e cm^-3, chi = %f' % 
      (TestSnap.temperatures[i,j,k], TestSnap.q['d'][i,j,k]/Constants.m_H, 
       TestSnap.ion_fractions[i,j,k]))
print('cell cooling time = %d s = %.2f yrs' % (cell_cooling_time(TestSnap, i, j, k), cell_cooling_time(TestSnap, i, j, k)/365.25/24/3600))

# %% [markdown]
# Test Snap from 8Msun fb, max temp.
# i,j,k = 165, 178, 155

# %%
# max temp
TestSnap = Snap039_n
print(np.max(TestSnap.temperatures))
print(np.unravel_index(np.argmax(TestSnap.temperatures), TestSnap.temperatures.shape))

# %%
TestSnap = Snap039_n
i = 165
j = 178
k = 155
print('%d, %d, %d' % (i,j,k))
print('%.2f, %.2f, %.2f' % (TestSnap.x1[i], TestSnap.x2[j], TestSnap.x3[k]))
print(TestSnap.temperatures[i,j,k])
print(TestSnap.ion_fractions[i,j,k])
print(TestSnap.q['d'][i,j,k]/Constants.m_H)
print(cell_cooling_time(TestSnap,i,j,k))

# %% [markdown]
# Test Snap from 8Msun fb, ~50% ionized
# i,j,k = 156, 141, 139

# %%
# 50% ionized
TestSnap = Snap039_n
for i in range(len(TestSnap.ion_fractions[:,0,0])):z
    for j in range(len(TestSnap.ion_fractions[0,:,0])):
        k = Snap054_hf.mid3
        if(np.abs(np.abs(TestSnap.ion_fractions[i,j,k]) - .5) < .01):
            print(i,j,k, TestSnap.ion_fractions[i,j,k])

# %%
TestSnap = Snap039_n
i = 156
j = 141
k = 139
print('%d, %d, %d' % (i,j,k))
print('%.2f, %.2f, %.2f' % (TestSnap.x1[i], TestSnap.x2[j], TestSnap.x3[k]))
print(TestSnap.temperatures[i,j,k])
print(TestSnap.ion_fractions[i,j,k])
print(TestSnap.q['d'][i,j,k]/Constants.m_H)
print(cell_cooling_time(TestSnap,i,j,k))

# %% [markdown]
# Test Snap from 12Msun fb, max temp
# i,j,k = 158,187,133

# %%
# max temp
TestSnap = Snap054_n
print(np.max(TestSnap.temperatures))
print(np.unravel_index(np.argmax(TestSnap.temperatures), TestSnap.temperatures.shape))

# %%
TestSnap = Snap054_n
i = 158
j = 187
k = 133
print('%d, %d, %d' % (i,j,k))
print('%.2f, %.2f, %.2f' % (TestSnap.x1[i], TestSnap.x2[j], TestSnap.x3[k]))
print(TestSnap.temperatures[i,j,k])
print(TestSnap.ion_fractions[i,j,k])
print(TestSnap.q['d'][i,j,k]/Constants.m_H)
print(cell_cooling_time(TestSnap,i,j,k))

# %% [markdown]
# Test Snap from 12Msun fb, ~50% ionization
# i,j,k = 161, 203, 139

# %%
# 50% ionized
TestSnap = Snap054_n
for i in range(len(TestSnap.ion_fractions[:,0,0])):
    for j in range(len(TestSnap.ion_fractions[0,:,0])):
        k = Snap054_hf.mid3
        if(np.abs(np.abs(TestSnap.ion_fractions[i,j,k]) - .5) < .0014):
            print(i,j,k, TestSnap.ion_fractions[i,j,k])

# %%
TestSnap = Snap054_n
i = 161
j = 203
k = 139
print('%d, %d, %d' % (i,j,k))
print('%.2f, %.2f, %.2f' % (TestSnap.x1[i], TestSnap.x2[j], TestSnap.x3[k]))
print(TestSnap.temperatures[i,j,k])
print(TestSnap.ion_fractions[i,j,k])
print(TestSnap.q['d'][i,j,k]/Constants.m_H)
print(cell_cooling_time(TestSnap,i,j,k))

# %% [markdown]
# Snap minimum cooling time

# %%
# calculate all
print('1000 years = %d s' % (1000 * 365 * 24 * 3600)) # 1000 years as cooling time)
for Snap in Snapshots:
    print(Snap.name)
#     calculate_cooling_times_slice(Snap)
#     calculate_cooling_times(Snap)

    load_cooling_times
    load_cooling_times_slice
    
#     min_cooling_time(Snap)

# %% [markdown]
# #### 6.2 *Flow Time Functions*

# %% [markdown]
# $$ t_\mathrm{flow} = \frac{\sum_{v_{s}>0} t_{\mathrm{flow},s} v_\mathrm{n} \rho_\mathrm{n}}{v_\mathrm{n} \rho_\mathrm{n}} = \frac{\sum_{v_{s}>0} (\Delta s / v_{s}) v_\mathrm{n} \rho_\mathrm{n}}{v_\mathrm{n} \rho_\mathrm{n}}$$

# %%
### calculate value for cell ###
################################


def delta_s(Snap, face, i,j,k):
    if((face == 'm1') or (face=='p1')): return Snap.del1[i]
    elif((face == 'm2') or (face=='p2')): return Snap.del2[j]
    elif((face == 'm3') or (face == 'p3')): return Snap.del3[k]

def cell_flow_time(Snap, i,j,k):
    numer = 0
    denom = 0
    if(i>0):
        v = np.abs(Snap.vel_in('m1',i,j,k))
        ds = Snap.del1[i]
        if(v>0):
            numer += np.abs(ds/v * Snap.q['d'][i-1,j,k] * v)
            denom += np.abs(Snap.q['d'][i-1,j,k] * v)
    if(i<len(Snap.x1)-1):
        v = np.abs(Snap.vel_in('p1',i,j,k))
        ds = Snap.del1[i]
        if(v>0):
            numer += np.abs(ds/v * Snap.q['d'][i+1,j,k] * v)
            denom += np.abs(Snap.q['d'][i+1,j,k] * v)
    if(j>0):
        v = np.abs(Snap.vel_in('m2',i,j,k))
        ds = Snap.del2[j]
        if(v>0):
            numer += np.abs(ds/v * Snap.q['d'][i,j-1,k] * v)
            denom += np.abs(Snap.q['d'][i,j-1,k] * v)
    if(j<len(Snap.x2)-1):
        v = np.abs(Snap.vel_in('p2',i,j,k))
        ds = Snap.del2[j]
        if(v>0):
            numer += np.abs(ds/v * Snap.q['d'][i,j+1,k] * v)
            denom += np.abs(Snap.q['d'][i,j+1,k] * v)
    if(k>0):
        v = np.abs(Snap.vel_in('m3',i,j,k))
        ds = Snap.del3[k]
        if(v>0):
            numer += np.abs(ds/v * Snap.q['d'][i,j,k-1] * v)
            denom += np.abs(Snap.q['d'][i,j,k-1] * v)
    if(k<len(Snap.x3)-1):
        v = np.abs(Snap.vel_in('p3',i,j,k))
        ds = Snap.del3[k]
        if(v>0):
            numer += np.abs(ds/v * Snap.q['d'][i,j,k+1] * v)
            denom += np.abs(Snap.q['d'][i,j,k+1] * v) 
    # unconverted units: cm/(km/s) 
    if(denom>0 and numer>0):
        return 2*numer/denom /100/1000 # s
    else:
        return 10**-10 #no shocks in cell

### calculate for whole Snapshot ###
####################################

def calculate_flow_times_slice(Snap):
    Snap.flow_times_slice = np.zeros((len(Snap.x1), len(Snap.x2)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            k = Snap.mid3
            Snap.flow_times_slice[i,j] = cell_flow_time(Snap,i,j,k)
    print('flow_times_slice[][] complete, units: s')
    
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_flow_times_slice.npz'), 
             flow_times_slice = Snap.flow_times_slice)
    print('flow_times_slice[][] saved, units: s')
    

def calculate_flow_times(Snap):
    Snap.flow_times = np.zeros((len(Snap.x1), len(Snap.x2), len(Snap.x3)))
    for i in range(len(Snap.x1)):
        for j in range(len(Snap.x2)):
            for k in range(len(Snap.x3)):
                Snap.flow_times[i,j,k] = cell_flow_time(Snap,i,j,k)
    print('flow_times[][][] complete, units: s')
    
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_flow_times.npz'), 
             flow_times = Snap.flow_times)
    print('flow_times[][][] saved, units: s')
    
# def cell_advec_time(Snap,i,j,k):
#     t1 = np.abs(Snap.del1[i]/100/(Snap.q['v1'][i,j,k]*1000))
#     t2 = np.abs(Snap.del2[j]/100/(Snap.q['v2'][i,j,k]*1000))
#     t3 = np.abs(Snap.del3[k]/100/(Snap.q['v3'][i,j,k]*1000))
#     return(np.min([t1,t2,t3]))
                            
# def calculate_advec_times_slice(Snap):
#     Snap.advec_times_slice = np.zeros((len(Snap.x1), len(Snap.x2)))
#     for i in range(len(Snap.x1)):
#         for j in range(len(Snap.x2)):
#             k=Snap.mid3
#             Snap.advec_times_slice[i,j] = cell_advec_time(Snap,i,j,k)
#     print('advec_times_slice[][] complete, units: s')
    
#     data_path = (VICO_loc+'/Data/'+Snap.name+'/')
#     np.savez((data_path+Snap.name+'_advec_times_slice.npz'), 
#              advec_times_slice = Snap.advec_times_slice)
#     print('advec_times_slice[][] saved, units: s')
    
# def calculate_advec_times(Snap):
#     Snap.advec_times = np.zeros((len(Snap.x1), len(Snap.x2), len(Snap.x3)))
#     for i in range(len(Snap.x1)):
#         for j in range(len(Snap.x2)):
#             for k in range(len(Snap.x3)):
#                 Snap.advec_times[i,j,k] = cell_advec_time(Snap,i,j,k)
#     print('advec_times[][][] complete, units: s')
    
#     data_path = (VICO_loc+'/Data/'+Snap.name+'/')
#     np.savez((data_path+Snap.name+'_advec_times.npz'), 
#              advec_times = Snap.advec_times)
#     print('advec_times[][][] saved, units: s')
        

######## load ########
######################
def load_flow_times_slice(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    flow_times_file = np.load(data_path+Snap.name+'_flow_times_slice.npz')
    Snap.flow_times_slice = flow_times_file['flow_times_slice']
    
def load_flow_times(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    flow_times_file = np.load(data_path+Snap.name+'_flow_times.npz')
    Snap.flow_times = flow_times_file['flow_times']

def load_advec_times(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    file = np.load(data_path+Snap.name+'_advec_times.npz')
    Snap.advec_times = file['advec_times']
  
    
######## min and max of cell ########
#####################################
def min_flow_time(Snap):
    x = np.min(Snap.flow_times)
    print(Snap.name + ' min flow time = %d s = %.2f years' % (x, x/365.25/24/3600))

    
def max_flow_time(Snap):
    x = np.max(Snap.flow_times)
    print(Snap.name + ' max flow time = %d s = %.2f years' % (x, x/365.25/24/3600))

# %% [markdown]
# 6.2.1 One cell test

# %%
TestSnap = Snap039_n
i = 156
j = 141
k = TestSnap.mid3
print('location: z = %d au, x = %d au, y = %d au' % (TestSnap.x1[i], TestSnap.x2[j], TestSnap.x3[k]))
print('deltax1 = %.2f cm, deltax2 = %.2f cm, deltax3 = %.2f cm, v1 = %.2f km/s, v2 = %.2f km/s, v3 = %.2f km/s' % 
      (TestSnap.del1[i], TestSnap.del2[j], TestSnap.del3[k], TestSnap.q['v1'][i,j,k], TestSnap.q['v2'][i,j,k], TestSnap.q['v3'][i,j,k]))
print('cell flow time = %d s = %.2f yrs' % (cell_flow_time(TestSnap, i, j, k), cell_flow_time(TestSnap, i, j, k)/365.25/24/3600))

# %% [markdown]
# Test Snap from 8Msun, ~50% ionization
# 156,141,139

# %%
TestSnap = Snap039_n
i = 156
j = 141
k = 139
print(i,j,k, '%e\n' % TestSnap.temperatures[i,j,k])
# m1
print()
print(np.abs(TestSnap.vel_in('m1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i-1,j,k])
print(TestSnap.q['v1'][i-1,j,k])
# p1
print()
print(np.abs(TestSnap.vel_in('p1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i+1,j,k])
print(TestSnap.q['v1'][i+1,j,k])
# m2
print()
print(np.abs(TestSnap.vel_in('m2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j-1,k])
print(TestSnap.q['v2'][i,j-1,k])
# p2
print()
print(np.abs(TestSnap.vel_in('p2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j+1,k])
print(TestSnap.q['v2'][i,j+1,k])
# m3
print()
print(np.abs(TestSnap.vel_in('m3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k-1])
print(TestSnap.q['v3'][i,j,k-1])
# p3
print()
print(np.abs(TestSnap.vel_in('p3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k+1])
print(TestSnap.q['v3'][i,j,k+1])

print('cell flow time = %e s = %.2f yrs' % (cell_flow_time(TestSnap, i, j, k), cell_flow_time(TestSnap, i, j, k)/365.25/24/3600))

# %% [markdown]
# Test Snap from 8Msun fb, max temp.

# %%
TestSnap = Snap039_n
i = 165
j = 178
k = 155
print(i,j,k, '%e\n' % TestSnap.temperatures[i,j,k])
# m1
print()
print(np.abs(TestSnap.vel_in('m1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i-1,j,k])
print(TestSnap.q['v1'][i-1,j,k])
# p1
print()
print(np.abs(TestSnap.vel_in('p1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i+1,j,k])
print(TestSnap.q['v1'][i+1,j,k])
# m2
print()
print(np.abs(TestSnap.vel_in('m2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j-1,k])
print(TestSnap.q['v2'][i,j-1,k])
# p2
print()
print(np.abs(TestSnap.vel_in('p2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j+1,k])
print(TestSnap.q['v2'][i,j+1,k])
# m3
print()
print(np.abs(TestSnap.vel_in('m3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k-1])
print(TestSnap.q['v3'][i,j,k-1])
# p3
print()
print(np.abs(TestSnap.vel_in('p3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k+1])
print(TestSnap.q['v3'][i,j,k+1])

print('cell flow time = %e s = %.2f yrs' % (cell_flow_time(TestSnap, i, j, k), cell_flow_time(TestSnap, i, j, k)/365.25/24/3600))

# %% [markdown]
# Test Snap from 12Msun fb, max temp
# i,j,k = 158,187,133

# %%
TestSnap = Snap054_n
i = 158
j = 187
k = 133
print(i,j,k, '%e\n' % TestSnap.temperatures[i,j,k])
# m1
print('\n\n')
print(np.abs(TestSnap.vel_in('m1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i-1,j,k])
print(TestSnap.q['v1'][i-1,j,k])
# p1
print('\n\n')
print(np.abs(TestSnap.vel_in('p1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i+1,j,k])
print(TestSnap.q['v1'][i+1,j,k])
# m2
print('\n\n')
print(np.abs(TestSnap.vel_in('m2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j-1,k])
print(TestSnap.q['v2'][i,j-1,k])
# p2
print('\n\n')
print(np.abs(TestSnap.vel_in('p2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j+1,k])
print(TestSnap.q['v2'][i,j+1,k])
# m3
print('\n\n')
print(np.abs(TestSnap.vel_in('m3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k-1])
print(TestSnap.q['v3'][i,j,k-1])
# p3
print('\n\n')
print(np.abs(TestSnap.vel_in('p3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k+1])
print(TestSnap.q['v3'][i,j,k+1])

print('cell flow time = %e s = %.2f yrs' % (cell_flow_time(TestSnap, i, j, k), cell_flow_time(TestSnap, i, j, k)/365.25/24/3600))

# %% [markdown]
# Test Snap from 12Msun fb, ~50% ionization
# i,j,k = 161, 203, 139

# %%
TestSnap = Snap054_n
i = 161
j = 203
k = 139
print(i,j,k, '%e\n' % TestSnap.temperatures[i,j,k])
# m1
print('\n\n')
print(np.abs(TestSnap.vel_in('m1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i-1,j,k])
print(TestSnap.q['v1'][i-1,j,k])
# p1
print('\n\n')
print(np.abs(TestSnap.vel_in('p1', i,j,k)))
print('%e' % TestSnap.del1[i])
print(TestSnap.q['d'][i+1,j,k])
print(TestSnap.q['v1'][i+1,j,k])
# m2
print('\n\n')
print(np.abs(TestSnap.vel_in('m2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j-1,k])
print(TestSnap.q['v2'][i,j-1,k])
# p2
print('\n\n')
print(np.abs(TestSnap.vel_in('p2', i,j,k)))
print('%e' % TestSnap.del2[j])
print(TestSnap.q['d'][i,j+1,k])
print(TestSnap.q['v2'][i,j+1,k])
# m3
print('\n\n')
print(np.abs(TestSnap.vel_in('m3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k-1])
print(TestSnap.q['v3'][i,j,k-1])
# p3
print('\n\n')
print(np.abs(TestSnap.vel_in('p3', i,j,k)))
print('%e' % TestSnap.del3[k])
print(TestSnap.q['d'][i,j,k+1])
print(TestSnap.q['v3'][i,j,k+1])

print('cell flow time = %e s = %.2f yrs' % (cell_flow_time(TestSnap, i, j, k), cell_flow_time(TestSnap, i, j, k)/365.25/24/3600))

# %% [markdown]
# ###### Snap calculate, min and max flow times

# %%
# calculate all
print('1000 years = %d s' % (1000 * 365 * 24 * 3600)) # 1000 years as cooling time)
for Snap in Snapshots:
#     print(Snap.name)
    calculate_flow_times_slice(Snap)
    calculate_flow_times(Snap)
    min_flow_time(Snap)
    max_flow_time(Snap)

# %% [markdown]
# ##### *Calculate cooling and flow times*

# %%
def calculate_all_times(Snap):
    print(Snap.name)
    calculate_cooling_times_slice(Snap)
    calculate_cooling_times(Snap)
    calculate_flow_times_slice(Snap)
    calculate_flow_times(Snap)
    
# uncomment whichever you wish to calculate
for Snap in [Snap039_n]:
    print(Snap.name)
    calculate_all_times(Snap)

# %%
print(np.sum(Snap039_n.cooling_times))
print(np.sum(Snap039_n.cooling_times_slice))
print(np.sum(Snap039_n.flow_times))
print(np.sum(Snap039_n.flow_times_slice))

# %% [markdown]
# ##### *Load cooling and flow times*

# %%
# load all

def load_all_times(Snap):
    load_cooling_times(Snap)
    load_flow_times(Snap)

for Snap in [Snap039_n]:
    print(Snap.name)
    load_all_times(Snap)

# %%
load_all_times(Snap054_n)

# %% [markdown]
# ### 6.3 Mapping Methods

# %%
# plots Snap.cooling_times_slice    
def cooling_time_slice_pcolormesh(Snap, year, scale, vmin, 
                                  vmax, cmap='Blues', 
                                  saveloc=False, 
                                  show_cbar= False, 
                                  show_xlabels=True, 
                                  show_ylabels=True, 
                                  cbar_pad=.2, point1=False,
                                  point2=False, point3=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.cooling_times[:,:,Snap.mid3]/365.25/24/3600)), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(point1):
        ax.scatter(point1[0], point1[1], color='fuchsia', 
                marker='x', s=100)
    if(point2):
        ax.scatter(point2[0], point2[1], color='palegreen', 
                marker='x', s=100)
    if(point3):
        ax.scatter(point3[0], point3[1], color='gold', 
                marker='x', s=100)
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20, length=10)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20, length=10)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            extend = 'both', fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = r'log($t_\mathrm{cool}}$ / [yrs])', 
                       fontsize=18,)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
        
    ax.text(.02, .3, (r'$\mathbf{t_{cool}}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_coolingtime_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename

# plots Snap.flow_times_slice        
def flow_time_slice_pcolormesh(Snap, year, scale, vmin, vmax, 
                               cmap='Reds', saveloc=False, 
                               show_cbar= False, 
                               show_xlabels=True, 
                               show_ylabels=True, 
                               cbar_pad=.2, point1=False,
                               point2=False, point3=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.flow_times[:,:,Snap.mid3]/365.25/24/3600)), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(point1):
        ax.scatter(point1[0], point1[1], color='fuchsia', 
                marker='x', s=100)
    if(point2):
        ax.scatter(point2[0], point2[1], color='palegreen', 
                marker='x', s=100)
    if(point3):
        ax.scatter(point3[0], point3[1], color='gold', 
                marker='x', s=100)
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20, length=10)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20, length=10)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            extend = 'both', fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($t_\mathrm{flow}}$ / [yrs])'), 
                       fontsize=18,)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
        
    ax.text(.02, .3, (r'$\mathbf{t_{flow}}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_flowtime_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
        
# Plots Snap.cooling_times[:,:,Snap.mid3]/Snap.flow_times[:,:,Snap.mid3]
def time_ratio_slice_pcolormesh(Snap, year, scale, vmin, vmax,
                                cmap='RdYlGn', saveloc=False, 
                                show=False, show_cbar= False, 
                                show_xlabels=True, 
                                show_ylabels=True, cbar_pad=.2,
                               axvline=False, point1=False,
                               point2=False, point3=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.cooling_times[:,:,Snap.mid3]/Snap.flow_times[:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, norm=DivergingNorm(0), cmap = cmap, shading='nearest')
    if(point1):
        ax.scatter(point1[0], point1[1], color='fuchsia', 
                marker='x', s=100)
    if(point2):
        ax.scatter(point2[0], point2[1], color='palegreen', 
                marker='x', s=100)
    if(point3):
        ax.scatter(point3[0], point3[1], color='gold', 
                marker='x', s=100)
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20, length=10)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20, length=10)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(axvline):
        ax.axvline(x=axvline, color='fuchsia', linewidth=4)
    
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            extend = 'both', fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($t_\mathrm{cooling} / t_\mathrm{flow}$)'), 
                       fontsize=18,)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
      
    ax.text(.02, .4, (r'$\mathbf{t_{cool}}$'+'\n'+r'$\mathbf{/t_{flow}}$'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 22, weight='bold', color='white')#, alpha=.5)
    ax.text(.02, .3, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_timeratio_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# #### All Figures (8msun)

# %%
slicescales = np.array([4000, 25000])
vmin_cool = -4
vmax_cool = 3
vmin_flow = 0
vmax_flow = 4
vmin_ratio = -4
vmax_ratio = 4
Snapshots = [Snap039_n]
Years = ['39,000 yrs']
for scale in slicescales:
    for s in range(len(Snapshots)):
        ylabels = True
        xlabels = True
        cooling_time_slice_pcolormesh(Snapshots[s], Years[s], 
                                      scale, vmin_cool, vmax_cool,
                                      show_xlabels=xlabels, 
                                      show_ylabels=ylabels, 
                                      show_cbar=True, 
                                      cbar_pad=.15, 
                                      point1=(Snap039_n.x2[82],
                                            Snap039_n.x1[128]))
        flow_time_slice_pcolormesh(Snapshots[s], Years[s], scale, vmin_flow, vmax_flow, 
                                    show_xlabels=xlabels, show_ylabels=ylabels)
        time_ratio_slice_pcolormesh(Snapshots[s], Years[s], scale, vmin_ratio, vmax_ratio, 
                                    show_xlabels=xlabels, show_ylabels=ylabels, show_cbar = True, cbar_pad=.15)

# %%
for Snap in Snapshots:
    print(Snap.name +' min t_cool: %.2e' % (np.min(Snap.cooling_times_slice)/365.25/24/3600))

# %%
for Snap in Snapshots:
    print(np.log10(np.mean(Snap.cooling_times_slice)/365.25/24/3600))

# %%
# Cooling time vs. height in slice
plt.plot(Snap039_n.x1, np.log10(Snap039_n.cooling_times_slice[:,int(Snap039_n.mid2/2)]))

# %%
# max flow times for each snapshot
for Snap in Snapshots:
    print(Snap.name+' max t_flow: %.2f' % np.log10(np.max(Snap.flow_times_slice)/365.25/24/3600))

# %% [markdown]
# #### Figure t_cool/t_flow

# %%
slicescales = np.array([4000, 25000])
vmin_cool = -4
vmax_cool = 3
vmin_flow = 0
vmax_flow = 4
vmin_ratio = -4
vmax_ratio = 4

for scale in [25000]:
    for s in range(4,5):
        ylabels = False
        if(s==len(Snapshots)-1): xlabels = True
        else: xlabels = False
        time_ratio_slice_pcolormesh(Snapshots[s], Years[s], scale, vmin_ratio, vmax_ratio, 
                                    show_xlabels=xlabels, show_ylabels=ylabels, show_cbar = True, 
                                    cbar_pad=.02)
    time_ratio_slice_pcolormesh(Snapshots[s], Years[s], scale, vmin, vmax, show_xlabels=True, show_ylabels = False, show_cbar = True, cbar_pad=.13)
    emis_slice_pcolormesh(Snapshots[s], Years[s], scale, -20, 0, show_xlabels=True, show_ylabels = False, show_cbar=True, cbar_pad=.13)

# %% [markdown]
# ### PIL Image Methods

# %%
# for PIL    
def make_cooling_allimage(imgfiles_arr, allimagename):
    nrows = len(imgfiles_arr)
    ncols = len(imgfiles_arr[0]) # should be 5 for 
    side=300
    leftax = 460-side
    middleax = 395-341
    bottomax = int((58)*side/231)
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side +bottomax+middleax))
    cropped_names = np.empty((nrows, ncols), dtype=object)

    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
#             print(img.size)
#             display(img)
            
            if(r==0): # 4000 au
                bottom=height-40
                new_height = 341
                new_y = 0
            else: # 25000 au
                bottom=height
                new_height = 395
                new_y = 341
            top=7.49 

    
            if(c==0): # y axis
                left=0
                if(r==0): # 4000au scale
                    new_x = 460-440
                else: # 4000au scale
                    new_x = 0
            else: # no y axis
                left=7.49
                new_x= c*side+(leftax)
            right=width-5.5
                
            
            img = img.crop((left, top, right, bottom))
            print(img.size)
#             display(img)
            new_width = int(new_height*img.width/img.height)
            img = img.resize((new_width, new_height))
            print(img.size)
#             display(img)
            allimage.paste(img, ((new_x, new_y)))
    display(allimage)
    
    imcbar0 = Image.open(saveloc+'/cbar_coolingtime.png')
    imcbar1 = Image.open(saveloc+'/cbar_flowtime.png')
    imcbar2 = Image.open(saveloc+'/cbar_timeratio.png')
    print(imcbar0.size)
    imcbar0 = imcbar0.resize((int(side), 
                              int(imcbar0.height*side
                                  /imcbar0.width)))
    imcbar1 = imcbar1.resize((int(side), 
                              int(imcbar1.height*side
                                  /imcbar1.width)))
    imcbar2 = imcbar2.resize((int(side), 
                              int(imcbar2.height*side
                                  /imcbar2.width)))
            
    
    cbarheight = np.max((imcbar0.height, imcbar1.height, imcbar2.height))
    
    imnew = Image.new('RGBA', (allimage.width, allimage.height+cbarheight),
                 color='white')
    imnew.paste(allimage, (0,0))
    
    
    imnew.paste(imcbar0, (leftax, allimage.height))
    imnew.paste(imcbar1, (leftax+side, allimage.height))
    imnew.paste(imcbar2, (leftax+2*side, allimage.height))
    
    display(imnew)
    imnew.save(allimagename)

# %% [markdown]
# ##### 6.5.1 Figure

# %%
nrows = 2
ncols = 3
coolingfiles = np.empty((nrows, ncols), dtype=object)
saveloc = VICO_loc+'/PaperImages/cooling_images'
s=3
slicescales=np.array([4000,25000])

r=0
for scale in slicescales:
    file0 = cooling_time_slice_pcolormesh(Snapshots[s], 
                                          Masses[s], scale, 
                                          vmin_cool, vmax_cool,
                                         saveloc=saveloc,
                                         show_xlabels=True,
                                         show_ylabels=True,
                                      point1=(Snap039_n.x2[141],
                                            Snap039_n.x1[156]),
                                      point2=(Snap039_n.x2[122],
                                            Snap039_n.x1[7]),
                                      point3=(Snap039_n.x2[191],
                                            Snap039_n.x1[165])) 
    file1 = flow_time_slice_pcolormesh(Snapshots[s], 
                                          Masses[s], scale, 
                                          vmin_flow, vmax_flow,
                                         saveloc=saveloc,
                                         show_xlabels=True,
                                         show_ylabels=False,
                                      point1=(Snap039_n.x2[141],
                                            Snap039_n.x1[156]),
                                      point2=(Snap039_n.x2[122],
                                            Snap039_n.x1[7]),
                                      point3=(Snap039_n.x2[191],
                                            Snap039_n.x1[165]))
    file2 = time_ratio_slice_pcolormesh(Snapshots[s], 
                                          Masses[s], scale, 
                                          vmin_ratio, vmax_ratio,
                                         saveloc=saveloc,
                                         show_xlabels=True,
                                         show_ylabels=False,
                                      point1=(Snap039_n.x2[141],
                                            Snap039_n.x1[156]),
                                      point2=(Snap039_n.x2[122],
                                            Snap039_n.x1[7]),
                                      point3=(Snap039_n.x2[191],
                                            Snap039_n.x1[165]))
    coolingfiles[r,0] = file0
    coolingfiles[r,1] = file1
    coolingfiles[r,2] = file2    
   
    r+=1

# %%
make_cooling_allimage(imgfiles_arr=coolingfiles,
                     allimagename=VICO_loc+'/PaperImages/Cooling39.png')

# %% [markdown]
# ##### *colorbars*

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/cooling_images'
scale = 25000
filename = cooling_time_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                        vmin=vmin_cool, vmax = vmax_cool, 
                        show_xlabels = False, show_ylabels = False,
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_coolingtime.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/cooling_images'
scale = 25000
filename = flow_time_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                        vmin=vmin_flow, vmax = vmax_flow, 
                        show_xlabels = False, show_ylabels = False,
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_flowtime.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/cooling_images'
scale = 25000
filename = time_ratio_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                        vmin=vmin_ratio, vmax = vmax_ratio, 
                        show_xlabels = False, show_ylabels = False,
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_timeratio.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %% [markdown]
# ###### *finding crop and resize parameters*
# Use the following to calculate crop and resize parameters

# %%
img = Image.open(imgfiles_arr[0,0])
print(img.size)

# %%
#using xaxes
side=300

img = Image.open("/scratch/ecg6wm/VICO/PaperImages/cooling_images/Snap054_n_flowtime_25000AU.png")
display(img)
print(img.size)

width, height = img.size

middleax=(height-231)*side/231
left = 7.49
top = 7.49
right = width-5.5 # width = 231 without axes
bottom = height
img = img.crop((left, top, right, bottom))
display(img)
print(img.size)
img = img.resize((side,int(img.height*side/img.width)))
display(img)
print(img.size)
img.show()
new.show()
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
#using yaxes 25000, xaxes
side=300

img = Image.open("/scratch/ecg6wm/VICO/PaperImages/cooling_images/Snap054_n_coolingtime_25000AU.png")
display(img)
print(img.size)

width, height = img.size

left = 0
top = 7.49
right = width-5.5 # width = 231 without axes
bottom = height-40
img = img.crop((left, top, right, bottom))
display(img)
print(img.size)
img = img.resize((int(341*img.width/img.height),341))
display(img)
print(img.size)
img.show()
new.show()
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
#using x axes
new = Image.new("RGBA", (1000,1000))
side=300
img1 = Image.open("/scratch/ecg6wm/VICO/PaperImages/ionfrac_images/Snap094_n_ionfrac_emis_v100kms_4000AU.png")
print(img1.size)
width, height = img1.size
left = 7.25
top = 6.75
right = width-6.25
bottom = height
img2 = img1.crop((left, top, right, bottom))
print(img2.size)
img2 = img2.resize((side,int(side*(289-6.75)/(231-6.75-6.75))))
new.paste(img2, (0,0))
new.paste(img2, (side,side))
print(img2.size)
img1.show()
new.show()
new.save("new.png")
img1.save("img1.png")
img2.save("img2.png")
# scaled by 500/(288-36*2)
# now scale height by 500/(288-36)

# %%
test0=plt.imread("new.png")
plt.imshow(test0)
plt.axis('off')
plt.margins(x=0, y=0)

# %%
test1=plt.imread("img1.png")
plt.imshow(test1)
plt.axis('off')
plt.margins(x=0, y=0)

# %%
test2=plt.imread("img2.png")
plt.imshow(test2)
plt.axis('on')
plt.margins(x=0, y=0)

# %% [markdown]
# ##### Min Time Ratios

# %%
def min_time_ratio_slice(Snap):
    print(Snap.name, 'slice min tau_cool/tau_flow = %.2e' % 
          (np.min(Snap.cooling_times_slice / Snap.flow_times_slice)), 'at', 
           np.unravel_index(np.argmin(Snap.cooling_times_slice / Snap.flow_times_slice), np.shape(Snap.cooling_times_slice / Snap.flow_times_slice)))
def min_time_ratio(Snap):
    print(Snap.name,('min tau_cool/tau_flow = %.2e' %
          np.min(Snap.cooling_times / Snap.flow_times)), 'at', 
           np.unravel_index(np.argmin(Snap.cooling_times / Snap.flow_times), np.shape(Snap.cooling_times / Snap.flow_times)))

print('in slice:')    
for s in range(len(Snapshots)):
    min_time_ratio_slice(Snapshots[s])
print('')
# print('\nin entire simulation:')
# for s in range(len(Snapshots)):
#     min_time_ratio(Snapshots[s])
# for s in range(len(Snapshots)):
#     min_short_time_ratio(Snapshots[s])

# %% [markdown]
# ## 6.6 Plot temp, ionfrac, cooling time, flow time

# %%
from matplotlib.ticker import FormatStrFormatter
import matplotlib


def check_times_along_line(Snap, Year, j):
    k=Snap.mid3
    fig, (axL, axR) = plt.subplots(2, sharex=True)
    fig.suptitle(('%s, x = %d au, y = %d au' % (Year, Snap.x2[j], Snap.x3[k])), fontsize=14)
    
    
    # Left Subplot
    #temperature
    axL.plot(Snap054_n.x1[:], (Snap.temperatures[:,j,k]), color='green', linewidth=1)
    axL.set_xlabel('z (au)', fontsize=14)
    axL.set_ylabel('Temperature (K)', color='green', fontsize=13)
    axL.set_yscale('log')
    axL.set_ylim(10**0, 10**7)
    axL.grid(True, which='both', axis='y')
    axL.set_yticks([10**0, 10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7])
#     axL.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#     axL.get_yaxis().get_major_formatter().labelOnlyBase = False

#     axL.tick_params(axis='y', which='minor')
#     axL.yaxis.set_minor_formatter(FormatStrFormatter('%.01f'))
   
    # cooling time
    ymin = .01
    ymax=10000
    ax2=axL.twinx()
    ax2.plot(Snap.x1[:], Snap.cooling_times_slice[:,j]/365.25/24/3600, color='blue')
    ax2.set_ylabel('coooling times (yrs)', color='blue')
    ax2.set_yscale('log')
    ax2.set_ylim(ymin, ymax)
    
    # flow time
    ax3=axL.twinx()
    ax3.plot(Snap.x1[:], Snap.flow_times_slice[:,j]/365.25/24/3600, color='red')
    ax3.set_ylabel('\nflow times (yrs)', color='red')
    ax3.set_yscale('log')
    ax3.set_ylim(ymin, ymax)
    
    
    # Right Subplot
    #ionization fraction
    #temperature
    axR.plot(Snap054_n.x1[:], (Snap.ion_fractions[:,j,k]), color='orange', linewidth=1)
    axR.set_xlabel('z (au)', fontsize=14)
    axR.set_ylabel('Ionization Fraction', color='orange', fontsize=13)
    axR.set_yscale('log')
    axR.set_ylim(10**-4, 1)
    axR.grid(True, which='both', axis='y')
    axR.set_yticks([10**-4, 10**-3, 10**-2, 10**-1, 10**0])
   
    # cooling time / flow time
    ax4=axR.twinx()
    ax4.plot(Snap.x1[:], Snap.cooling_times_slice[:,j]/Snap.flow_times_slice[:,j], color='purple')
    ax4.set_ylabel('t_cool/t_flow', color='purple')
    ax4.set_yscale('log')
    ax4.set_ylim(10**-3, 10**2)
    ax4.axhline(1, color='black', label='t_cool = t_flow')
    ax4.legend()
    

    
    

    vmin = -4
    vmax = 4
    slicescales = np.array([4000, 25000])
    for scale in slicescales[1:2]:
        s=4
        time_ratio_slice_pcolormesh(Snap, Year, scale, vmin, vmax, show_xlabels=True, show_ylabels = True, show_cbar = True, cbar_pad=.13, axvline=Snapshots[s].x2[j])

# %%
check_times_along_line(Snap054_n, '54,000 yrs', 235)

# %%
check_times_along_line(Snap054_n, '54,000 yrs', 45)

# %%
check_times_along_line(Snap039_n, '39,000 yrs', 85)

# %% [markdown]
# ## 6.7 time vs temp scatter and fit

# %%
# find hot spots

# %%
Snap054_n.load_cooling_times()
Snap054_n.load_flow_times()

# %%
def time_vs_temp_arrays(Snap):
    Snap.load_cooling_times()
    Snap.load_flow_times()
    
    Snap.x_temp = np.array([])
    Snap.x_ionfrac = np.array([])
    Snap.y_cool = np.array([])
    Snap.y_flow = np.array([])
    Snap.y_ratio = np.array([])

    for i in range(len(Snap.x1)):
    #     for j in range(len(Snap.x2)):
        for j in range(len(Snap.x2)):
            for k in range(len(Snap.x3)):
                Snap.x_ionfrac = np.append(Snap.x_ionfrac, Snap.ion_fractions[i,j,k])
                Snap.x_temp = np.append(Snap.x_temp, Snap.temperatures[i,j,k]) # K
                Snap.y_cool = np.append(Snap.y_cool, Snap.cooling_times[i,j,k]/365.25/24/3600) # years
                Snap.y_flow = np.append(Snap.y_flow, Snap.flow_times[i,j,k]/365.25/24/3600) # years
                Snap.y_ratio = np.append(Snap.y_ratio, Snap.cooling_times[i,j,k]/Snap.flow_times[i,j,k])
    
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_time_vs_temp_arrays.npz'), 
             x_temp = Snap.x_temp, x_ionfrac = Snap.x_ionfrac, y_cool = Snap.y_cool, y_flow=Snap.y_flow, y_ratio=Snap.y_ratio)
    print('x_temp[], x_ionfrac[], y_cool[], y_flow[], and y_ratio[] save, units: K, none, yrs, yrs, none')

def load_time_vs_temp_arrays(Snap):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    file = np.load(data_path+Snap.name+'_time_vs_temp_arrays.npz')
    Snap.x_temp = file['x_temp']
    Snap.x_ionfrac = file['x_ionfrac']
    Snap.y_cool = file['y_cool']
    Snap.y_flow = file['y_flow']
    Snap.y_ratio = file['y_ratio']

# %%
def time_vs_temp_plots(Snap, Year):
    load_time_vs_temp_arrays(Snap)
    fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(12,10))
    plt.subplots_adjust(wspace=0, hspace=.1)
    ax1.set_title(Year, fontsize=18)


    # ax1.set_xscale('log')
    ax1.set_xlim(10**5, 10**7.2)
    ax1.set_ylabel('Time (yrs)', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
    ax1.set_ylim(10**-4, 10**6)


    ax2.set_xlabel('Temperature [K]', fontsize=14)
    ax2.set_xscale('log')
    ax2.set_ylabel('cooling time / flow time', fontsize=14)
    ax2.set_yscale('log')
    ax2.grid(True, which='both')
    ax2.axhline(1, color='black', linewidth=3)
    ax2.set_ylim(10**-6, 10**7)


    ax1.scatter(Snap.x_temp, Snap.y_cool, color='#7695E8', s=1) # light blue 
    ax1.scatter(Snap.x_temp, Snap.y_flow, color='#E39B96', s=1) # light red
    ax2.scatter(Snap.x_temp, Snap.y_ratio, color='#9F7AE3', s=1) # light purple

    # lines of best fit
    m_cool, b_cool = np.polyfit(np.log10(Snap.x_temp), np.log10(Snap.y_cool), 1)
    ax1.plot(Snap.x_temp, 10**(m_cool * np.log10(Snap.x_temp) +b_cool), color='#1E5BFF', linewidth=3) # blue
    a = 1/(10**b_cool)
    ax1.text(.5, .9, r'$t_\mathrm{cool} = (%.1E) (\frac{T}{\mathrm{K}})^{%.2f}\ \mathrm{yrs}$ ' % ((1/(10**b_cool)),m_cool),  transform = ax1.transAxes, fontsize = 18, color = '#1E5BFF')

    m_flow, b_flow = np.polyfit(np.log10(Snap.x_temp), np.log10(Snap.y_flow), 1)
    ax1.plot(Snap.x_temp, 10**(m_flow * np.log10(Snap.x_temp) +b_flow), color='#F62C26', linewidth=3) # red
    ax1.text(.5, .3, r'$t_\mathrm{flow} = (%.1E) (\frac{T}{\mathrm{K}})^{%.2f}\ \mathrm{yrs}$ ' % ((1/(10**b_flow)),m_flow),  transform = ax1.transAxes, fontsize = 18, color = '#F62C26')


    m_ratio, b_ratio = np.polyfit(np.log10(Snap.x_temp), np.log10(Snap.y_ratio), 1)
    ax2.plot(Snap.x_temp, 10**(m_ratio * np.log10(Snap.x_temp) +b_ratio), color='#7D38FC', linewidth=3) # purple
    ax2.text(.5, .82, r'$\frac{t_\mathrm{cool}}{t_\mathrm{flow}} = (%.1E) (\frac{T}{\mathrm{K}})^{%.2f}$ ' % ((1/(10**b_ratio)),m_ratio),  transform = ax2.transAxes, fontsize = 22, color = '#7D38FC')

#     idx = np.argwhere(np.diff(np.sign((10**(m_ratio * np.log10(Snap.x_temp) +b_ratio)) - 1.00))).flatten()
#     T = Snap.x_temp[idx]
# #     ax2.plot(Snap.x_temp[idx], Snap.y_ratio[idx], 'ro')
    T = 10**(-b_ratio/m_ratio)
    ax2.scatter(T, 10**(m_ratio * np.log10(T) +b_ratio), color='black', marker='X', s=100)


    print(Snap.name, 'Intersection near %d K' % T)
    print('Ratio = %e' % 10**(m_ratio * np.log10(T) +b_ratio))

# %%
# calculate and save time vs. temperature and ionfrac arrays
for Snap in Snapshots:
    print(Snap.name)
    time_vs_temp_arrays(Snap)
print(Snap009_hrfb.name)
    time_vs_temp_arrays(Snap009_hrfb)

# %%
# make plots
for s in range(len(Snapshots[:-1])):
    time_vs_temp_plots(Snapshots[s], Years[s])

# %%
def time_vs_temp_and_ionfrac_plots(Snap, Year):
    load_time_vs_temp_arrays(Snap)
    fig, (ax1, ax2) = plt.subplots(2, sharex=False, figsize=(12,10))
    plt.subplots_adjust(wspace=0, hspace=.2)
    ax1.set_title(Year, fontsize=18)


    # ax1.set_xscale('log')
    ax1.set_xlabel('Temperature [K]', fontsize=14)
    ax1.set_xlim(10**5, 10**7.2)
    ax1.set_xscale('log')
    ax1.set_ylabel('cooling time / flow time', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
    ax1.set_ylim(10**-4, 10**6)


    ax2.set_xlabel('Ionization Fraction', fontsize=14)
#     ax2.set_xscale('log')
    ax2.set_xlim(0,1)
    ax2.set_ylabel('cooling time / flow time', fontsize=14)
    ax2.set_yscale('log')
    ax2.grid(True, which='both')
    ax2.set_ylim(10**-6, 10**7)


#     ax1.scatter(Snap.x_temp, Snap.y_cool, color='#7695E8', s=1) # light blue 
#     ax1.scatter(Snap.x_temp, Snap.y_flow, color='#E39B96', s=1) # light red
    ax1.scatter(Snap.x_temp, Snap.y_ratio, color='#9F7AE3', s=1) # light purple

    
#     ax2.scatter(Snap.x_ionfrac, Snap.y_cool, color='#7695E8', s=1) # light blue
#     ax2.scatter(Snap.x_ionfrac, Snap.y_flow, color='#E39B96', s=1) # light red
    ax2.scatter(Snap.x_ionfrac, Snap.y_ratio, color='#9F7AE3', s=1) # light purple


    # lines of best fit
#     m_cool, b_cool = np.polyfit(np.log10(Snap.x_temp), np.log10(Snap.y_cool), 1)
#     ax1.plot(Snap.x_temp, 10**(m_cool * np.log10(Snap.x_temp) +b_cool), color='#1E5BFF', linewidth=3) # blue
#     a = 1/(10**b_cool)
#     ax1.text(.5, .9, r'$t_\mathrm{cool} = (%.1E) (\frac{T}{\mathrm{K}})^{%.2f}\ \mathrm{yrs}$ ' % ((1/(10**b_cool)),m_cool),  transform = ax1.transAxes, fontsize = 18, color = '#1E5BFF')

#     m_flow, b_flow = np.polyfit(np.log10(Snap.x_temp), np.log10(Snap.y_flow), 1)
#     ax1.plot(Snap.x_temp, 10**(m_flow * np.log10(Snap.x_temp) +b_flow), color='#F62C26', linewidth=3) # red
#     ax1.text(.5, .3, r'$t_\mathrm{flow} = (%.1E) (\frac{T}{\mathrm{K}})^{%.2f}\ \mathrm{yrs}$ ' % ((1/(10**b_flow)),m_flow),  transform = ax1.transAxes, fontsize = 18, color = '#F62C26')


#     idx = np.argwhere(np.diff(np.sign((10**(m_ratio * np.log10(Snap.x_temp) +b_ratio)) - 1.00))).flatten()
#     T = Snap.x_temp[idx]
# #     ax2.plot(Snap.x_temp[idx], Snap.y_ratio[idx], 'ro')
#     T = 10**(-b_ratio/m_ratio)
#     ax2.scatter(T, 10**(m_ratio * np.log10(T) +b_ratio), color='black', marker='X', s=100)


#     print(Snap.name, 'Intersection near %d K' % T)
#     print('Ratio = %e' % 10**(m_ratio * np.log10(T) +b_ratio))

# %%
for s in range(len(Snapshots)):
    time_vs_temp_and_ionfrac_plots(Snapshots[s], Years[s])

# %%
def ionfrac_vs_temp_plots(Snap, Year):
    load_time_vs_temp_arrays(Snap)
    fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=False, figsize=(12,10))
    plt.subplots_adjust(wspace=0, hspace=.2)
    ax1.set_title(Year, fontsize=18)


    # ax1.set_xscale('log')
    ax1.set_xlabel('Temperature [K]', fontsize=14)
    ax1.set_xlim(10**5, 10**7.2)
    ax1.set_xscale('log')
    ax1.set_ylabel('cooling time / flow time', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
    ax1.set_ylim(10**-4, 10**6)


    ax2.set_xlabel('Ionization Fraction', fontsize=14)
#     ax2.set_xscale('log')
    ax2.set_xlim(0,1)
    ax2.set_ylabel('cooling time / flow time', fontsize=14)
    ax2.set_yscale('log')
    ax2.grid(True, which='both')
    ax2.set_ylim(10**-6, 10**7)
    
    ax3.set_xlabel('Temperature', fontsize=14)
    ax3.set_xscale('log')
    ax3.set_ylabel('Ionization Fraction', fontsize=14)
    ax3.set_yscale('log')


#     ax1.scatter(Snap.x_temp, Snap.y_cool, color='#7695E8', s=1) # light blue 
#     ax1.scatter(Snap.x_temp, Snap.y_flow, color='#E39B96', s=1) # light red
    ax1.scatter(Snap.x_temp, Snap.y_ratio, color='#9F7AE3', s=1) # light purple

    
#     ax2.scatter(Snap.x_ionfrac, Snap.y_cool, color='#7695E8', s=1) # light blue
#     ax2.scatter(Snap.x_ionfrac, Snap.y_flow, color='#E39B96', s=1) # light red
    ax2.scatter(Snap.x_ionfrac, Snap.y_ratio, color='#9F7AE3', s=1) # light purple

    ax3.scatter(Snap.x_temp, Snap.x_ionfrac, color = 'gray', s=1)

# %%
for s in range(len(Snapshots)):
    ionfrac_vs_temp_plots(Snapshots[s], Years[s])

# %% [markdown]
# ##### including advection times

# %%
def advectime_plots(Snap, Year):
#     load_time_vs_temp_arrays(Snap)
    load_cooling_times(Snap)
    load_flow_times(Snap)
    load_advec_times(Snap)
    
    fig, (ax1) = plt.subplots(figsize=(12,10))
#     plt.subplots_adjust(wspace=0, hspace=.1)
    ax1.set_title(Year, fontsize=18)


    ax1.set_xscale('log')
    ax1.set_xlim(10**2, 10**7.2)
    ax1.set_xscale('log')
    ax1.set_xlabel('Temperature (K)')
    ax1.set_ylabel('Time (yrs)', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
    ax1.set_ylim(10**-7, 10**10)


#     ax2.set_xlabel('Temperature [K]', fontsize=14)
#     ax2.set_xscale('log')
#     ax2.set_ylabel('cooling time / flow time', fontsize=14)
#     ax2.set_yscale('log')
#     ax2.grid(True, which='both')
#     ax2.axhline(1, color='black', linewidth=3)
#     ax2.set_ylim(10**-6, 10**7)


    ax1.scatter(Snap.temperatures.flatten(), Snap.flow_times.flatten()/365.25/24/3600, color='#E39B96', s=1, label='compression time') # light red
    ax1.scatter(Snap.temperatures.flatten(), Snap.advec_times.flatten()/365.25/24/3600, color='orange', s=1, label='advection time') # light red
    ax1.scatter(Snap.temperatures.flatten(), Snap.cooling_times.flatten()/365.25/24/3600, color='#7695E8', s=1, label='cooling time') # light blue 
   
    ax1.legend()
#     print(Snap.name, 'Intersection near %d K' % T)
#     print('Ratio = %e' % 10**(m_ratio * np.log10(T) +b_ratio))
for s in range(len(Snapshots)):
    advectime_plots(Snapshots[s], Years[s])

# %%
for snap in Snapshots:
    calculate_cooling_times3(snap)

# %% [markdown]
# ## 6.8  Luminosity vs. Temp

# %% [markdown]
# ##### luminosity array functions

# %%
def luminosity_array(Snap, nu):
    Snap.load_intensity_variables(nu)
    Snap.luminosities = np.zeros((len(Snap.x1), len(Snap.x2), len(Snap.x3)))

    for i in range(len(Snap.x1)):
    #     for j in range(len(Snap.x2)):
        for j in range(len(Snap.x2)):
            for k in range(len(Snap.x3)):
                Snap.luminosities[i,j,k] = 4*np.pi * Snap.emission_coefs[i,j,k]*Snap.del1[i]*Snap.del2[j]*Snap.del3[k]
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_'+str(nu/10**9)+'_luminosity_only.npz'), 
             luminosities = Snap.luminosities)
                                
    Snap.ordered_temp = Snap.temperatures.flatten()
    Snap.ordered_lum = Snap.luminosities.flatten()
    
    Snap.ordered_temp, Snap.ordered_lum = zip(*sorted(zip(Snap.ordered_temp, Snap.ordered_lum)))
    Snap.cum_lum = np.cumsum(Snap.ordered_lum)
    Snap.cum_lum_rev = np.cumsum(Snap.ordered_lum[::-1])[::-1] 
    Snap.cum_lum_percent = Snap.cum_lum/np.max(Snap.cum_lum)
    Snap.cum_lum_rev_percent = Snap.cum_lum_rev/np.max(Snap.cum_lum)

    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    np.savez((data_path+Snap.name+'_'+str(nu/10**9)+'_luminosity_array.npz'), 
             ordered_temp = Snap.ordered_temp, 
             ordered_lum = Snap.ordered_lum, 
             cum_lum = Snap.cum_lum, cum_lum_rev = Snap.cum_lum_rev)
                    

def load_luminosity(Snap, nu):
    data_path = (VICO_loc+'/Data/'+Snap.name+'/')
    file1 = np.load(data_path+Snap.name+'_'+str(nu/10**9)+'_luminosity_only.npz')
    file2 = np.load(data_path+Snap.name+'_'+str(nu/10**9)+'_luminosity_array.npz')
    Snap.luminosities = file1['luminosities']
    Snap.ordered_temp = file2['ordered_temp']
    Snap.ordered_lum = file2['ordered_lum'] 
    Snap.cum_lum = file2['cum_lum']
    Snap.cum_lum_rev = file2['cum_lum_rev']
    Snap.cum_lum_percent = Snap.cum_lum/np.max(Snap.cum_lum)
    Snap.cum_lum_rev_percent = Snap.cum_lum_rev/np.max(Snap.cum_lum)

# %%
Snap=Snap054_n
luminosity_array(Snap054_n, 5.3*10**9)

# %%
# plt.scatter(Snap.temperatues, Snap.luminosities)
# plt.plot(Snap.ordered_temp, Snap.cum_lum)
# plt.grid

# %%
Snap=Snap054_n
load_luminosity(Snap054_n, 5.3*10**9)
plt.scatter(Snap.temperatures, Snap.luminosities)
plt.plot(Snap.ordered_temp, Snap.cumulative_lum)
plt.grid

# %% [markdown]
# ##### Test cumulative luminosity calculations

# %%
temperatures = np.array([[5, 2, 1], [3, 4, 7]])
luminosities = np.array([[.5, .1, 0], [.15, .1, 1]])
print('original')
print(temperatures)
print(luminosities)

ordered_temp = temperatures.flatten()
ordered_lum = luminosities.flatten()
print('\nflattened')
print(ordered_temp)
print(ordered_lum)

ordered_temp, ordered_lum = zip(*sorted(zip(ordered_temp, ordered_lum)))
print('\nordered')
print(ordered_temp)
print(ordered_lum)

cumulative_lum = np.zeros(len(ordered_lum))
for i in range(len(ordered_lum)):
    cumulative_lum[i] = np.sum(ordered_lum[:i+1])
print('\ncumulative lum')
print(ordered_temp)
print(cumulative_lum) 
plt.plot(ordered_temp, cumulative_lum)
plt.scatter(temperatures, luminosities)
plt.grid()

# %% [markdown]
# ##### calculate/load luminosity arrays

# %%
nu = 5.3*10**9
# for s in range(len(Snapshots)):
#     print(Snapshots[s].name)
#     luminosity_array(Snapshots[s], nu)
#     load_luminosity(Snapshots[s], nu)
print(Snap009_hrfb.name)
luminosity_array(Snap009_hrfb, nu)
load_luminosity(Snap009_hrfb, nu)    
print(Snap009_lrfb.name)
luminosity_array(Snap009_lrfb, nu)
load_luminosity(Snap009_lrfb, nu)

# %% [markdown]
# ##### plot luminosity vs temp

# %%
def luminosity_vs_temp_plot(Snap, Year, nu): 
#     load_luminosity(Snap, nu)

    fig, ax = plt.subplots()

    ax.set_title(Year)

    ax.set_xlabel(r'$T$ (K)')
    ax.set_ylabel(r'$L_\mathrm{%sGHz}$ erg/s/Hz' % str(nu/10**9))
    ax.set_xscale('log')
    ax.set_xlim(10**3, 10**7)

    ax.set_yscale('log')
    ax.set_ylim(1, 1.e21)

    ax.plot(Snap.ordered_temp, Snap.cum_lum, label='from cells with temperature < T')
    ax.plot(Snap.ordered_temp, Snap.cum_lum_rev, label='from cells with temperature > T')

    ax.legend(loc='lower left')
    
nu = 5.3*10**9
print('')
for s in range(len(Snapshots)):
    luminosity_vs_temp_plot(Snapshots[s], Years[s], nu)

# %%
def luminosity_percent_vs_temp_plot(Snap, Year, nu):
    fig, ax = plt.subplots()

    ax.set_title(Year)

    ax.set_xlabel(r'$T$ (K)')
    ax.set_ylabel(r'%% $L_\mathrm{%sGHz}$' % str(nu/10**9))
    ax.set_xscale('log')
    ax.set_xlim(10**3, 10**7.5)

    # ax.set_yscale('log')

    ax.plot(Snap.ordered_temp, Snap.cum_lum_percent, label='from cells with temperature < T')
    ax.plot(Snap.ordered_temp, Snap.cum_lum_rev_percent, label='from cells with temperature > T')

    ax.legend()
print('')
nu = 5.3*10**9
for s in range(len(Snapshots)):
    luminosity_percent_vs_temp_plot(Snapshots[s], Years[s], nu)

# %% [markdown]
# ## 6.9 time ratio using powerlaw

# %% [markdown]
# #### ratio vs temp

# %%
def ratio_vs_temp3(Snap, Year):
#     load_time_vs_temp_arrays(Snap)
    load_cooling_times3(Snap)
    load_flow_times(Snap)
#     load_advec_times(Snap)
    
    fig, (ax1) = plt.subplots(figsize=(12,10))
#     plt.subplots_adjust(wspace=0, hspace=.1)
    ax1.set_title(Year+' power-law', fontsize=18)


    ax1.set_xscale('log')
    ax1.set_xlim(10**2, 10**7.2)
    ax1.set_xscale('log')
    ax1.set_xlabel('Temperature (K)')
    ax1.set_ylabel(r'$t_\mathrm{cool}/t_\mathrm{flow}$', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
    ax1.set_ylim(10**-5, 10**5)
    
    ax1.axhline(1)


#     ax2.set_xlabel('Temperature [K]', fontsize=14)
#     ax2.set_xscale('log')
#     ax2.set_ylabel('cooling time / flow time', fontsize=14)
#     ax2.set_yscale('log')
#     ax2.grid(True, which='both')
#     ax2.axhline(1, color='black', linewidth=3)
#     ax2.set_ylim(10**-6, 10**7)


    ax1.scatter(Snap.temperatures.flatten(), Snap.cooling_times3.flatten()/Snap.flow_times.flatten(), color='blueviolet', s=.25) 
    
#     ax1.legend()

# %%
print('')
for s in range(len(Snapshots)):
    ratio_vs_temp3(Snapshots[s], Years[s])

# %%
print('')
for Snap in Snaps9:
    print(Snap.name)
#     calculate_flow_times(Snap)
#     calculate_cooling_times3(Snap)
    ratio_vs_temp3(Snap, Snap.name)

# %%
for Snap in Snaps14:
    print(Snap.name)
    ratio_vs_temp3(Snap, Snap.name)

# %%
def ratio_vs_luminosities3(Snap, Year):
#     load_time_vs_temp_arrays(Snap)
#     load_cooling_times2(Snap)
    load_flow_times(Snap)
    load_advec_times(Snap)
    
    fig, (ax1) = plt.subplots(figsize=(12,10))
#     plt.subplots_adjust(wspace=0, hspace=.1)
    ax1.set_title(Year+' power-law', fontsize=18)


    ax1.set_xscale('log')
#     ax1.set_xlim(10**2, 10**7.2)
    ax1.set_xscale('log')
    ax1.set_xlabel(r'$L_\mathrm{%sGHz}$ erg/s/Hz' % str(nu/10**9), fontsize=14)
    ax1.set_ylabel(r'$t_\mathrm{cool}/t_\mathrm{flow}$', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
    ax1.set_ylim(10**-5, 10**5)
    ax1.axhline(1)


#     ax2.set_xlabel('Temperature [K]', fontsize=14)
#     ax2.set_xscale('log')
#     ax2.set_ylabel('cooling time / flow time', fontsize=14)
#     ax2.set_yscale('log')
#     ax2.grid(True, which='both')
#     ax2.axhline(1, color='black', linewidth=3)
#     ax2.set_ylim(10**-6, 10**7)


    ax1.scatter(Snap.luminosities.flatten(), Snap.cooling_times3.flatten()/Snap.flow_times.flatten(), color='green', s=.5) 
    
#     ax1.legend()

# %%
nu = 5.3*10**9
for s in range(len(Snapshots)):
    load_luminosity(Snapshots[s], nu)
    ratio_vs_luminosities3(Snapshots[s], Years[s])

# %% [markdown]
# #### lum vs temp

# %%
def lum_vs_temp(Snap, Year):
#     load_time_vs_temp_arrays(Snap)
#     load_cooling_times2(Snap)
#     load_flow_times(Snap)
#     load_advec_times(Snap)
    
    fig, (ax1) = plt.subplots(figsize=(12,10))
#     plt.subplots_adjust(wspace=0, hspace=.1)
    ax1.set_title(Year+' power-law', fontsize=18)


    ax1.set_xscale('log')
    ax1.set_xlim(10**2, 10**7.2)
    ax1.set_xscale('log')
    ax1.set_ylabel(r'$L_\mathrm{%sGHz}$ erg/s/Hz' % str(nu/10**9), fontsize=14)
    ax1.set_xlabel(r'$T$ (K)', fontsize=14)
    ax1.set_yscale('log')
    ax1.grid(True, which='both')
#     ax1.set_ylim(10**-5, 10**5)
    ax1.axhline(1)


#     ax2.set_xlabel('Temperature [K]', fontsize=14)
#     ax2.set_xscale('log')
#     ax2.set_ylabel('cooling time / flow time', fontsize=14)
#     ax2.set_yscale('log')
#     ax2.grid(True, which='both')
#     ax2.axhline(1, color='black', linewidth=3)
#     ax2.set_ylim(10**-6, 10**7)


    ax1.scatter(Snap.temperatures.flatten(), Snap.luminosities.flatten(), color='green', s=.25) 
    
#     ax1.legend()

# %%
print('')
for s in range(len(Snapshots)):
    lum_vs_temp(Snapshots[s], Years[s])

# %%
print('')
for Snap in [Snap009_hrfb, Snap009_lrfb]:
    lum_vs_temp(Snap, Snap.name)

# %% [markdown]
# # 7. $t_\mathrm{cool}/t_\mathrm{flow}$ Scaled Intensities
# Note to Snap:
# ScaleFluxes stored for a given SCALE = const under VICO_loc+'/Data/'+snapshot.name+'/'+snapshot.name+'_ScaleFluxes_const'+str(const)+'.npz') \
# E.g. for SCALE=1: Data/Snap039_n/Snap039_n_ScaleFluxes_const1.npz
# - Snap.ScaleFluxes_const
#
# And Intensity variables stored for a given SCALE and nu under
# VICO_loc+'/Data/'+Snap.name+'_'+str(nu/10^9)+'GHz_'+str(r_kpc)+'kpc_arrays_const'+str(const)+'.npz' \
# E.g for nu=5.3, SCALE=1: Data/Snap039_n/Snap039_n_5.3GHz_1kpc_arrays_const1.npz
# - Snap.InuA_const
# - Snap.FnuA_const
# - nu
# - r_kpc

# %% [markdown]
# const=False refers to scale_factor = t_cool/t_flow

# %% [markdown]
# ## 7.1 Testing scale fluxes for Snap039_n
# const=False refers to scale_factor = t_cool/t_flow

# %%
# Testing Snap039_n calculate scale fluxes
Scale_Fluxes39_1 = Snap039_n.load_scalefluxes_const(const=1)
Scale_Fluxes39_p1 = Snap039_n.load_scalefluxes_const(const=.1)
Scale_Fluxes39_p01 = Snap039_n.load_scalefluxes_const(const=.01)
Scale_Fluxes39_p001 = Snap039_n.load_scalefluxes_const(const=.001)
Scale_Fluxes39_ratio = Snap039_n.load_scalefluxes_const(const=False)

# %%
# Plot all for Snap039_n
# const intensity variables
CONSTANT_SCALE_FACTOR = .01 #FILL IN
Snap=Snap039_n
year = '39,000 years'
vmin = -5
vmax = 5

slicescales = np.array([4000,25000])

# plot all const frequencies for given Snap at 4000 au and 25000 au
for scale in slicescales:
    for f in range(len(frequencies)):
        intensity_const_proj_pcolormesh(Snap, year, scale, vmin, vmax, nu = frequencies[f], const=CONSTANT_SCALE_FACTOR, cmap='CMRmap',
                                        show_cbar= True, show_xlabels=True, show_ylabels=True, cbar_pad=.15,
                                        show_freq=True, vertical_cbar=False)

# %%
# plot all ratio frequencies for given Snap at 4000 au and 25000 au
for scale in slicescales:
    for f in range(len(frequencies)):
        intensity_const_proj_pcolormesh(Snap, year, scale, vmin, vmax, nu = frequencies[f], const=False, cmap='CMRmap',
                                        show_cbar= True, show_xlabels=True, show_ylabels=True, cbar_pad=.15,
                                        show_freq=True, vertical_cbar=False)

# %% [markdown]
# #### Snap039_n  Test Spectra

# %% [markdown]
# ## 7.2 spectra of all snapshots

# %%
Snapshots_temp = np.array([Snap004_n, Snap009_n, Snap021_n, Snap039_n, Snap054_n])
for Snap in (Snapshots_temp):
    Snap.load_scalefluxes_const(const=.01)
    Snap.load_scalefluxes_const(const=False)

# %%
# plot spectra for 8msun

# 3rd plot spectra scale=1

# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()



##### Inner Region #####

axA.set_title('Inner 1000AU Spectral Evolution', fontsize=16)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap004_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='4,000 yrs', marker='o', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap004_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='4,000 yrs .01', marker='x', color='palevioletred')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap004_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='4,000 yrs ratio', marker='*', color='darkmagenta')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs', marker='o', color='red')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs .01', marker='x', color='lightcoral')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='9,000 yrs ratio', marker='*', color='firebrick')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs', marker='o', color='darkorange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs .01', marker='x', color='gold')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='21,000 yrs ratio', marker='*', color='darkgoldenrod')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs', marker='o', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs .01', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='39,000 yrs ratio', marker='*', color='olivedrab')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='54,000 yrs', marker='o', color='turquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='54,000 yrs .01', marker='x', color='paleturquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='54,000 yrs ratio', marker='*', color='teal')


# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap004_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='4,000 yrs', marker='o', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap004_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='4,000 yrs .01', marker='x', color='palevioletred')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap004_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='4,000 yrs ratio', marker='*', color='darkmagenta')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs', marker='o', color='red')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs .01', marker='x', color='lightcoral')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='9,000 yrs ratio', marker='*', color='firebrick')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs', marker='o', color='darkorange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs .01', marker='x', color='gold')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='21,000 yrs ratio', marker='*', color='darkgoldenrod')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs', marker='o', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs .01', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='39,000 yrs ratio', marker='*', color='olivedrab')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='54,000 yrs', marker='o', color='turquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='54,000 yrs .01', marker='x', color='paleturquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='54,000 yrs ratio', marker='*', color='teal')
axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %%
# plot spectra for 8msun

# 3rd plot spectra scale=1

# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (12,4))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
fig.tight_layout()



##### Inner Region #####

axA.set_title('Inner 1000AU Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'2$M_\odot$', marker='v', color='red')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'2$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='v', color='red')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'4$M_\odot$', marker='s', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'4$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='s', color='orange')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'8$M_\odot$', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'8$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='x', color='yellowgreen')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'12$M_\odot$', marker='*', color='aqua')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'12$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='aqua')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'16$M_\odot$', marker='d', color='blue')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'16$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='d', color='blue')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'24$M_\odot$', marker='+', markersize=10, color='darkviolet')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',linewidth=3,
         label=r'24$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='+', markersize=10, color='darkviolet')
# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
# axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'2$M_\odot$', marker='v', color='red')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'2$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='v', color='red')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'4$M_\odot$', marker='s', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'4$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='s', color='orange')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'8$M_\odot$', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'8$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='x', color='yellowgreen')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'12$M_\odot$', marker='*', color='aqua')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'12$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='aqua')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'16$M_\odot$', marker='d', color='blue')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'16$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='d', color='blue')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'24$M_\odot$', marker='+', markersize=10, color='darkviolet')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',linewidth=3,
         label=r'24$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='+', markersize=10, color='darkviolet')
axB.legend(loc = 'upper left', bbox_to_anchor=(1.0,1))

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %% [markdown]
# horizontal legend underneath

# %%
# plot spectra for 8msun

# 3rd plot spectra scale=1

# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
fig.tight_layout()



##### Inner Region #####

axA.set_title('Inner 1000AU Spectral Evolution', fontsize=16)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'2$M_\odot$', marker='v', color='red')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'2$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='v', color='red')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'4$M_\odot$', marker='s', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'4$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='s', color='orange')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'8$M_\odot$', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'8$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='x', color='yellowgreen')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'12$M_\odot$', marker='*', color='aqua')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'12$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='aqua')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'16$M_\odot$', marker='d', color='blue')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'16$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='d', color='blue')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'24$M_\odot$', marker='+', markersize=10, color='darkviolet')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',linewidth=3,
         label=r'24$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='+', markersize=10, color='darkviolet')
# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
# axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'2$M_\odot$', marker='v', color='red')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'2$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='v', color='red')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'4$M_\odot$', marker='s', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'4$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='s', color='orange')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'8$M_\odot$', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'8$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='x', color='yellowgreen')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'12$M_\odot$', marker='*', color='aqua')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'12$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='aqua')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'16$M_\odot$', marker='d', color='blue')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap068_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', linewidth=3,
         label=r'16$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='d', color='blue')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',
         label=r'24$M_\odot$', marker='+', markersize=10, color='darkviolet')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap094_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',linewidth=3,
         label=r'24$M_\odot$ $t_\mathrm{cool}/t_\mathrm{flow}$', marker='+', markersize=10, color='darkviolet')
axA.legend(loc = 'upper left', bbox_to_anchor=(0,-.1), ncol = 10)

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %% [markdown]
# just Snap 054

# %%
# plot spectra for 8msun

# 3rd plot spectra scale=1

# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()



##### Inner Region #####

axA.set_title('Inner 1000AU Spectral Evolution', fontsize=16)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3


num=5
s = np.where(scales == 1000)[0][0]



axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='54,000 yrs', marker='o', color='turquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='54,000 yrs .01', marker='x', color='paleturquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='54,000 yrs ratio', marker='*', color='teal')


# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

num=5
s = np.where(scales == 32000)[0][0]



axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='54,000 yrs', marker='o', color='turquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='54,000 yrs .01', marker='x', color='paleturquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='54,000 yrs ratio', marker='*', color='teal')
axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %%
### some random plots idk

# %%
for s in range(1):
    Snap = Snap039_n
    Year = '39,000 yrs const'
    print(Snap.name)
    Snap.load_intensity_variables(5.3*10**9)
    Snap.load_cooling_times()
    Snap.load_flow_times()
    calculate_intensities_const(Snap)
    calculate_fluxes_const(Snap)
    intensity_const_proj_pcolormesh(Snap, Year, 4000, -3, 2.7, show_cbar=True)
    intensity_const_proj_pcolormesh(Snap, Year, 25000, -3, 2.7, show_cbar=True)
    print(Snap.FnuA_const)
    for sc in range(len(scales)):
        print(scales[sc],': ', scale_fluxes_const(Snap)[5,sc], 'mJy')

# %%
print(Snap039_n.FnuA)

# %%
for s in range(1):
    Snap = Snap039_n
    Year = '39,000 yrs scaled'
    print(Snap.name)
    Snap.load_intensity_variables(5.3*10**9)
    Snap.load_cooling_times()
    Snap.load_flow_times()
    calculate_intensities_scaled(Snap)
    calculate_fluxes_scaled(Snap)
    intensity_scaled_proj_pcolormesh(Snap, Year, 4000, -3, 2.7, show_cbar=True)
    intensity_scaled_proj_pcolormesh(Snap, Year, 25000, -3, 2.7, show_cbar=True)
    print(Snap.FnuA_scaled)
    for sc in range(len(scales)):
        print(scales[sc],': ', scale_fluxes_scaled(Snap)[5,sc], 'mJy')

# %%
# scale_fluxes_const(Snap039_n)
# Snap039_n.ScaleFluxes_scaled = scale_fluxes_scaled(Snap039_n)
print(Snap039_n.ScaleFluxes_const)
# print(Snap039_n.ScaleFluxes_scaled)
print(Snap039_n.ScaleFluxes)

# %% [markdown]
# ## 7.5 Cell by Cell Test
# uses old const methods

# %%
def get_frameA_intensity(Snap,i,j, to_print=True, labels=True):
    print('i \tj \tk \tdelta_y(AU) \tdelta_y(cm) \tT (K) \tj (mJy/(cm sr)) \tkappa (cm^-1) \ttauA \tI_cur (mJy/as) \tI_cur (erg cm^-2 sr^-1) \tdensity(g/cm^3) \tdensity (N(H)/cm^3) \tz-velocity (km/s) \tx-velocity (km/s) \ty-velocity (km/s)')
    # start with emission from backmost cell
    I_cur = Snap.emission_coefs[i,j,0] * Snap.del3[0]     
    # iterate through cells moving forward
    for k in range(1, len(Snap.x3)): #len(x3)):
        I_prev = I_cur #inputs intensity of previous cell to calculate intensity of current cell
        I_cur = (I_prev * np.exp(-1*Snap.tauA[i,j,k]) 
                 + (Snap.source_functions[i,j,k])  * (1 - np.exp(-1 * Snap.tauA[i,j,k])))
        if(to_print==True):
            if(labels==True):
                print('i=%d, j = %d, k=%d, delta_x = %dAU, delta_x = %.4ecm, T = %d K, j=%.4e mJy/(cm sr), kappa=%.4e cm^-1, tauA = %.2e, I_cur = %.3e mJy/as, I_cur=%.3e erg cm^-2 sr^-1 \
                      \tdensity = %.2e g/cm^3 \tdensity %.2e N(H)/cm^3 \tz-velocity = %d km/s \tx-velocity = %d km/s \ty-velocity = %d km/s' % 
                      (i, j, k, Snap.del3[k]/(1.496*10**13), Snap.del3[k], Snap.temperatures[i,j,k], Snap.emission_coefs[i,j,k]*10**26, Snap.absorption_coefs[i,j,k], Snap.tauA[i,j,k], I_cur* 10**26  / (4.2545 * 10**10),  I_cur,
                      Snap.q['d'][i,j,k], Snap.q['d'][i,j,k]/Constants.m_H, Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k] ))
            else:
                print('%d \t%d \t%d \t%d \t%.4e \t%d \t%.4e \t%.4e \t%.2e \t%.3e \t%.3e \
                      \t%.2e \t%.2e \t%d \t%d \t%d' % 
                      (i, j, k, Snap.del3[k]/(1.496*10**13), Snap.del3[k], Snap.temperatures[i,j,k], Snap.emission_coefs[i,j,k]*10**26, Snap.absorption_coefs[i,j,k], Snap.tauA[i,j,k], I_cur* 10**26  / (4.2545 * 10**10), I_cur,
                      Snap.q['d'][i,j,k], Snap.q['d'][i,j,k]/Constants.m_H, Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k] ))
    return(I_cur) # erg cm^-2 s^-1 Hz^-1 sr^-1

def test_frameA_intensity_const(Snap,i,j, to_print=True, labels=True, const=True):
    print('i \tj \tk \tdelta_y(AU) \tdelta_y(cm) \tT (K) \tj (mJy/(cm sr)) \tkappa (cm^-1) \ttauA \tI_cur (mJy/as) \tI_cur (erg cm^-2 sr^-1) \tdensity(g/cm^3) \tdensity (N(H)/cm^3) \tz-velocity (km/s) \tx-velocity (km/s) \ty-velocity (km/s)')
    # start with emission from backmost cell
    I_cur = Snap.emission_coefs[i,j,0] * Snap.del3[0] *.001     
    # iterate through cells moving forward
    for k in range(1, len(Snap.x3)): #len(x3)):
        if(const): scale_factor = .001
        else: 
            scale_factor = Snap.cooling_times[i,j,k]/Snap.flow_times[i,j,k]
            if(scale_factor>1): scale_factor=1 # can't be more than 1
                
        I_prev = I_cur #inputs intensity of previous cell to calculate intensity of current cell
        I_cur = (I_prev * np.exp(-1*Snap.tauA[i,j,k]*scale_factor) 
                 + (Snap.source_functions[i,j,k])  * (1 - np.exp(-1 * Snap.tauA[i,j,k]*scale_factor)))
        if(to_print==True):
            if(labels==True):
                print('i=%d, j = %d, k=%d, delta_x = %dAU, delta_x = %.4ecm, T = %d K, j=%.4e mJy/(cm sr), kappa=%.4e cm^-1, tauA = %.2e, I_cur = %.3e mJy/as, I_cur=%.3e erg cm^-2 sr^-1 \
                      \tdensity = %.2e g/cm^3 \tdensity %.2e N(H)/cm^3 \tz-velocity = %d km/s \tx-velocity = %d km/s \ty-velocity = %d km/s' % 
                      (i, j, k, Snap.del3[k]/(1.496*10**13), Snap.del3[k], Snap.temperatures[i,j,k], Snap.emission_coefs[i,j,k]*10**26, Snap.absorption_coefs[i,j,k], Snap.tauA[i,j,k], I_cur* 10**26  / (4.2545 * 10**10),  I_cur,
                      Snap.q['d'][i,j,k], Snap.q['d'][i,j,k]/Constants.m_H, Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k] ))
            else:
                print('%d \t%d \t%d \t%d \t%.4e \t%d \t%.4e \t%.4e \t%.2e \t%.3e \t%.3e \
                      \t%.2e \t%.2e \t%d \t%d \t%d' % 
                      (i, j, k, Snap.del3[k]/(1.496*10**13), Snap.del3[k], Snap.temperatures[i,j,k], Snap.emission_coefs[i,j,k]*10**26, Snap.absorption_coefs[i,j,k], Snap.tauA[i,j,k], I_cur* 10**26  / (4.2545 * 10**10), I_cur,
                      Snap.q['d'][i,j,k], Snap.q['d'][i,j,k]/Constants.m_H, Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k] ))
    return(I_cur) # erg cm^-2 s^-1 Hz^-1 sr^-1

def get_frameA_intensity_compare(Snap,i,j, to_print=True, labels=True):
    print('i \tj \tk \tdelta_y(AU) \tdelta_y(cm) \tT (K) \tj (mJy/(cm sr)) \tkappa (cm^-1) \ttauA \tI_cur (mJy/as) \tI_cur (erg cm^-2 sr^-1) \tdensity(g/cm^3) \tdensity (N(H)/cm^3) \tz-velocity (km/s) \tx-velocity (km/s) \ty-velocity (km/s)')
    # start with emission from backmost cell
    I_cur_const = Snap.emission_coefs[i,j,0] * Snap.del3[0] *.001 
    I_cur = Snap.emission_coefs[i,j,0] * Snap.del3[0]
    # iterate through cells moving forward
    for k in range(1, len(Snap.x3)): #len(x3)):
        if(const): scale_factor = .001
        else: 
            scale_factor = Snap.cooling_times[i,j,k]/Snap.flow_times[i,j,k]
            if(scale_factor>1): scale_factor=1 # can't be more than 1
                
        I_prev = I_cur #inputs intensity of previous cell to calculate intensity of current cell
        I_cur = (I_prev * np.exp(-1*Snap.tauA[i,j,k]*scale_factor) 
                 + (Snap.source_functions[i,j,k])  * (1 - np.exp(-1 * Snap.tauA[i,j,k]*scale_factor)))
        if(to_print==True):
            if(labels==True):
                print('i=%d, j = %d, k=%d, delta_x = %dAU, delta_x = %.4ecm, T = %d K, j=%.4e mJy/(cm sr), kappa=%.4e cm^-1, tauA = %.2e, I_cur = %.3e mJy/as, I_cur=%.3e erg cm^-2 sr^-1 \
                      \tdensity = %.2e g/cm^3 \tdensity %.2e N(H)/cm^3 \tz-velocity = %d km/s \tx-velocity = %d km/s \ty-velocity = %d km/s' % 
                      (i, j, k, Snap.del3[k]/(1.496*10**13), Snap.del3[k], Snap.temperatures[i,j,k], Snap.emission_coefs[i,j,k]*10**26, Snap.absorption_coefs[i,j,k], Snap.tauA[i,j,k], I_cur* 10**26  / (4.2545 * 10**10),  I_cur,
                      Snap.q['d'][i,j,k], Snap.q['d'][i,j,k]/Constants.m_H, Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k] ))
            else:
                print('%d \t%d \t%d \t%d \t%.4e \t%d \t%.4e \t%.4e \t%.2e \t%.3e \t%.3e \
                      \t%.2e \t%.2e \t%d \t%d \t%d' % 
                      (i, j, k, Snap.del3[k]/(1.496*10**13), Snap.del3[k], Snap.temperatures[i,j,k], Snap.emission_coefs[i,j,k]*10**26, Snap.absorption_coefs[i,j,k], Snap.tauA[i,j,k], I_cur* 10**26  / (4.2545 * 10**10), I_cur,
                      Snap.q['d'][i,j,k], Snap.q['d'][i,j,k]/Constants.m_H, Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k] ))
    return(I_cur) # erg cm^-2 s^-1 Hz^-1 sr^-1

# %%
print(np.unravel_index(Snap039_n.InuA.argmax(), Snap039_n.InuA.shape))
i = 160
j = 145
print(Snap039_n.InuA[i,j])

# %%
i=160
j=145
get_frameA_intensity(Snap039_n, i, j)

# %%
test_frameA_intensity_const(Snap039_n, i,j,labels=False)

# %% [markdown]
# ## 7.6 Flux for Anglada

# %%
print('Filled')
print('Years     \t1000au   \t4000au   \t32000au')
for s in range(len(Snapshots)):
    print('%s \t%f \t%f \t%f' % (Years[s], Snapshots[s].ScaleFluxes[0,5,1], 
                                 Snapshots[s].ScaleFluxes[0,5,3], Snapshots[s].ScaleFluxes[0,5,6]))

print('\nscaled by .01')
# print('Years     \t1000au   \t4000au   \t32000au')
for s in range(len(Snapshots)):
    print('%s \t%f \t%f \t%f' % (Years[s], Snapshots[s].ScaleFluxes_const[5,1], 
                                 Snapshots[s].ScaleFluxes_const[5,3], 
                                 Snapshots[s].ScaleFluxes_const[5,6]))
    
print('\nscaled by t_cool/t_flow')
# print('Years     \t1000au   \t4000au   \t32000au')
for s in range(len(Snapshots)):
    print('%s \t%f \t%f \t%f' % (Years[s], Snapshots[s].ScaleFluxes_ratio[5,1], 
                                 Snapshots[s].ScaleFluxes_ratio[5,3], 
                                 Snapshots[s].ScaleFluxes_ratio[5,6]))

# %%
print(Snap004_n.ScaleFluxes.shape)
print(frequencies.shape)
print(frequencies[5])
print(scales)

# %% [markdown]
# # 8 Resolution Comparison

# %%
# Snaps009 = np.array([Snap009_nhr, Snap009_n, Snap009_nlr])
# Snaps021 = np.array([Snap021_nhr, Snap021_n, Snap021_nlr])
# Snaps039 = np.array([Snap039_nhr, Snap039_n, Snap039_nlr])
# # Snaps054 = np.array([Snap054_n, Snap054_nlr])
# # Snaps068 = np.array([Snap068_n, Snap068_nlr])

# ResYears = np.array([np.array(['9,000 yrs hi-res', '9,000 yrs mid-res',
#                                '9,000 yrs lo-res']),
#                      np.array(['21,000 yrs hi-res', '21,000 yrs mid-res',
#                               '21,000 yrs lo-res']),
#                      np.array(['39,000 yrs hi-res', '39,000 yrs mid-res',
#                               '39,000 yrs lo-res'])])
# ResSnapshots = np.array([Snaps009, Snaps021, Snaps039])
# ResMasses = np.array([np.array([r'2$M_\odot$'+'\nhi', r'2$M_\odot$'+'\nmed',
#                                r'2$M_\odot$'+'\nlo']),
#                      np.array([r'4$M_\odot$'+'\nhi', r'4$M_\odot$'+'\nmed',
#                               r'4$M_\odot$'+'\nlo']),
#                      np.array([r'8$M_\odot$'+'\nhi', r'8$M_\odot$'+'\nmed',
#                               r'8$M_\odot$'+'\nlo'])])

# FlatResYears = ResYears.flatten()
# FlatResSnapshots = ResSnapshots.flatten()
# FlatResMasses = ResMasses.flatten()

# %%
Snaps009 = np.array([Snap009_nhr, Snap009_n])
Snaps021 = np.array([Snap021_nhr, Snap021_n])
Snaps039 = np.array([Snap039_nhr, Snap039_n])

ResYears = np.array([np.array(['9,000 yrs hi-res', '9,000 yrs mid-res']),
                     np.array(['21,000 yrs hi-res', '21,000 yrs mid-res']),
                     np.array(['39,000 yrs hi-res', '39,000 yrs mid-res'])])
print(Snaps_hires)
print(Snaps_mires)
ResSnapshots = np.array([Snaps009, Snaps021, Snaps039])
ResMasses = np.array([np.array([r'2$M_\odot$'+'\nhi', r'2$M_\odot$'+'\nmed']),
                     np.array([r'4$M_\odot$'+'\nhi', r'4$M_\odot$'+'\nmed']),
                     np.array([r'8$M_\odot$'+'\nhi', r'8$M_\odot$'+'\nmed'])])

FlatResYears = ResYears.flatten()
FlatResSnapshots = ResSnapshots.flatten()
FlatResMasses = ResMasses.flatten()

# %%
print(FlatResMasses)

# %% [markdown]
# ## 8.1 Spectra

# %% [markdown]
# plot all no ratio (with lo-res)

# %%
# # Plot all fluxes vs frequency on one

# fig = plt.figure(figsize = (15,5))
# axA = plt.subplot(1,2,1)
# axB = plt.subplot(1,2,2)
# # fig.tight_layout()

# fig.suptitle('Spectral Evolution without Cooling',fontsize=14)

# ##### Inner Region #####

# axA.set_title('Inner 1000AU', fontsize=14)
# #     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
# #     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# axA.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
# axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
# #axB.set_aspect(1)
# #axB.set_ylim(ymin,ymax)
# # ymin = -4.2
# # ymax = 3

# colors = cm.get_cmap('rainbow_r')
# c=0
# num=5
# s = np.where(scales == 1000)[0][0]


# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label=r'2$M_\odot$ hi-res', marker='x', color='red')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
#          linestyle='solid',
#          label=r'2$M_\odot$ med-res', marker='o', color='red')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'2$M_\odot$ lo-res', marker='*', color='red')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label=r'4$M_\odot$ hi-res', marker='x', color='orange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
#          linestyle='solid',
#          label=r'4$M_\odot$ med-res', marker='o', color='orange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'4$M_\odot$ lo-res', marker='*', color='orange')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label=r'8$M_\odot$ hi-res', marker='x', color='greenyellow')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
#          linestyle='solid',
#          label=r'8$M_\odot$ med-res', marker='o', color='greenyellow')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'8$M_\odot$ lo-res', marker='*', color='greenyellow')

# ##### Entire Region #####

# axB.set_title('Entire Region', fontsize=14)
# #     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
# #     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# # ymin = -4.2
# # ymax = 3


# #axB.set_title('y-direction')
# axB.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
# axB.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
# #axB.set_aspect(1)
# #axB.set_ylim(ymin,ymax)

# colors = cm.get_cmap('rainbow_r')
# c=0
# num=5
# s = np.where(scales == 32000)[0][0]

# axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label=r'2$M_\odot$ hi-res', marker='x', color='red')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
#          linestyle='solid',
#          label=r'2$M_\odot$ med-res', marker='o', color='red')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'2$M_\odot$ lo-res', marker='*', color='red')

# axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label=r'4$M_\odot$ hi-res', marker='x', color='orange')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
#          linestyle='solid',
#          label=r'4$M_\odot$ med-res', marker='o', color='orange')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'4$M_\odot$ lo-res', marker='*', color='orange')

# axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label=r'8$M_\odot$ hi-res', marker='x', color='greenyellow')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
#          linestyle='solid',
#          label=r'8$M_\odot$ med-res', marker='o', color='greenyellow')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'8$M_\odot$ lo-res', marker='*', color='greenyellow')

# axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/PaperPlots/ResSpectra_noratio.png')

# %% [markdown]
# plot all no ratio (without lo-res), withou cooling

# %%
# Plot all fluxes vs frequency on one

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()

# fig.suptitle('Spectral Evolution without Cooling',fontsize=14)

##### Inner Region #####

axA.set_title('Inner 1000AU', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'2$M_\odot$ lo-res', marker='*', color='red')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

##### Entire Region #####

axB.set_title('Entire Region', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axB.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'2$M_\odot$ lo-res', marker='*', color='red')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='solid', lw=5,
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
#          linestyle='dotted',
#          label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

fig.savefig(VICO_loc+'/PaperPlots/ResSpectra_noratio.png')

# %% [markdown]
# all including lo-res, without cooling

# %%
# Plot all fluxes vs frequency on one

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()

# fig.suptitle('Spectral Evolution without Cooling',fontsize=14)

##### Inner Region #####

axA.set_title('Inner 1000AU', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dotted', lw=2, 
         label=r'2$M_\odot$ lo-res', marker='*', color='deeppink')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dotted', lw=2,
         label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dotted', lw=2,
         label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

##### Entire Region #####

axB.set_title('Entire Region', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axB.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dotted', lw=2,
         label=r'2$M_\odot$ lo-res', marker='*', color='deeppink')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',lw=3,
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dotted', lw=2,
         label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
         linestyle='solid',lw=5,
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed', lw=3,
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dotted',lw=2,
         label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/PaperPlots/ResSpectra_noratio+lores.png')

# %% [markdown]
# all without lo-res, including cooling

# %%
# Plot all fluxes vs frequency on one

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()

# fig.suptitle('Spectral Evolution with Cooling',fontsize=14)

##### Inner Region #####

axA.set_title('Inner 1000AU', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'2$M_\odot$ lo-res', marker='*', color='red')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

##### Entire Region #####

axB.set_title('Entire Region', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axB.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'2$M_\odot$ lo-res', marker='*', color='red')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
# axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

fig.savefig(VICO_loc+'/PaperPlots/ResSpectra_ratio.png')

# %% [markdown]
# all including lo-res, WITH cooling

# %%
# Plot all fluxes vs frequency on one

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()

# fig.suptitle('Spectral Evolution without Cooling',fontsize=14)

##### Inner Region #####

axA.set_title(r'Inner 1000AU with $t_\mathrm{cool}/t_\mathrm{flow}$-scaling', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axA.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',lw=5,
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',lw=3,
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', lw=2, 
         label=r'2$M_\odot$ lo-res', marker='*', color='deeppink')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',lw=5,
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',lw=3,
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', lw=2,
         label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',lw=5,
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',lw=3,
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', lw=2,
         label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

##### Entire Region #####

axB.set_title(r'Entire Region with $t_\mathrm{cool}/t_\mathrm{flow}$-scaling', fontsize=14)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])', fontsize=12)
axB.set_ylabel(r'log($S_\nu$ / [mJy])', fontsize=12)
#axB.set_aspect(1)
axB.set_ylim(-2,-.25)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',lw=5,
         label=r'2$M_\odot$ hi-res', marker='x', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',lw=3,
         label=r'2$M_\odot$ med-res', marker='o', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', lw=2,
         label=r'2$M_\odot$ lo-res', marker='*', color='deeppink')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',lw=5,
         label=r'4$M_\odot$ hi-res', marker='x', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed',lw=3,
         label=r'4$M_\odot$ med-res', marker='o', color='orange')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted', lw=2,
         label=r'4$M_\odot$ lo-res', marker='*', color='orange')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='solid',lw=5,
         label=r'8$M_\odot$ hi-res', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dashed', lw=3,
         label=r'8$M_\odot$ med-res', marker='o', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',lw=2,
         label=r'8$M_\odot$ lo-res', marker='*', color='yellowgreen')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))
axB.yaxis.set_ticks(np.arange(-2, -.25, .25))


# fig.savefig(VICO_loc+'/PaperPlots/ResSpectra_ratio+lores.png')

# %%
# plot spectra for 2msun


# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()



##### Inner Region #####

axA.set_title('2Msun Inner 1000AU Spectral Evolution', fontsize=16)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs hi-res filled', marker='o', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs hi-res const.01', marker='x', color='palevioletred')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label=r'9,000 yrs hi-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='firebrick')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='9,000 yrs mid-res filled', marker='o', color='darkorange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='9,000 yrs mid-res const.01', marker='x', color='gold')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'9,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='darkgoldenrod')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs mid-res filled', marker='o', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs mid-res const.01', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='9,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='olivedrab')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs lo-res filled', marker='o', color='turquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs lo-res const.01', marker='x', color='paleturquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='9,000 yrs lo-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='teal')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='54,000 yrs', marker='o', color='turquoise')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='54,000 yrs .01', marker='x', color='paleturquoise')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label='54,000 yrs ratio', marker='*', color='teal')


# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('2Msun Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs hi-res filled', marker='o', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs hi-res const.01', marker='x', color='palevioletred')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label=r'9,000 yrs hi-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='firebrick')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='9,000 yrs mid-res filled', marker='o', color='darkorange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='9,000 yrs mid-res const.01', marker='x', color='gold')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'9,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='darkgoldenrod')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs mid-res filled', marker='o', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs mid-res const.01', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='9,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='olivedrab')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='9,000 yrs lo-res filled', marker='o', color='turquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='9,000 yrs lo-res const.01', marker='x', color='paleturquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap009_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='9,000 yrs lo-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='teal')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %%
# plot spectra for 2msun


# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()



##### Inner Region #####

axA.set_title('4Msun Inner 1000AU Spectral Evolution', fontsize=16)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs hi-res filled', marker='o', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs hi-res const.01', marker='x', color='palevioletred')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label=r'21,000 yrs hi-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='firebrick')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='21,000 yrs mid-res filled', marker='o', color='darkorange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='21,000 yrs mid-res const.01', marker='x', color='gold')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'21,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='darkgoldenrod')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs mid-res filled', marker='o', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs mid-res const.01', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='21,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='olivedrab')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs lo-res filled', marker='o', color='turquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs lo-res const.01', marker='x', color='paleturquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='21,000 yrs lo-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='teal')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='54,000 yrs', marker='o', color='turquoise')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='54,000 yrs .01', marker='x', color='paleturquoise')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label='54,000 yrs ratio', marker='*', color='teal')


# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('4Msun Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs hi-res filled', marker='o', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs hi-res const.01', marker='x', color='palevioletred')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label=r'21,000 yrs hi-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='firebrick')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='21,000 yrs mid-res filled', marker='o', color='darkorange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='21,000 yrs mid-res const.01', marker='x', color='gold')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'21,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='darkgoldenrod')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs mid-res filled', marker='o', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs mid-res const.01', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='21,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='olivedrab')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='21,000 yrs lo-res filled', marker='o', color='turquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='21,000 yrs lo-res const.01', marker='x', color='paleturquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap021_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='21,000 yrs lo-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='teal')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %%
# plot spectra for 8msun


# Plot all fluxes vs frequency on one
# Plot Flux at Scale of index, s

fig = plt.figure(figsize = (15,5))
axA = plt.subplot(1,2,1)
axB = plt.subplot(1,2,2)
# fig.tight_layout()



##### Inner Region #####

axA.set_title('8Msun Inner 1000AU Spectral Evolution', fontsize=16)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
axA.set_xlabel(r'log($\nu$ / [GHz])')
axA.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)
# ymin = -4.2
# ymax = 3

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 1000)[0][0]


axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs hi-res filled', marker='o', color='deeppink')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs hi-res const.01', marker='x', color='palevioletred')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label=r'39,000 yrs hi-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='firebrick')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='39,000 yrs mid-res filled', marker='o', color='darkorange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='39,000 yrs mid-res const.01', marker='x', color='gold')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'39,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='darkgoldenrod')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs mid-res filled', marker='o', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs mid-res const.01', marker='x', color='yellowgreen')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='39,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='olivedrab')

axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs lo-res filled', marker='o', color='turquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs lo-res const.01', marker='x', color='paleturquoise')
axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='39,000 yrs lo-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='teal')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='54,000 yrs', marker='o', color='turquoise')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='54,000 yrs .01', marker='x', color='paleturquoise')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap054_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label='54,000 yrs ratio', marker='*', color='teal')


# axA.legend(loc = 'upper left')

##### Entire Region #####

axB.set_title('8Msun Entire Region Spectral Evolution', fontsize=15)
#     ymin = np.log10(np.min(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) -.2
#     ymax = np.log10(np.max(np.concatenate((flux_arr[0,:,s], flux_arr[1,:,s], flux_arr[2,:,s])))) +.2
# ymin = -4.2
# ymax = 3


#axB.set_title('y-direction')
axB.set_xlabel(r'log($\nu$ / [GHz])')
axB.set_ylabel(r'log($S_\nu$ / [mJy])')
#axB.set_aspect(1)
#axB.set_ylim(ymin,ymax)

colors = cm.get_cmap('rainbow_r')
c=0
num=5
s = np.where(scales == 32000)[0][0]

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs hi-res filled', marker='o', color='deeppink')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs hi-res const.01', marker='x', color='palevioletred')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nhr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label=r'39,000 yrs hi-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='firebrick')

# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
#          linestyle='dashed',
#          label='39,000 yrs mid-res filled', marker='o', color='darkorange')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_const[:,s]), 
#          linestyle='solid',
#          label='39,000 yrs mid-res const.01', marker='x', color='gold')
# axA.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
#          linestyle='dotted',
#          label=r'39,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='darkgoldenrod')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs mid-res filled', marker='o', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs mid-res const.01', marker='x', color='yellowgreen')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_n.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='39,000 yrs mid-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='olivedrab')

axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes[0,:,s]), 
         linestyle='dashed',
         label='39,000 yrs lo-res filled', marker='o', color='turquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_const[:,s]), 
         linestyle='solid',
         label='39,000 yrs lo-res const.01', marker='x', color='paleturquoise')
axB.plot(np.log10(frequencies/10**9), np.log10(Snap039_nlr.ScaleFluxes_ratio[:,s]), 
         linestyle='dotted',
         label='39,000 yrs lo-res $t_\mathrm{cool}/t_\mathrm{flow}$', marker='*', color='teal')

axB.legend(loc = 'upper left', bbox_to_anchor=(1.03,1))

# fig.savefig(VICO_loc+'/RadioEmissions/FluxNuPlots/all_sf_Fnu_vs_nu_1000AU.png')

# %% [markdown]
# ## 8.2 Slice and Proj Images

# %%
for Snap in FlatResSnapshots:
    load_average_ionfrac_array(Snap)
    load_average_ionfrac_array_const(Snap, const=False)

# %% [markdown]
# ##### *Slice Res Map Methods*

# %%
def density_res_pcolormesh(Snap, year, scale, vmin, vmax, cmap='cividis', 
                        saveloc=False, show=False, show_cbar= False, 
                             show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('darkkhaki')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.q['d'][:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
#     ax.plot(Snap.x2[9], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[9], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[0], 
#             color='cyan', markersize=50, marker='+')
#     ax.plot(Snap.x2[270], Snap.x1[165], 
#             color='cyan', markersize=50, marker='+')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($\rho$ / [g/cm^3])'), 
                       fontsize=18,)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .45, (r'$\mathbf{\rho}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='black')#, alpha=.5)
    filename = saveloc+'/'+Snap.name+'_0_density_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename
        
        
def temp_res_pcolormesh(Snap, year, scale, vmin, vmax, cmap='hot', 
                        saveloc=False, show=False, show_cbar= False, 
                          show_xlabels=True, show_ylabels=True, cbar_pad=.2):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.temperatures[:,:,Snap.mid3])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        cbar = fig.colorbar(cont, orientation = 'horizontal', 
                            fraction=0.038, pad=cbar_pad)
        cbar.set_label(label = (r'log($T$ / [K])'), 
                       fontsize=18)
        cbar.ax.tick_params(rotation=45, labelsize = 13)
    ax.text(.02, .45, (r'$\mathbf{T}$'+'\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, weight='bold', color='white')#, alpha=.5)
    filename = saveloc+'/'+Snap.name+'_2_temp_'+str(scale)+'AU.png'
    if (saveloc != False): fig.savefig(filename, bbox_inches='tight')
    return filename

# %% [markdown]
# ##### *Ionfrac Res Map Methods*

# %%
def mass_ionfrac_res_pcolormesh(Snap, year, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
            
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=13)
            
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, mass}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    ax.text(.02, .45, (r'$\mathbf{\langle\chi_{H+}\rangle}$'+'\n'+year),
            ha='left', va='top', transform=ax.transAxes, 
            fontsize = 28, weight='bold', color='white')
    
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'
        fig.savefig(filename, bbox_inches='tight')
        return filename
    
def mass_ionfrac_res_const_pcolormesh(Snap, year, const, scale, vmin, vmax, v, cmap=new_cmap,
                            saveloc=saveloc, show_cbar= False, 
                            show_xlabels=True, show_ylabels=True, 
                            cbar_pad=.2, show_freq=False, vertical_cbar=False, 
                            show_contours=False, show_legend=False):
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    v_min=v_mins[v]
            
    # Make projection log plots for snapshot
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    if(const):
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass_const[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    else: 
        cont = ax.pcolormesh(Snap.X2_1v , Snap.X1_2v, np.rot90(np.log10(Snap.ionfrac_mass_ratio[v,:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 13)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad, extend='min')
            cbar.set_label(label = (r'log10($\langle\chi_\mathrm{H+}\rangle$ )'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=13)
            
    if(show_contours):
        cntr = ax.contour(Snap.X2_1v , Snap.X1_2v, np.rot90(Snap.maxv1), 
                       levels = [1,10,100], colors = ['darkorange', 'red', 'magenta']) #linewidths = [1, 1.5, 1])
        h,_ = cntr.legend_elements()
        if(show_legend):
            ax.legend([h[0], h[1], h[2]], ['1 km/s', '10km/s', '100km/s'], loc = 'upper center', bbox_to_anchor=(.5, -.65))
    
#     ax.text(.02, .22, (r'$\mathbf{\langle\chi_{H+}\rangle, mass}$'+'\n'+year+'\n'+'$\mathbf{v_{min}}$='+str(v_min)+' km/s'), ha='left', va='top', 
#             transform=ax.transAxes, fontsize = 13, color='white', weight='bold')
    ax.text(.02, .45, (r'$\mathbf{\langle\chi_{H+}\rangle}$'+'\n'+year),
            ha='left', va='top', transform=ax.transAxes, 
            fontsize = 28, weight='bold', color='white')
    ax.text(.65, .1, ('cooled'),
            ha='left', va='top', transform=ax.transAxes, 
            fontsize = 20, weight='bold', color='white')
    
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_const_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_ionfrac_mass_ratio_v'+str(v_mins[v])+'kms_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# ##### *Intensity Proj Map Methods*

# %%
freq_strings=np.array(['.01', '.05', '0.1', '0.5', '1.0', 
                       '5.3', '23', '43', '100', '230']) 

def intensity_res_pcolormesh(Snap, year, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')

    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 12)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=12)
    ax.text(.02, .39, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .45, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    if (saveloc != False): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_'+str(scale)+'AU.png' 
        fig.savefig(filename, bbox_inches='tight')
        return(filename)
        
def intensity_res_const_pcolormesh(Snap, year, const, scale, f, vmin, vmax, cmap='CMRmap',
                        saveloc=False, show=False, show_cbar= False, show_xlabels=True, show_ylabels=True, cbar_pad=.2,
                             vertical_cbar=False):
    nu=frequencies[f]
    Snap.load_intensity_variables(nu)
    Snap.load_intensity_variables_const(nu=nu, const=const)
    
    Snap.X1_2v, Snap.X2_1v = np.meshgrid(Snap.x1, Snap.x2)
    fig = plt.figure(figsize = (4,4))
    fig.tight_layout()
    ax = plt.subplot()
    ax.set_aspect(1)
    ax.set_xlim(-scale/2, scale/2)
    ax.set_ylim(0, scale)
    ax.set_facecolor('black')
    
    cont = ax.pcolormesh(Snap.X2_1v, Snap.X1_2v, np.log10(np.rot90(Snap.InuA_const[:,:])), 
                               vmin=vmin, vmax=vmax, cmap = cmap, shading='nearest')
    if(show_xlabels):
        ax.set_xticks([-scale*.25, 0, scale*.25])
        ax.set_xlabel('x (au)', fontsize=28)
        ax.tick_params(axis='x', labelsize=20)
    else:
        ax.tick_params(bottom=False)
        ax.set_xticks([])
    if(show_ylabels):
        ax.set_yticks([scale*.25,scale*.5,scale*.75])
        ax.set_ylabel('z (au)', fontsize=28)
        ax.tick_params(axis='y', labelsize=20)
    else:
        ax.tick_params(left=False)
        ax.set_yticks([])
        
    if(show_cbar):
        if(vertical_cbar):
            cbar = fig.colorbar(cont, orientation = 'vertical', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize = 18)
            cbar.ax.tick_params(rotation=45, labelsize = 12)
        else:
            cbar = fig.colorbar(cont, orientation = 'horizontal', 
                                fraction=0.038, pad=cbar_pad)
            cbar.set_label(label = (r'log($I_\nu$ / [mJy/as])'),
                          fontsize=18)
            cbar.ax.tick_params(rotation=45, labelsize=12)
    ax.text(.02, .39, (freq_strings[f]+'GHz'), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 20, color='white', weight='bold')
    ax.text(.02, .45, ('\n'+year), ha='left', va='top', 
            transform=ax.transAxes, fontsize = 28, color='white', weight='bold')
    ax.text(.65, .1, ('cooled'),
            ha='left', va='top', transform=ax.transAxes, 
            fontsize = 20, weight='bold', color='white')
    
    if ((saveloc) and (const)): 
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_const_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename
    elif ((saveloc)):  #  and (!const)
        filename = saveloc+'/'+Snap.name+'_'+str(nu/10**9)+'GHzIntensity_ratio_'+str(scale)+'AU.png'             
        fig.savefig(filename, bbox_inches='tight')
        return filename

# %% [markdown]
# ##### PIL Image Methods

# %%
slicescales = np.array([4000, 25000])      
v = len(v_mins)-1

vmin_density, vmax_density = -22.1, -14.7    # 0 Density Slice
vmin_temp, vmax_temp = 0, 7                  # 1 Temperature Slice
vmin_ionfrac, vmax_ionfrac = -3, 0           # 2 Ionization Fraction Slice
vmin_intensity_noratio, vmax_intensity_noratio = -3, 2.8   
vmin_intensity_ratio, vmax_intensity_ratio = -4, 0    

def res_images(Snap, year, scale, saveloc = VICO_loc+'/PaperImages/res_images', 
                 show_cbar=False, xlabels=False, cbar_pad=.15):
    # density slice
    file0 = density_res_pcolormesh(Snap=Snap, year=year, scale = scale, 
                             vmin = vmin_density, vmax=vmax_density, saveloc=saveloc, 
                             cmap='cividis', show_cbar=show_cbar, 
                             show_xlabels=xlabel, show_ylabels=True,
                             cbar_pad=cbar_pad)
    # temperature slice
    file1 = temp_res_pcolormesh(Snap=Snap, year=year, scale = scale, 
                          vmin = vmin_temp, vmax=vmax_temp, saveloc=saveloc, 
                          show=True, cmap='hot', show_cbar=show_cbar, 
                          show_xlabels=xlabel, show_ylabels=False,
                          cbar_pad=cbar_pad)

    # Ionization Fraction noratio
    file2 = mass_ionfrac_res_pcolormesh(Snap, year, scale, v = v,
                            vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                            show_xlabels = xlabels, show_ylabels = False,
                            show_contours = False, show_legend = False, 
                            show_cbar = False, saveloc=saveloc)
    # 5.3 GHz Intensity noratio
    file3 = intensity_res_pcolormesh(Snap, year, scale, 5, 
                              vmin_intensity_noratio, vmax_intensity_noratio, 
                             show_xlabels = xlabels, show_ylabels = False, 
                              show_cbar=False, saveloc=saveloc)
    
    # Ionization Fraction ratio
    file4 = mass_ionfrac_res_const_pcolormesh(Snap, year, False, scale, v = v,
                            vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                            show_xlabels = xlabels, show_ylabels = False,
                            show_contours = False, show_legend = False, 
                            show_cbar = False, saveloc=saveloc)
    
    # 5.3 GHz Intensity
    file5 = intensity_res_const_pcolormesh(Snap, year, False, scale, 5, 
                              vmin_intensity_ratio, vmax_intensity_ratio, 
                             show_xlabels = xlabels, show_ylabels = False, 
                              show_cbar=False, saveloc=saveloc)
    
    return (file0, file1, file2, file3, file4, file5)

# %%
s=0
res_images(FlatResSnapshots[s], FlatResMasses[s], 
                   scale, saveloc = saveloc, 
                   show_cbar=False, xlabels=xlabel, 
                   cbar_pad=.2)

# %%
# for PIL    
def make_res_allimage(imgfiles_arr, allimagename, scale):
    nrows = len(imgfiles_arr)
    ncols = len(imgfiles_arr[0])
    side=300
    header=0
    if(scale==25000):
        leftax = 150
    else:
        leftax=134
    bottomax = 82
    allimage=Image.new("RGBA", (ncols*side + leftax, 
                                nrows*side + bottomax + header))
    cropped_names = np.empty((nrows, ncols), dtype=object)



    for r in range(nrows):
        for c in range(ncols):
            img = Image.open(imgfiles_arr[r,c])
            width, height = img.size
#             print(r,c,width,height)
#             display(img)
            if(c==0): # y axis
                new_width=int(side*((width-6.25)/(231-6.25-7.25)))
                left=0
                new_x=0
                right=width-6.25
            else: 
                new_width=side
                left=7.25
                new_x=c*side+(leftax)
                right=width-6.25

            if(r==nrows-1): # x axis
                bottom=height
            else: 
                bottom=height-6.75
            top=7
            new_y = r*side + header

            img = img.crop((left, top, right, bottom))
#             print(r,c,img.size)
#             display(img)
            
            new_height = int(img.height*new_width/img.width)
            img = img.resize((new_width,new_height))
#             print(r,c,img.size)
#             display(img)
            allimage.paste(img, ((new_x, new_y)))
            img.save('./IonFracCroppedImages/25000_noratio_r%d_c%d.png' % (r,c))
            cropped_names[r][c] = str('25000_noratio_r%d_c%d.png' % (r,c))

    im0 = Image.open(VICO_loc+'/PaperImages/res_images/cbar_density.png')
    im1 = Image.open(VICO_loc+'/PaperImages/res_images/cbar_temp.png')
    im2 = Image.open(VICO_loc+'/PaperImages/res_images/cbar_ionfrac.png')
    im3 = Image.open(VICO_loc+'/PaperImages/res_images/cbar_intensity_noratio.png')
    im4 = Image.open(VICO_loc+'/PaperImages/res_images/cbar_ionfrac.png')
    im5 = Image.open(VICO_loc+'/PaperImages/res_images/cbar_intensity_ratio.png')
    cbar_ims = np.array([im0, im1, im2, im3, im4, im5])
    cbar_height = 0
    
    for i in range(len(cbar_ims)):
        im = cbar_ims[i]
        im = im.resize((side, int(im.height * side/im.width)))
        if(im.height > cbar_height): cbar_height = im.height
        cbar_ims[i] = im
    imnew = Image.new('RGBA', (allimage.width, allimage.height+cbar_height),
                 color='white')
    imnew.paste(allimage, (0,0))
    for i in range(len(cbar_ims)):
        imnew.paste(cbar_ims[i], (leftax+side*i, allimage.height))
        
    # lines - HARDCODED, CHANGE IF NUM ROWS CHANGES
    imdraw = ImageDraw.Draw(imnew)
    line1 = [(0,2*side), (imnew.width, 2*side)]
    line2 = [(0,4*side), (imnew.width, 4*side)]
    line3 = [(0,6*side), (imnew.width, 6*side)]
#     line2 = [(leftax+6*side,0), (leftax+6*side, header)]
    imdraw.line(line1,fill=(0,255, 255),width=10)
    imdraw.line(line2,fill=(0,255, 255),width=10)
    
    display(imnew)
    imnew.save(allimagename)

# %% [markdown]
# ##### 2.1.1 PIL Figure: 25000 au Slices

# %%
nrows = len(FlatResSnapshots)
ncols = 6
scale = 25000
resfiles_25000au = np.empty((nrows, ncols), dtype=object)
r=0
saveloc = VICO_loc+'/PaperImages/res_images'
for s in range(0,len(FlatResSnapshots)):
    print(FlatResYears[s])
    if(s < len(FlatResSnapshots)-1):
        xlabel = False
    else: xlabel = True
    file0, file1, file2, file3, file4, file5 = \
        res_images(FlatResSnapshots[s], FlatResMasses[s], 
                   scale, saveloc = saveloc, 
                   show_cbar=False, xlabels=xlabel, 
                   cbar_pad=.2)
    
    resfiles_25000au[r,0] = file0
    resfiles_25000au[r,1] = file1
    resfiles_25000au[r,2] = file2
    resfiles_25000au[r,3] = file3
    resfiles_25000au[r,4] = file4
    resfiles_25000au[r,5] = file5
    r+=1

# %%
make_res_allimage(imgfiles_arr = resfiles_25000au, 
                allimagename='/home/ecg6wm/PaperImages/Res_25000au.png',
                    scale = 25000)

# %% [markdown]
# ##### 2.1.1 PIL Figure: 25000 au Slices

# %%
nrows = len(FlatResSnapshots)
ncols = 6
scale = 4000
resfiles_4000au = np.empty((nrows, ncols), dtype=object)
r=0
saveloc = VICO_loc+'/PaperImages/res_images'
for s in range(0,len(FlatResSnapshots)):
    print(FlatResYears[s])
    if(s < len(FlatResSnapshots)-1):
        xlabel = False
    else: xlabel = True
    file0, file1, file2, file3, file4, file5 = \
        res_images(FlatResSnapshots[s], FlatResMasses[s], 
                   scale, saveloc = saveloc, 
                   show_cbar=False, xlabels=xlabel, 
                   cbar_pad=.2)
    
    resfiles_4000au[r,0] = file0
    resfiles_4000au[r,1] = file1
    resfiles_4000au[r,2] = file2
    resfiles_4000au[r,3] = file3
    resfiles_4000au[r,4] = file4
    resfiles_4000au[r,5] = file5
    r+=1

# %%
make_res_allimage(imgfiles_arr = resfiles_4000au, 
                allimagename='/home/ecg6wm/PaperImages/Res_4000au.png',
                    scale = 4000)

# %% [markdown]
# ###### *colorbars*

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/res_images'
scale = 25000
density_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                         vmin=vmin_density, vmax=vmax_density, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_0_density_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_density.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/res_images'
scale = 25000
temp_slice_pcolormesh(Snapshots[s], Years[s], scale, 
                         vmin=vmin_temp, vmax=vmax_temp, 
                         show_xlabels=False, show_ylabels=False, 
                         show_cbar=True, saveloc = saveloc)
cbar_h_img = Image.open((saveloc+'/'+Snapshots[s].name+'_2_temp_'+str(scale)+'AU.png'))
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_temp.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/res_images'
scale = 25000
filename = mass_ionfrac_proj_pcolormesh(Snapshots[s], Years[s], scale, v = v,
                        vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                        show_xlabels = False, show_ylabels = False,
                        show_contours = False, show_legend = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_ionfrac.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
saveloc = VICO_loc+'/PaperImages/res_images'
scale = 25000
filename = intensity_proj_pcolormesh(Snapshots[s], Years[s], scale, 5,
                                     vmin=vmin_intensity_noratio, 
                                     vmax = vmax_intensity_noratio, 
                        show_xlabels = False, show_ylabels = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_intensity_noratio.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %%
# use Snap004_n for this
s=0
f=5
saveloc = VICO_loc+'/PaperImages/res_images'
scale = 25000
filename = intensity_proj_const_pcolormesh(Snapshots[s], Years[s], False, 
                                     scale, f,
                                     vmin=vmin_intensity_ratio, 
                                     vmax = vmax_intensity_ratio, 
                        show_xlabels = False, show_ylabels = False, 
                        show_cbar = True, saveloc=saveloc)
cbar_h_img = Image.open(filename)
print(cbar_h_img.size)
width, height = cbar_h_img.size
left = 0
right = width
top = 200
bottom = height
cbar_h_img = cbar_h_img.crop((left, top, right, bottom))
print(cbar_h_img.size)
cbar_h_filename = saveloc+'/cbar_intensity_ratio.png'
cbar_h_img.save(cbar_h_filename)
display(cbar_h_img)

# %% [markdown]
# other shit

# %%
for s1 in range(len(ResSnapshots)):
    for scale in slicescales:
        for s2 in range(len(ResSnapshots[s1,:])):
            print(ResSnapshots[s1,s2].name)
            if(s2 < len(ResSnapshots[s1,:])-1):
                slice_images(ResSnapshots[s1,s2], ResYears[s1,s2])
            else:      
                slice_images(ResSnapshots[s1,s2], ResYears[s1,s2], xlabel=True)

# %%
for scale in slicescales:
    for Snap in Snaps14:
        if(Snap == Snaps14[-1]): 
            xlabels = True
#             show_cbar=True
        else: 
            xlabels = False
#             show_cbar = False
        slice_images(Snap, Snap.name, xlabel=xlabels)

# %%
v=2 # 100 km/s
vmin_ionfrac = -3
vmax_ionfrac = 0
nu_intensity = 5.3*10**9
vmin_iontemp = 0
vmax_iontemp = 7
vmin_intensity = -3
vmax_intensity = 2.7

for scale in slicescales:
    for Snap in Snaps9:
        if(Snap == Snaps9[-1]): 
            xlabels = True
        else:
            xlabels = False
        mass_ionfrac_pcolormesh(Snap, Snap.name, scale, v = v,
                                vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                show_xlabels = xlabels, show_ylabels = True,
                                show_contours = False, show_legend = False)
        iontemp_proj_pcolormesh(Snap, Snap.name, scale, vmin = vmin_iontemp, vmax=vmax_iontemp, 
                                show_xlabels = xlabels, show_ylabels = False)
        intensity_proj_pcolormesh(Snap, Snap.name, scale,  vmin_intensity, vmax_intensity, nu = nu_intensity,
                                 show_xlabels = xlabels, show_ylabels = False)

# %%
for scale in slicescales:
    for Snap in Snaps14:
        if(Snap == Snaps14[-1]): 
            xlabels = True
        else: xlabels = False
        mass_ionfrac_pcolormesh(Snap, Snap.name, scale, v = v,
                                vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                                show_xlabels = xlabels, show_ylabels = True,
                                show_contours = False, show_legend = False)
        iontemp_proj_pcolormesh(Snap, Snap.name, scale, vmin = vmin_iontemp, vmax=vmax_iontemp, 
                                show_xlabels = xlabels, show_ylabels = False)
        intensity_proj_pcolormesh(Snap, Snap.name, scale,  vmin_intensity, vmax_intensity, nu = nu_intensity,
                                 show_xlabels = xlabels, show_ylabels = False)
        
mass_ionfrac_pcolormesh(Snap, Snap.name, scale, v = v,
                        vmin=vmin_ionfrac, vmax = vmax_ionfrac, 
                        show_xlabels = xlabels, show_ylabels = True,
                        show_contours = False, show_legend = False, show_cbar=True)
iontemp_proj_pcolormesh(Snap, Snap.name, scale, vmin = vmin_iontemp, vmax=vmax_iontemp, 
                        show_xlabels = xlabels, show_ylabels = False, show_cbar=True)
intensity_proj_pcolormesh(Snap, Snap.name, scale,  vmin_intensity, vmax_intensity, nu = nu_intensity,
                         show_xlabels = xlabels, show_ylabels = False, show_cbar=True)

# %% [markdown]
# ## 8.3 Flux for Anglada

# %%
print('Hi-res ratio')
print('Years            \t1000au   \t4000au   \t32000au')

# s1 refers to the mass
# s2 refers to the resolution
for s2 in [0]:
    for s1 in range(len(ResSnapshots[:,s2])):
        print('%s \t%f \t%f \t%f' % (ResYears[s1,s2], ResSnapshots[s1,s2].ScaleFluxes_ratio[5,1], 
                             ResSnapshots[s1,s2].ScaleFluxes_ratio[5,3], ResSnapshots[s1,s2].ScaleFluxes_ratio[5,6]))

print('\nMid-Res ratio')
# print('Years     \t1000au   \t4000au   \t32000au')
for s2 in [1]:
    for s1 in range(len(ResSnapshots[:,s2])):
        print('%s \t%f \t%f \t%f' % (ResYears[s1,s2], ResSnapshots[s1,s2].ScaleFluxes_ratio[5,1], 
                             ResSnapshots[s1,s2].ScaleFluxes_ratio[5,3], ResSnapshots[s1,s2].ScaleFluxes_ratio[5,6]))
   
print('\nLo-res ratio')
# print('Years     \t1000au   \t4000au   \t32000au')
for s2 in [2]:
    for s1 in range(len(ResSnapshots[:,s2])):
        print('%s \t%f \t%f \t%f' % (ResYears[s1,s2], ResSnapshots[s1,s2].ScaleFluxes_ratio[5,1], 
                             ResSnapshots[s1,s2].ScaleFluxes_ratio[5,3], ResSnapshots[s1,s2].ScaleFluxes_ratio[5,6]))

# %% [markdown]
# ## old 8.3 Flux vs Height

# %%
# Plot all fluxes vs height for sloped floor (with bug)
# Plot Flux at Frequency of index f



for f in [5,9]:
    fig = plt.figure(figsize = (8,6))
    ax = plt.subplot()
    fig.tight_layout()
    ymin = -16
    ymax = 2.5

#     axA.set_title('Flux vs. Height at '+str(frequencies[f]/10**9)+'GHz', 
#                  fontsize=15)
    ax.set_xlabel('z (au)', fontsize=12)
    ax.set_ylabel(r'log($\langle S_\mathrm{%sGHz}\rangle$ / [mJy])' % str(frequencies[f]/10**9), fontsize=12)
    #axA.set_aspect(3500)
    ax.set_ylim(ymin,ymax)


    colors = cm.get_cmap('rainbow_r')
    num=2
    c=0
    for s in range(0, len(CompareSnaps)):
        load_flux_profiles(CompareSnaps[s])
        c = add_snap_to_flux_height_plot(CompareSnaps[s], CompareSnaps[s].name, c)

    
    #fig.savefig('FluxScalePlots/all_Fnu_vs_height_'+str(frequencies[f]/10**9)+'GHz.png')

# %% [markdown]
# ## 8.4 Ionfrac vs Height

# %%
# make_mass_ionfrac_arrays(Snap009_hrfb, '9,000 yrs')
make_vol_ionfrac_arrays(Snap009_hrfb, '9,000 yrs')
make_emis_ionfrac_arrays(Snap009_hrfb, '9,000 yrs', 5.3*10**9)
save_ionfrac_profile(Snap009_hrfb)

# %%
for s in range(len(CompareSnaps)):
    load_ionfrac_profile(CompareSnaps[s])
    make_xslice_plot(CompareSnaps[s], CompareSnaps[s].name)

# %%
print(np.min(Snap009_hrfb.del3))

# %% [markdown]
# #### flux

# %%
Snaps = np.array([Snap009_lrfb, Snap009_hrfb, Snap014_lrfb, Snap014_hrfb])
for Snap in Snaps:
    print('###### '+Snap.name)
    for s in (1, 3, 6):
        print(str(scales[s])+':', Snap.ScaleFluxes[0,5,s])

# %% [markdown]
# # 9. Single cell Test

# %% [markdown]
# ## 9.1 50% ionized long cooling
# i,j,k = 128, 82, 139

# %%
## density and velocity
TestSnap=Snap039_n
Snap=TestSnap
i,j,k = 128, 82, 139
print('i,j,k = %d,%d,%d' % (i,j,k))
print('z = \t%f\tau' % Snap.x1[i])
print('x = \t%f\tau' % Snap.x2[j])
print('y = \t%f\tau' % Snap.x3[k])
print('rho = \t%e\tg/cm^3' % Snap.q['d'][i,j,k])
print('n_H = \t%e\t cm^-3' % (Snap.q['d'][i,j,k]
                              /Constants.m_H))
print('delta_z = \t%f\tcm' % Snap.del1[i])
print('delta_x = \t%f\tcm' % Snap.del2[j])
print('delta_y = \t%f\tcm' % Snap.del3[k])
print('v_z = \t%f\tkm/s' % Snap.q['v1'][i,j,k])
print('v_x = \t%f\tkm/s' % Snap.q['v2'][i,j,k])
print('v_y = \t%f\tkm/s' % Snap.q['v3'][i,j,k])
print('T = \t%dK' % Snap.temperatures[i,j,k])
print('chi_H+ = \t%f' % Snap.ion_fractions[i,j,k])
def print_cell_sim_data(Snap,i,j,k):
    print('(%d,%d,%d) \t& \t%d \t& \t%d \t& \t%d \
    \t& \t%.3e \t& \t%.2f \t& \t%.2f \t& \t%.2f' % 
          (i,j,k,Snap.x1[i], Snap.x2[j], Snap.x3[k], 
           Snap.q['d'][i,j,k], Snap.q['v1'][i,j,k], 
           Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k]))
def all_sim_data(Snap,i,j,k):
    print_cell_sim_data(Snap,i,j,k) # cur
    print_cell_sim_data(Snap,i-1,j,k) # m1
    print_cell_sim_data(Snap,i+1,j,k) # p1
    print_cell_sim_data(Snap,i,j-1,k) # m2
    print_cell_sim_data(Snap,i,j+1,k) # p2
    print_cell_sim_data(Snap,i,j,k-1) # m3
    print_cell_sim_data(Snap,i,j,k+1) # p3

# %%
print_cell_sim_data(TestSnap,i,j,k)

# %%
all_sim_data(TestSnap, i,j,k)

# %%
v=25.51
print(TestSnap.temp(v))
print(TestSnap.ion_fraction(TestSnap.temp(v)))
print(TestSnap.ion_fraction2('m2',i,j,k))

# %%
v=9.94
print(TestSnap.temp(v))
print(TestSnap.ion_fraction(TestSnap.temp(v)))
print(TestSnap.ion_fraction2('p2',i,j,k))

# %%
i,j,k = 128,82,139

print('n_H = %e cm^-3' 
      % (TestSnap.q['d'][i,j,k]/Constants.m_H))
print('t_cool', 
      TestSnap.cooling_time(T=12022,n_H=259.1735, chi=.499)
      /365.25/24/3600)
print('t_cool', TestSnap.cooling_times[i,j,k]/365.25/24/3600)
print('t_flow', TestSnap.flow_times[i,j,k]/365.25/24/3600)

# %%
load_all_times(Snap=Snap039_n)

# %% [markdown]
# ## 9.2 50% ionized short cooling
# i,j,k = 55, 175, 139

# %%
## density and velocity
TestSnap=Snap039_n
Snap=TestSnap
i,j,k = 55, 175, 139
print('i,j,k = %d,%d,%d' % (i,j,k))
print('z = \t%f\tau' % Snap.x1[i])
print('x = \t%f\tau' % Snap.x2[j])
print('y = \t%f\tau' % Snap.x3[k])
print('rho = \t%e\tg/cm^3' % Snap.q['d'][i,j,k])
print('n_H = \t%e\t cm^-3' % (Snap.q['d'][i,j,k]
                              /Constants.m_H))
print('delta_z = \t%f\tcm' % Snap.del1[i])
print('delta_x = \t%f\tcm' % Snap.del2[j])
print('delta_y = \t%f\tcm' % Snap.del3[k])
print('v_z = \t%f\tkm/s' % Snap.q['v1'][i,j,k])
print('v_x = \t%f\tkm/s' % Snap.q['v2'][i,j,k])
print('v_y = \t%f\tkm/s' % Snap.q['v3'][i,j,k])
print('T = \t%dK' % Snap.temperatures[i,j,k])
print('chi_H+ = \t%f' % Snap.ion_fractions[i,j,k])
def print_cell_sim_data(Snap,i,j,k):
    print('(%d,%d,%d) \t& \t%d \t& \t%d \t& \t%d \
    \t& \t%.3e \t& \t%.2f \t& \t%.2f \t& \t%.2f' % 
          (i,j,k,Snap.x1[i], Snap.x2[j], Snap.x3[k], 
           Snap.q['d'][i,j,k], Snap.q['v1'][i,j,k], 
           Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k]))
def all_sim_data(Snap,i,j,k):
    print_cell_sim_data(Snap,i,j,k) # cur
    print_cell_sim_data(Snap,i-1,j,k) # m1
    print_cell_sim_data(Snap,i+1,j,k) # p1
    print_cell_sim_data(Snap,i,j-1,k) # m2
    print_cell_sim_data(Snap,i,j+1,k) # p2
    print_cell_sim_data(Snap,i,j,k-1) # m3
    print_cell_sim_data(Snap,i,j,k+1) # p3

# %%
print_cell_sim_data(TestSnap,i,j,k)

# %%
all_sim_data(TestSnap, i,j,k)

# %%
print(TestSnap.temp(23.26))
print(TestSnap.ion_fraction(TestSnap.temp(23.26)))
print(TestSnap.ion_fraction2('m2',i,j,k))

# %%
print(TestSnap.temp(26.12))
print(TestSnap.ion_fraction(TestSnap.temp(26.12)))
print(TestSnap.ion_fraction2('p2',i,j,k))

# %%
print('n_H = %e cm^-3' 
      % (TestSnap.q['d'][i,j,k]/Constants.m_H))
print('t_cool', 
      TestSnap.cooling_time(T=14141,n_H=17389.95, chi=.5003)
      /365.25/24/3600)
print('t_cool', TestSnap.cooling_times[i,j,k]/365.25/24/3600)
print('t_flow', TestSnap.flow_times[i,j,k]/365.25/24/3600)

# %%
## density and velocity
Snap=TestSnap
i,j,k = 165,191,139
print('i,j,k = %d,%d,%d' % (i,j,k))
print('z = \t%f\tau' % Snap.x1[i])
print('x = \t%f\tau' % Snap.x2[j])
print('y = \t%f\tau' % Snap.x3[k])
print('rho = \t%e\tg/cm^3' % Snap.q['d'][i,j,k])
print('delta_z = \t%f\tcm' % Snap.del1[i])
print('delta_x = \t%f\tcm' % Snap.del2[j])
print('delta_y = \t%f\tcm' % Snap.del3[k])
print('v_z = \t%f\tkm/s' % Snap.q['v1'][i,j,k])
print('v_x = \t%f\tkm/s' % Snap.q['v2'][i,j,k])
print('v_y = \t%f\tkm/s' % Snap.q['v3'][i,j,k])
def print_cell_sim_data(Snap,i,j,k):
    print('(%d,%d,%d) \t& \t%d \t& \t%d \t& \t%d \t& \t%.3e \t& \t%.2f \t& \t%.2f \t& \t%.2f' % 
          (i,j,k,Snap.x1[i], Snap.x2[j], Snap.x3[k], Snap.q['d'][i,j,k],
          Snap.q['v1'][i,j,k], Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k]))

# %%
print_cell_sim_data(TestSnap,i=165,j=191,k=140)
print(TestSnap.temperatures[i,j,k])
print(TestSnap.ion_fractions[i,j,k])

# %%
i,j,k = 165,191,139
print(TestSnap.temp(23.26))
print(TestSnap.ion_fraction(TestSnap.temp(23.26)))
print(TestSnap.ion_fraction2('p2',156,141,139))
print(TestSnap.ion_fractions[i,j,k])
load_cooling_times3(TestSnap)
load_flow_times2(TestSnap)

# %%
i,j,k = 165,191,139
print(TestSnap.q['d'][i,j,k])
print(Constants.m_H)
print(TestSnap.q['d'][i,j,k]/Constants.m_H)
print(TestSnap.cooling_times3[i,j,k]/365.25/24/3600)
print(cooling_time3(4565000, 168.58966936104494, 1.000)/365.25/24/3600)
print(TestSnap.flow_times2[i,j,k]/365.25/24/3600)

# %% [markdown]
# ## 9.3 Very bright cell
# (i,j,k) = (165, 191, 139)

# %%
# max temp
TestSnap = Snap039_n
TestSnap.load_intensity_variables(5.3*10**9)
array = TestSnap.emission_coefs[10:50,:,139]
print(np.max(array))
print(np.unravel_index(np.argmax(array), array.shape))

# %%
## density and velocity
TestSnap=Snap039_n
Snap=TestSnap
i,j,k = 165, 191, 139
print('i,j,k = %d,%d,%d' % (i,j,k))
print('z = \t%f\tau' % Snap.x1[i])
print('x = \t%f\tau' % Snap.x2[j])
print('y = \t%f\tau' % Snap.x3[k])
print('rho = \t%e\tg/cm^3' % Snap.q['d'][i,j,k])
print('n_H = \t%e\t cm^-3' % (Snap.q['d'][i,j,k]
                              /Constants.m_H))
print('delta_z = \t%f\tcm' % Snap.del1[i])
print('delta_x = \t%f\tcm' % Snap.del2[j])
print('delta_y = \t%f\tcm' % Snap.del3[k])
print('v_z = \t%f\tkm/s' % Snap.q['v1'][i,j,k])
print('v_x = \t%f\tkm/s' % Snap.q['v2'][i,j,k])
print('v_y = \t%f\tkm/s' % Snap.q['v3'][i,j,k])
print('T = \t%eK' % Snap.temperatures[i,j,k])
print('chi_H+ = \t%f' % Snap.ion_fractions[i,j,k])
def print_cell_sim_data(Snap,i,j,k):
    print('(%d,%d,%d) \t& \t%d \t& \t%d \t& \t%d \
    \t& \t%.3e \t& \t%.2f \t& \t%.2f \t& \t%.2f' % 
          (i,j,k,Snap.x1[i], Snap.x2[j], Snap.x3[k], 
           Snap.q['d'][i,j,k], Snap.q['v1'][i,j,k], 
           Snap.q['v2'][i,j,k], Snap.q['v3'][i,j,k]))
def all_sim_data(Snap,i,j,k):
    print_cell_sim_data(Snap,i,j,k) # cur
    print_cell_sim_data(Snap,i-1,j,k) # m1
    print_cell_sim_data(Snap,i+1,j,k) # p1
    print_cell_sim_data(Snap,i,j-1,k) # m2
    print_cell_sim_data(Snap,i,j+1,k) # p2
    print_cell_sim_data(Snap,i,j,k-1) # m3
    print_cell_sim_data(Snap,i,j,k+1) # p3

# %%
print_cell_sim_data(TestSnap,i,j,k)

# %%
all_sim_data(TestSnap, i,j,k)

# %%
# v=368.8
print(TestSnap.temp(v))
print(TestSnap.ion_fraction(TestSnap.temp(v)))
print(TestSnap.ion_fraction2('m1',i,j,k))

# %%
v=459.7

print(TestSnap.temp(v))
print(TestSnap.ion_fraction(TestSnap.temp(v)))
print(TestSnap.ion_fraction2('m1',i,j,k))

# %%
print('n_H = %e cm^-3' 
      % (TestSnap.q['d'][i,j,k]/Constants.m_H))
print('t_cool', 
      TestSnap.cooling_time(T=4565000,n_H=168.5897, chi=1.000)
      /365.25/24/3600)
print('t_cool', TestSnap.cooling_times[i,j,k]/365.25/24/3600)
print('t_flow', TestSnap.flow_times[i,j,k]/365.25/24/3600)

# %%
def flux_weighted_temp(snap,i,j,k):
    flux_tot = 0
    t_tot = 0
    if(i>0 and snap.temperatures_m1[i,j,k]>0):
        t_tot += np.abs(snap.temperatures_m1[i,j,k] * snap.q['d'][i-1,j,k] * snap.vel_in('m1',i,j,k))
        flux_tot += np.abs(snap.q['d'][i-1,j,k] * snap.vel_in('m1',i,j,k))
        print(snap.temperatures_m1[i,j,k])
    if(i<len(snap.x1)-1  and snap.temperatures_p1[i,j,k]>0):
        t_tot += np.abs(snap.temperatures_p1[i,j,k] * snap.q['d'][i+1,j,k] * snap.vel_in('p1',i,j,k))
        flux_tot += np.abs(snap.q['d'][i+1,j,k] * snap.vel_in('p1',i,j,k))
        print(snap.temperatures_p1[i,j,k])
    if(j>0  and snap.temperatures_m2[i,j,k]>0):
        t_tot += np.abs(snap.temperatures_m2[i,j,k] * snap.q['d'][i,j-1,k] * snap.vel_in('m2',i,j,k))
        flux_tot += np.abs(snap.q['d'][i,j-1,k] * snap.vel_in('m2',i,j,k))
        print(snap.temperatures_m2[i,j,k])
    if(j<len(snap.x2)-1  and snap.temperatures_p2[i,j,k]>0):
        t_tot += np.abs(snap.temperatures_p2[i,j,k] * snap.q['d'][i,j+1,k] * snap.vel_in('p2',i,j,k))
        flux_tot += np.abs(snap.q['d'][i,j+1,k] * snap.vel_in('p2',i,j,k))
        print(snap.temperatures_p2[i,j,k])
    if(k>0  and snap.temperatures_m3[i,j,k]>0):
        t_tot += np.abs(snap.temperatures_m3[i,j,k] * snap.q['d'][i,j,k-1] * snap.vel_in('m3',i,j,k))
        flux_tot += np.abs(snap.q['d'][i,j,k-1] * snap.vel_in('m3',i,j,k))
        print(snap.temperatures_m3[i,j,k])
    if(k<len(snap.x3)-1  and snap.temperatures_p3[i,j,k]>0):
        t_tot += np.abs(snap.temperatures_p3[i,j,k] * snap.q['d'][i,j,k+1] * snap.vel_in('p3',i,j,k))
        flux_tot += np.abs(snap.q['d'][i,j,k+1] * snap.vel_in('p3',i,j,k))
        print(snap.temperatures_p3[i,j,k])
    if (flux_tot>0):
        return (t_tot/flux_tot) 
    else:
        return(0)
